# %%
import os
import random

import numpy as np
import pandas as pd
import scipy.sparse as sps
import matplotlib.pyplot as plt
import seaborn as snb

# Random seed for reproducibility
SEED = 42
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)

# %%
from data_manager import DatasetLoader, DatasetSplitter, URMGenerator

dataset_loader = DatasetLoader()
dataset_splitter = DatasetSplitter(dataset_loader)
dataset_train, dataset_val = dataset_splitter.load_train_val()
URM_generator = URMGenerator(dataset_train, dataset_val)
URM_train, URM_val = URM_generator.generate_implicit_URM()
URM_all = URM_train + URM_val
# Out:
# Loading previusly generated splits...
# Generating implicit URM...

# %%
from evaluation.evaluator import EvaluatorHoldout

evaluator = EvaluatorHoldout(URM_val, cutoff_list=[10])

# %%
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import (
    SLIM_BPR_Cython,
)
from skopt.space import Real, Integer, Categorical
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

output_folder_path = "result_experiments/SLIM_BPR/"
recommender_class = SLIM_BPR_Cython
n_cases = 10
n_random_starts = int(n_cases * 0.3)
metric_to_optimize = "MAP"
cutoff_to_optimize = 10

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Define hyperparameters
hyperparameters_range_dictionary = {
    "topK": Integer(100, 2000),
    "epochs": Categorical([1500]),
    "symmetric": Categorical([True, False]),
    "sgd_mode": Categorical(["sgd", "adagrad", "adam"]),
    "lambda_i": Real(low=1e-5, high=1e-2, prior="log-uniform"),
    "lambda_j": Real(low=1e-5, high=1e-2, prior="log-uniform"),
    "learning_rate": Real(low=1e-4, high=1e-1, prior="log-uniform"),
}

hyperparameter_search = SearchBayesianSkopt(
    recommender_class,
    evaluator_validation=evaluator,
)

recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS=[
        URM_train,
    ],
    CONSTRUCTOR_KEYWORD_ARGS={},
    FIT_POSITIONAL_ARGS=[],
    FIT_KEYWORD_ARGS={},
    EARLYSTOPPING_KEYWORD_ARGS={},
)

# %%
hyperparameter_search.search(
    recommender_input_args,
    hyperparameter_search_space=hyperparameters_range_dictionary,
    n_cases=n_cases,
    n_random_starts=n_random_starts,
    save_model="best",
    output_folder_path=output_folder_path,  # Where to save the results
    output_file_name_root=recommender_class.RECOMMENDER_NAME,  # How to call the files
    metric_to_optimize=metric_to_optimize,
    cutoff_to_optimize=cutoff_to_optimize,
)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 166, 'epochs': 1500, 'symmetric': True, 'sgd_mode': 'adam', 'lambda_i': 0.0001235574369479305, 'lambda_j': 0.0016934349366472816, 'learning_rate': 0.00010280946828529104}
# Unable to read memory status: list index out of range
# SLIM_BPR_Recommender: Automatic selection of fastest train mode. Unable to get current RAM status, you may be using a non-Linux operating system. Using dense matrix.
# Processed 41629 (100.0%) in 0.77 sec. BPR loss is 3.86E-04. Sample per second: 54217
# SLIM_BPR_Recommender: Epoch 1 of 1500. Elapsed time 0.23 sec
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 1.84E-03. Sample per second: 40102
# SLIM_BPR_Recommender: Epoch 2 of 1500. Elapsed time 0.50 sec
# Processed 41629 (100.0%) in 0.28 sec. BPR loss is 3.73E-03. Sample per second: 150625
# SLIM_BPR_Recommender: Epoch 3 of 1500. Elapsed time 0.74 sec
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 6.03E-03. Sample per second: 81015
# SLIM_BPR_Recommender: Epoch 4 of 1500. Elapsed time 0.98 sec
# Processed 41629 (100.0%) in 0.76 sec. BPR loss is 8.38E-03. Sample per second: 54877
# SLIM_BPR_Recommender: Epoch 5 of 1500. Elapsed time 1.22 sec
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 1.11E-02. Sample per second: 39986
# SLIM_BPR_Recommender: Epoch 6 of 1500. Elapsed time 1.51 sec
# Processed 41629 (100.0%) in 0.28 sec. BPR loss is 1.37E-02. Sample per second: 148078
# SLIM_BPR_Recommender: Epoch 7 of 1500. Elapsed time 1.75 sec
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 1.67E-02. Sample per second: 79415
# SLIM_BPR_Recommender: Epoch 8 of 1500. Elapsed time 1.99 sec
# Processed 41629 (100.0%) in 0.76 sec. BPR loss is 1.87E-02. Sample per second: 54711
# SLIM_BPR_Recommender: Epoch 9 of 1500. Elapsed time 2.23 sec
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 2.09E-02. Sample per second: 40899
# SLIM_BPR_Recommender: Epoch 10 of 1500. Elapsed time 2.48 sec
# Processed 41629 (100.0%) in 0.28 sec. BPR loss is 2.53E-02. Sample per second: 148225
# SLIM_BPR_Recommender: Epoch 11 of 1500. Elapsed time 2.75 sec
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 2.88E-02. Sample per second: 76686
# SLIM_BPR_Recommender: Epoch 12 of 1500. Elapsed time 3.01 sec
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 3.27E-02. Sample per second: 52614
# SLIM_BPR_Recommender: Epoch 13 of 1500. Elapsed time 3.26 sec
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 3.46E-02. Sample per second: 39470
# SLIM_BPR_Recommender: Epoch 14 of 1500. Elapsed time 3.52 sec
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 3.58E-02. Sample per second: 142251
# SLIM_BPR_Recommender: Epoch 15 of 1500. Elapsed time 3.76 sec
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 3.95E-02. Sample per second: 78243
# SLIM_BPR_Recommender: Epoch 16 of 1500. Elapsed time 4.00 sec
# Processed 41629 (100.0%) in 0.77 sec. BPR loss is 4.36E-02. Sample per second: 54150
# SLIM_BPR_Recommender: Epoch 17 of 1500. Elapsed time 4.23 sec
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 4.88E-02. Sample per second: 40889
# SLIM_BPR_Recommender: Epoch 18 of 1500. Elapsed time 4.48 sec
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 5.06E-02. Sample per second: 153017
# SLIM_BPR_Recommender: Epoch 19 of 1500. Elapsed time 4.74 sec
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 5.48E-02. Sample per second: 77949
# SLIM_BPR_Recommender: Epoch 20 of 1500. Elapsed time 5.00 sec
# Processed 41629 (100.0%) in 0.77 sec. BPR loss is 6.01E-02. Sample per second: 53730
# SLIM_BPR_Recommender: Epoch 21 of 1500. Elapsed time 5.24 sec
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 6.30E-02. Sample per second: 40901
# SLIM_BPR_Recommender: Epoch 22 of 1500. Elapsed time 5.48 sec
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 6.60E-02. Sample per second: 156039
# SLIM_BPR_Recommender: Epoch 23 of 1500. Elapsed time 5.73 sec
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 7.38E-02. Sample per second: 79237
# SLIM_BPR_Recommender: Epoch 24 of 1500. Elapsed time 5.99 sec
# Processed 41629 (100.0%) in 0.78 sec. BPR loss is 7.88E-02. Sample per second: 53160
# SLIM_BPR_Recommender: Epoch 25 of 1500. Elapsed time 6.25 sec
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 7.98E-02. Sample per second: 40061
# SLIM_BPR_Recommender: Epoch 26 of 1500. Elapsed time 6.50 sec
# Processed 41629 (100.0%) in 0.28 sec. BPR loss is 8.11E-02. Sample per second: 147950
# SLIM_BPR_Recommender: Epoch 27 of 1500. Elapsed time 6.75 sec
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 8.73E-02. Sample per second: 72010
# SLIM_BPR_Recommender: Epoch 28 of 1500. Elapsed time 7.04 sec
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 8.69E-02. Sample per second: 50504
# SLIM_BPR_Recommender: Epoch 29 of 1500. Elapsed time 7.29 sec
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 9.80E-02. Sample per second: 38890
# SLIM_BPR_Recommender: Epoch 30 of 1500. Elapsed time 7.54 sec
# Processed 41629 (100.0%) in 0.38 sec. BPR loss is 9.85E-02. Sample per second: 108915
# SLIM_BPR_Recommender: Epoch 31 of 1500. Elapsed time 7.85 sec
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 1.01E-01. Sample per second: 66684
# SLIM_BPR_Recommender: Epoch 32 of 1500. Elapsed time 8.09 sec
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 1.07E-01. Sample per second: 47389
# SLIM_BPR_Recommender: Epoch 33 of 1500. Elapsed time 8.34 sec
# Processed 41629 (100.0%) in 1.12 sec. BPR loss is 1.13E-01. Sample per second: 36979
# SLIM_BPR_Recommender: Epoch 34 of 1500. Elapsed time 8.59 sec
# Processed 41629 (100.0%) in 0.38 sec. BPR loss is 1.18E-01. Sample per second: 108855
# SLIM_BPR_Recommender: Epoch 35 of 1500. Elapsed time 8.85 sec
# Processed 41629 (100.0%) in 0.64 sec. BPR loss is 1.28E-01. Sample per second: 64699
# SLIM_BPR_Recommender: Epoch 36 of 1500. Elapsed time 9.11 sec
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 1.20E-01. Sample per second: 47086
# SLIM_BPR_Recommender: Epoch 37 of 1500. Elapsed time 9.35 sec
# Processed 41629 (100.0%) in 1.12 sec. BPR loss is 1.31E-01. Sample per second: 37033
# SLIM_BPR_Recommender: Epoch 38 of 1500. Elapsed time 9.59 sec
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 1.35E-01. Sample per second: 115295
# SLIM_BPR_Recommender: Epoch 39 of 1500. Elapsed time 9.83 sec
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 1.37E-01. Sample per second: 67231
# SLIM_BPR_Recommender: Epoch 40 of 1500. Elapsed time 10.08 sec
# Processed 41629 (100.0%) in 0.87 sec. BPR loss is 1.45E-01. Sample per second: 48083
# SLIM_BPR_Recommender: Epoch 41 of 1500. Elapsed time 10.33 sec
# Processed 41629 (100.0%) in 1.10 sec. BPR loss is 1.46E-01. Sample per second: 37784
# SLIM_BPR_Recommender: Epoch 42 of 1500. Elapsed time 10.57 sec
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 1.67E-01. Sample per second: 121222
# SLIM_BPR_Recommender: Epoch 43 of 1500. Elapsed time 10.81 sec
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 1.58E-01. Sample per second: 71842
# SLIM_BPR_Recommender: Epoch 44 of 1500. Elapsed time 11.04 sec
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 1.69E-01. Sample per second: 49822
# SLIM_BPR_Recommender: Epoch 45 of 1500. Elapsed time 11.30 sec
# Processed 41629 (100.0%) in 1.11 sec. BPR loss is 1.65E-01. Sample per second: 37586
# SLIM_BPR_Recommender: Epoch 46 of 1500. Elapsed time 11.57 sec
# Processed 41629 (100.0%) in 0.35 sec. BPR loss is 1.84E-01. Sample per second: 119406
# SLIM_BPR_Recommender: Epoch 47 of 1500. Elapsed time 11.81 sec
# Processed 41629 (100.0%) in 0.59 sec. BPR loss is 1.80E-01. Sample per second: 70568
# SLIM_BPR_Recommender: Epoch 48 of 1500. Elapsed time 12.05 sec
# Processed 41629 (100.0%) in 0.85 sec. BPR loss is 1.79E-01. Sample per second: 49136
# SLIM_BPR_Recommender: Epoch 49 of 1500. Elapsed time 12.31 sec
# Processed 41629 (100.0%) in 1.09 sec. BPR loss is 2.02E-01. Sample per second: 38253
# SLIM_BPR_Recommender: Epoch 50 of 1500. Elapsed time 12.55 sec
# Processed 41629 (100.0%) in 0.33 sec. BPR loss is 2.04E-01. Sample per second: 127106
# SLIM_BPR_Recommender: Epoch 51 of 1500. Elapsed time 12.79 sec
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 1.98E-01. Sample per second: 73874
# SLIM_BPR_Recommender: Epoch 52 of 1500. Elapsed time 13.03 sec
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 2.09E-01. Sample per second: 51868
# SLIM_BPR_Recommender: Epoch 53 of 1500. Elapsed time 13.27 sec
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 2.10E-01. Sample per second: 40082
# SLIM_BPR_Recommender: Epoch 54 of 1500. Elapsed time 13.50 sec
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 2.13E-01. Sample per second: 142847
# SLIM_BPR_Recommender: Epoch 55 of 1500. Elapsed time 13.76 sec
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 2.17E-01. Sample per second: 77985
# SLIM_BPR_Recommender: Epoch 56 of 1500. Elapsed time 14.00 sec
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 2.36E-01. Sample per second: 49803
# SLIM_BPR_Recommender: Epoch 57 of 1500. Elapsed time 14.30 sec
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 2.31E-01. Sample per second: 38408
# SLIM_BPR_Recommender: Epoch 58 of 1500. Elapsed time 14.55 sec
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 2.44E-01. Sample per second: 128517
# SLIM_BPR_Recommender: Epoch 59 of 1500. Elapsed time 14.79 sec
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 2.42E-01. Sample per second: 73697
# SLIM_BPR_Recommender: Epoch 60 of 1500. Elapsed time 15.03 sec
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 2.50E-01. Sample per second: 50965
# SLIM_BPR_Recommender: Epoch 61 of 1500. Elapsed time 15.28 sec
# Processed 41629 (100.0%) in 1.06 sec. BPR loss is 2.56E-01. Sample per second: 39349
# SLIM_BPR_Recommender: Epoch 62 of 1500. Elapsed time 15.52 sec
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 2.70E-01. Sample per second: 130479
# SLIM_BPR_Recommender: Epoch 63 of 1500. Elapsed time 15.78 sec
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 2.73E-01. Sample per second: 73363
# SLIM_BPR_Recommender: Epoch 64 of 1500. Elapsed time 16.03 sec
# Processed 41629 (100.0%) in 0.86 sec. BPR loss is 2.75E-01. Sample per second: 48607
# SLIM_BPR_Recommender: Epoch 65 of 1500. Elapsed time 16.32 sec
# Processed 41629 (100.0%) in 1.12 sec. BPR loss is 2.90E-01. Sample per second: 37124
# SLIM_BPR_Recommender: Epoch 66 of 1500. Elapsed time 16.59 sec
# Processed 41629 (100.0%) in 0.38 sec. BPR loss is 2.99E-01. Sample per second: 110333
# SLIM_BPR_Recommender: Epoch 67 of 1500. Elapsed time 16.84 sec
# Processed 41629 (100.0%) in 0.63 sec. BPR loss is 2.88E-01. Sample per second: 66146
# SLIM_BPR_Recommender: Epoch 68 of 1500. Elapsed time 17.09 sec
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 2.96E-01. Sample per second: 47093
# SLIM_BPR_Recommender: Epoch 69 of 1500. Elapsed time 17.35 sec
# Processed 41629 (100.0%) in 1.16 sec. BPR loss is 3.14E-01. Sample per second: 35916
# SLIM_BPR_Recommender: Epoch 70 of 1500. Elapsed time 17.62 sec
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 3.30E-01. Sample per second: 97934
# SLIM_BPR_Recommender: Epoch 71 of 1500. Elapsed time 17.89 sec
# Processed 41629 (100.0%) in 0.76 sec. BPR loss is 3.21E-01. Sample per second: 55053
# SLIM_BPR_Recommender: Epoch 72 of 1500. Elapsed time 18.22 sec
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 3.47E-01. Sample per second: 38842
# SLIM_BPR_Recommender: Epoch 73 of 1500. Elapsed time 18.54 sec
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 3.22E-01. Sample per second: 136305
# SLIM_BPR_Recommender: Epoch 74 of 1500. Elapsed time 18.77 sec
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 3.27E-01. Sample per second: 79095
# SLIM_BPR_Recommender: Epoch 75 of 1500. Elapsed time 18.99 sec
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 3.49E-01. Sample per second: 39735
# SLIM_BPR_Recommender: Epoch 76 of 1500. Elapsed time 19.51 sec
# Processed 41629 (100.0%) in 0.71 sec. BPR loss is 3.58E-01. Sample per second: 58369
# SLIM_BPR_Recommender: Epoch 77 of 1500. Elapsed time 20.18 sec
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 3.34E-01. Sample per second: 39509
# SLIM_BPR_Recommender: Epoch 78 of 1500. Elapsed time 20.52 sec
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 3.92E-01. Sample per second: 100896
# SLIM_BPR_Recommender: Epoch 79 of 1500. Elapsed time 20.88 sec
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 3.81E-01. Sample per second: 62770
# SLIM_BPR_Recommender: Epoch 80 of 1500. Elapsed time 21.13 sec
# Processed 41629 (100.0%) in 0.93 sec. BPR loss is 3.72E-01. Sample per second: 44959
# SLIM_BPR_Recommender: Epoch 81 of 1500. Elapsed time 21.39 sec
# Processed 41629 (100.0%) in 1.17 sec. BPR loss is 3.84E-01. Sample per second: 35678
# SLIM_BPR_Recommender: Epoch 82 of 1500. Elapsed time 21.63 sec
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 4.00E-01. Sample per second: 102090
# SLIM_BPR_Recommender: Epoch 83 of 1500. Elapsed time 21.87 sec
# Processed 41629 (100.0%) in 0.65 sec. BPR loss is 4.09E-01. Sample per second: 63631
# SLIM_BPR_Recommender: Epoch 84 of 1500. Elapsed time 22.12 sec
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 4.10E-01. Sample per second: 46461
# SLIM_BPR_Recommender: Epoch 85 of 1500. Elapsed time 22.36 sec
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 4.14E-01. Sample per second: 36614
# SLIM_BPR_Recommender: Epoch 86 of 1500. Elapsed time 22.60 sec
# Processed 41629 (100.0%) in 0.38 sec. BPR loss is 4.17E-01. Sample per second: 110726
# SLIM_BPR_Recommender: Epoch 87 of 1500. Elapsed time 22.84 sec
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 4.28E-01. Sample per second: 67508
# SLIM_BPR_Recommender: Epoch 88 of 1500. Elapsed time 23.08 sec
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 4.07E-01. Sample per second: 47390
# SLIM_BPR_Recommender: Epoch 89 of 1500. Elapsed time 23.34 sec
# Processed 41629 (100.0%) in 1.12 sec. BPR loss is 4.54E-01. Sample per second: 37146
# SLIM_BPR_Recommender: Epoch 90 of 1500. Elapsed time 23.59 sec
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 4.40E-01. Sample per second: 112761
# SLIM_BPR_Recommender: Epoch 91 of 1500. Elapsed time 23.83 sec
# Processed 41629 (100.0%) in 0.61 sec. BPR loss is 4.53E-01. Sample per second: 67720
# SLIM_BPR_Recommender: Epoch 92 of 1500. Elapsed time 24.08 sec
# Processed 41629 (100.0%) in 0.86 sec. BPR loss is 4.60E-01. Sample per second: 48611
# SLIM_BPR_Recommender: Epoch 93 of 1500. Elapsed time 24.32 sec
# Processed 41629 (100.0%) in 1.10 sec. BPR loss is 4.73E-01. Sample per second: 37938
# SLIM_BPR_Recommender: Epoch 94 of 1500. Elapsed time 24.56 sec
# Processed 41629 (100.0%) in 0.33 sec. BPR loss is 4.95E-01. Sample per second: 125649
# SLIM_BPR_Recommender: Epoch 95 of 1500. Elapsed time 24.80 sec
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 4.84E-01. Sample per second: 73161
# SLIM_BPR_Recommender: Epoch 96 of 1500. Elapsed time 25.03 sec
# Processed 41629 (100.0%) in 0.85 sec. BPR loss is 5.05E-01. Sample per second: 49111
# SLIM_BPR_Recommender: Epoch 97 of 1500. Elapsed time 25.31 sec
# Processed 41629 (100.0%) in 1.10 sec. BPR loss is 5.05E-01. Sample per second: 37741
# SLIM_BPR_Recommender: Epoch 98 of 1500. Elapsed time 25.57 sec
# Processed 41629 (100.0%) in 0.38 sec. BPR loss is 5.05E-01. Sample per second: 109615
# SLIM_BPR_Recommender: Epoch 99 of 1500. Elapsed time 25.84 sec
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 5.28E-01. Sample per second: 66898
# SLIM_BPR_Recommender: Epoch 100 of 1500. Elapsed time 26.09 sec
# Processed 41629 (100.0%) in 0.86 sec. BPR loss is 5.12E-01. Sample per second: 48281
# SLIM_BPR_Recommender: Epoch 101 of 1500. Elapsed time 26.33 sec
# Processed 41629 (100.0%) in 1.10 sec. BPR loss is 5.35E-01. Sample per second: 37691
# SLIM_BPR_Recommender: Epoch 102 of 1500. Elapsed time 26.57 sec
# Processed 41629 (100.0%) in 0.35 sec. BPR loss is 5.57E-01. Sample per second: 120452
# SLIM_BPR_Recommender: Epoch 103 of 1500. Elapsed time 26.81 sec
# Processed 41629 (100.0%) in 0.59 sec. BPR loss is 5.30E-01. Sample per second: 70923
# SLIM_BPR_Recommender: Epoch 104 of 1500. Elapsed time 27.05 sec
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 5.50E-01. Sample per second: 50155
# SLIM_BPR_Recommender: Epoch 105 of 1500. Elapsed time 27.30 sec
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 5.88E-01. Sample per second: 38678
# SLIM_BPR_Recommender: Epoch 106 of 1500. Elapsed time 27.54 sec
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 5.65E-01. Sample per second: 129782
# SLIM_BPR_Recommender: Epoch 107 of 1500. Elapsed time 27.79 sec
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 5.64E-01. Sample per second: 73419
# SLIM_BPR_Recommender: Epoch 108 of 1500. Elapsed time 28.03 sec
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 6.07E-01. Sample per second: 51304
# SLIM_BPR_Recommender: Epoch 109 of 1500. Elapsed time 28.28 sec
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 5.97E-01. Sample per second: 39534
# SLIM_BPR_Recommender: Epoch 110 of 1500. Elapsed time 28.52 sec
# Processed 41629 (100.0%) in 0.29 sec. BPR loss is 6.02E-01. Sample per second: 141917
# SLIM_BPR_Recommender: Epoch 111 of 1500. Elapsed time 28.76 sec
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 6.32E-01. Sample per second: 77506
# SLIM_BPR_Recommender: Epoch 112 of 1500. Elapsed time 29.00 sec
# Processed 41629 (100.0%) in 0.78 sec. BPR loss is 6.27E-01. Sample per second: 53614
# SLIM_BPR_Recommender: Epoch 113 of 1500. Elapsed time 29.24 sec
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 6.01E-01. Sample per second: 40891
# SLIM_BPR_Recommender: Epoch 114 of 1500. Elapsed time 29.48 sec
# Processed 41629 (100.0%) in 0.26 sec. BPR loss is 6.38E-01. Sample per second: 161434
# SLIM_BPR_Recommender: Epoch 115 of 1500. Elapsed time 29.72 sec
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 6.45E-01. Sample per second: 82795
# SLIM_BPR_Recommender: Epoch 116 of 1500. Elapsed time 29.97 sec
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 6.53E-01. Sample per second: 56171
# SLIM_BPR_Recommender: Epoch 117 of 1500. Elapsed time 30.21 sec
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 6.32E-01. Sample per second: 42342
# SLIM_BPR_Recommender: Epoch 118 of 1500. Elapsed time 30.45 sec
# Processed 41629 (100.0%) in 1.25 sec. BPR loss is 6.51E-01. Sample per second: 33350
# SLIM_BPR_Recommender: Epoch 119 of 1500. Elapsed time 30.71 sec
# Processed 41629 (100.0%) in 0.49 sec. BPR loss is 7.09E-01. Sample per second: 84744
# SLIM_BPR_Recommender: Epoch 120 of 1500. Elapsed time 30.96 sec
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 6.99E-01. Sample per second: 56776
# SLIM_BPR_Recommender: Epoch 121 of 1500. Elapsed time 31.20 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 6.76E-01. Sample per second: 42775
# SLIM_BPR_Recommender: Epoch 122 of 1500. Elapsed time 31.44 sec
# Processed 41629 (100.0%) in 1.22 sec. BPR loss is 7.20E-01. Sample per second: 34102
# SLIM_BPR_Recommender: Epoch 123 of 1500. Elapsed time 31.69 sec
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 6.83E-01. Sample per second: 90186
# SLIM_BPR_Recommender: Epoch 124 of 1500. Elapsed time 31.93 sec
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 7.55E-01. Sample per second: 59053
# SLIM_BPR_Recommender: Epoch 125 of 1500. Elapsed time 32.17 sec
# Processed 41629 (100.0%) in 0.95 sec. BPR loss is 7.04E-01. Sample per second: 43790
# SLIM_BPR_Recommender: Epoch 126 of 1500. Elapsed time 32.42 sec
# Processed 41629 (100.0%) in 1.19 sec. BPR loss is 7.18E-01. Sample per second: 35005
# SLIM_BPR_Recommender: Epoch 127 of 1500. Elapsed time 32.65 sec
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 7.31E-01. Sample per second: 96750
# SLIM_BPR_Recommender: Epoch 128 of 1500. Elapsed time 32.89 sec
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 7.02E-01. Sample per second: 62255
# SLIM_BPR_Recommender: Epoch 129 of 1500. Elapsed time 33.13 sec
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 7.29E-01. Sample per second: 45946
# SLIM_BPR_Recommender: Epoch 130 of 1500. Elapsed time 33.37 sec
# Processed 41629 (100.0%) in 1.15 sec. BPR loss is 7.76E-01. Sample per second: 36293
# SLIM_BPR_Recommender: Epoch 131 of 1500. Elapsed time 33.61 sec
# Processed 41629 (100.0%) in 0.39 sec. BPR loss is 7.71E-01. Sample per second: 108055
# SLIM_BPR_Recommender: Epoch 132 of 1500. Elapsed time 33.85 sec
# Processed 41629 (100.0%) in 0.63 sec. BPR loss is 7.81E-01. Sample per second: 66400
# SLIM_BPR_Recommender: Epoch 133 of 1500. Elapsed time 34.09 sec
# Processed 41629 (100.0%) in 0.87 sec. BPR loss is 7.59E-01. Sample per second: 47811
# SLIM_BPR_Recommender: Epoch 134 of 1500. Elapsed time 34.34 sec
# Processed 41629 (100.0%) in 1.11 sec. BPR loss is 8.30E-01. Sample per second: 37499
# SLIM_BPR_Recommender: Epoch 135 of 1500. Elapsed time 34.58 sec
# Processed 41629 (100.0%) in 0.35 sec. BPR loss is 8.23E-01. Sample per second: 118854
# SLIM_BPR_Recommender: Epoch 136 of 1500. Elapsed time 34.82 sec
# Processed 41629 (100.0%) in 0.59 sec. BPR loss is 7.89E-01. Sample per second: 70191
# SLIM_BPR_Recommender: Epoch 137 of 1500. Elapsed time 35.06 sec
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 8.26E-01. Sample per second: 49770
# SLIM_BPR_Recommender: Epoch 138 of 1500. Elapsed time 35.30 sec
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 8.18E-01. Sample per second: 38528
# SLIM_BPR_Recommender: Epoch 139 of 1500. Elapsed time 35.55 sec
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 8.26E-01. Sample per second: 129131
# SLIM_BPR_Recommender: Epoch 140 of 1500. Elapsed time 35.79 sec
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 8.33E-01. Sample per second: 74197
# SLIM_BPR_Recommender: Epoch 141 of 1500. Elapsed time 36.03 sec
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 8.74E-01. Sample per second: 52380
# SLIM_BPR_Recommender: Epoch 142 of 1500. Elapsed time 36.26 sec
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 8.90E-01. Sample per second: 40409
# SLIM_BPR_Recommender: Epoch 143 of 1500. Elapsed time 36.49 sec
# Processed 41629 (100.0%) in 0.26 sec. BPR loss is 9.09E-01. Sample per second: 159968
# SLIM_BPR_Recommender: Epoch 144 of 1500. Elapsed time 36.73 sec
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 9.08E-01. Sample per second: 83422
# SLIM_BPR_Recommender: Epoch 145 of 1500. Elapsed time 36.96 sec
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 9.08E-01. Sample per second: 56814
# SLIM_BPR_Recommender: Epoch 146 of 1500. Elapsed time 37.20 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 9.11E-01. Sample per second: 43071
# SLIM_BPR_Recommender: Epoch 147 of 1500. Elapsed time 37.43 sec
# Processed 41629 (100.0%) in 1.20 sec. BPR loss is 9.43E-01. Sample per second: 34685
# SLIM_BPR_Recommender: Epoch 148 of 1500. Elapsed time 37.66 sec
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 8.85E-01. Sample per second: 95871
# SLIM_BPR_Recommender: Epoch 149 of 1500. Elapsed time 37.90 sec
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 8.94E-01. Sample per second: 62267
# SLIM_BPR_Recommender: Epoch 150 of 1500. Elapsed time 38.13 sec
# Processed 41629 (100.0%) in 0.90 sec. BPR loss is 9.53E-01. Sample per second: 46126
# SLIM_BPR_Recommender: Epoch 151 of 1500. Elapsed time 38.37 sec
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 9.49E-01. Sample per second: 36649
# SLIM_BPR_Recommender: Epoch 152 of 1500. Elapsed time 38.60 sec
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 1.01E+00. Sample per second: 112125
# SLIM_BPR_Recommender: Epoch 153 of 1500. Elapsed time 38.84 sec
# Processed 41629 (100.0%) in 0.61 sec. BPR loss is 9.36E-01. Sample per second: 68251
# SLIM_BPR_Recommender: Epoch 154 of 1500. Elapsed time 39.08 sec
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 1.01E+00. Sample per second: 47363
# SLIM_BPR_Recommender: Epoch 155 of 1500. Elapsed time 39.34 sec
# Processed 41629 (100.0%) in 1.11 sec. BPR loss is 1.03E+00. Sample per second: 37483
# SLIM_BPR_Recommender: Epoch 156 of 1500. Elapsed time 39.58 sec
# Processed 41629 (100.0%) in 0.35 sec. BPR loss is 1.00E+00. Sample per second: 120086
# SLIM_BPR_Recommender: Epoch 157 of 1500. Elapsed time 39.81 sec
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 1.01E+00. Sample per second: 71363
# SLIM_BPR_Recommender: Epoch 158 of 1500. Elapsed time 40.05 sec
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 9.78E-01. Sample per second: 50907
# SLIM_BPR_Recommender: Epoch 159 of 1500. Elapsed time 40.28 sec
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 1.11E+00. Sample per second: 39859
# SLIM_BPR_Recommender: Epoch 160 of 1500. Elapsed time 40.51 sec
# Processed 41629 (100.0%) in 0.28 sec. BPR loss is 9.91E-01. Sample per second: 147241
# SLIM_BPR_Recommender: Epoch 161 of 1500. Elapsed time 40.75 sec
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 1.02E+00. Sample per second: 80640
# SLIM_BPR_Recommender: Epoch 162 of 1500. Elapsed time 40.98 sec
# Processed 41629 (100.0%) in 0.75 sec. BPR loss is 1.09E+00. Sample per second: 55418
# SLIM_BPR_Recommender: Epoch 163 of 1500. Elapsed time 41.22 sec
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 1.06E+00. Sample per second: 42318
# SLIM_BPR_Recommender: Epoch 164 of 1500. Elapsed time 41.45 sec
# Processed 41629 (100.0%) in 1.22 sec. BPR loss is 1.08E+00. Sample per second: 34186
# SLIM_BPR_Recommender: Epoch 165 of 1500. Elapsed time 41.68 sec
# Processed 41629 (100.0%) in 0.45 sec. BPR loss is 1.06E+00. Sample per second: 92567
# SLIM_BPR_Recommender: Epoch 166 of 1500. Elapsed time 41.92 sec
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 1.15E+00. Sample per second: 60808
# SLIM_BPR_Recommender: Epoch 167 of 1500. Elapsed time 42.15 sec
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 1.09E+00. Sample per second: 45421
# SLIM_BPR_Recommender: Epoch 168 of 1500. Elapsed time 42.38 sec
# Processed 41629 (100.0%) in 1.15 sec. BPR loss is 1.11E+00. Sample per second: 36209
# SLIM_BPR_Recommender: Epoch 169 of 1500. Elapsed time 42.61 sec
# Processed 41629 (100.0%) in 0.38 sec. BPR loss is 1.05E+00. Sample per second: 108285
# SLIM_BPR_Recommender: Epoch 170 of 1500. Elapsed time 42.85 sec
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 1.10E+00. Sample per second: 67560
# SLIM_BPR_Recommender: Epoch 171 of 1500. Elapsed time 43.08 sec
# Processed 41629 (100.0%) in 0.85 sec. BPR loss is 1.12E+00. Sample per second: 48923
# SLIM_BPR_Recommender: Epoch 172 of 1500. Elapsed time 43.32 sec
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 1.14E+00. Sample per second: 38429
# SLIM_BPR_Recommender: Epoch 173 of 1500. Elapsed time 43.55 sec
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 1.14E+00. Sample per second: 131323
# SLIM_BPR_Recommender: Epoch 174 of 1500. Elapsed time 43.78 sec
# Processed 41629 (100.0%) in 0.55 sec. BPR loss is 1.22E+00. Sample per second: 75372
# SLIM_BPR_Recommender: Epoch 175 of 1500. Elapsed time 44.02 sec
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 1.16E+00. Sample per second: 52897
# SLIM_BPR_Recommender: Epoch 176 of 1500. Elapsed time 44.25 sec
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 1.25E+00. Sample per second: 40712
# SLIM_BPR_Recommender: Epoch 177 of 1500. Elapsed time 44.49 sec
# Processed 41629 (100.0%) in 0.26 sec. BPR loss is 1.18E+00. Sample per second: 162279
# SLIM_BPR_Recommender: Epoch 178 of 1500. Elapsed time 44.72 sec
# Processed 41629 (100.0%) in 0.49 sec. BPR loss is 1.22E+00. Sample per second: 85095
# SLIM_BPR_Recommender: Epoch 179 of 1500. Elapsed time 44.95 sec
# Processed 41629 (100.0%) in 0.72 sec. BPR loss is 1.27E+00. Sample per second: 57562
# SLIM_BPR_Recommender: Epoch 180 of 1500. Elapsed time 45.19 sec
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 1.20E+00. Sample per second: 43266
# SLIM_BPR_Recommender: Epoch 181 of 1500. Elapsed time 45.43 sec
# Processed 41629 (100.0%) in 1.20 sec. BPR loss is 1.15E+00. Sample per second: 34753
# SLIM_BPR_Recommender: Epoch 182 of 1500. Elapsed time 45.66 sec
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 1.26E+00. Sample per second: 97280
# SLIM_BPR_Recommender: Epoch 183 of 1500. Elapsed time 45.89 sec
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 1.30E+00. Sample per second: 62868
# SLIM_BPR_Recommender: Epoch 184 of 1500. Elapsed time 46.13 sec
# Processed 41629 (100.0%) in 0.90 sec. BPR loss is 1.20E+00. Sample per second: 46287
# SLIM_BPR_Recommender: Epoch 185 of 1500. Elapsed time 46.36 sec
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 1.29E+00. Sample per second: 36710
# SLIM_BPR_Recommender: Epoch 186 of 1500. Elapsed time 46.60 sec
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 1.21E+00. Sample per second: 112986
# SLIM_BPR_Recommender: Epoch 187 of 1500. Elapsed time 46.83 sec
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 1.30E+00. Sample per second: 69108
# SLIM_BPR_Recommender: Epoch 188 of 1500. Elapsed time 47.07 sec
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 1.30E+00. Sample per second: 49748
# SLIM_BPR_Recommender: Epoch 189 of 1500. Elapsed time 47.30 sec
# Processed 41629 (100.0%) in 1.10 sec. BPR loss is 1.31E+00. Sample per second: 37768
# SLIM_BPR_Recommender: Epoch 190 of 1500. Elapsed time 47.57 sec
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 1.30E+00. Sample per second: 123706
# SLIM_BPR_Recommender: Epoch 191 of 1500. Elapsed time 47.80 sec
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 1.34E+00. Sample per second: 73137
# SLIM_BPR_Recommender: Epoch 192 of 1500. Elapsed time 48.03 sec
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 1.41E+00. Sample per second: 51859
# SLIM_BPR_Recommender: Epoch 193 of 1500. Elapsed time 48.27 sec
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 1.39E+00. Sample per second: 40191
# SLIM_BPR_Recommender: Epoch 194 of 1500. Elapsed time 48.50 sec
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 1.36E+00. Sample per second: 152231
# SLIM_BPR_Recommender: Epoch 195 of 1500. Elapsed time 48.74 sec
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 1.38E+00. Sample per second: 82855
# SLIM_BPR_Recommender: Epoch 196 of 1500. Elapsed time 48.97 sec
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 1.45E+00. Sample per second: 56833
# SLIM_BPR_Recommender: Epoch 197 of 1500. Elapsed time 49.20 sec
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 1.45E+00. Sample per second: 43090
# SLIM_BPR_Recommender: Epoch 198 of 1500. Elapsed time 49.43 sec
# Processed 41629 (100.0%) in 1.20 sec. BPR loss is 1.44E+00. Sample per second: 34664
# SLIM_BPR_Recommender: Epoch 199 of 1500. Elapsed time 49.67 sec
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 1.38E+00. Sample per second: 96091
# SLIM_BPR_Recommender: Epoch 200 of 1500. Elapsed time 49.90 sec
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 1.43E+00. Sample per second: 62299
# SLIM_BPR_Recommender: Epoch 201 of 1500. Elapsed time 50.13 sec
# Processed 41629 (100.0%) in 0.90 sec. BPR loss is 1.45E+00. Sample per second: 46243
# SLIM_BPR_Recommender: Epoch 202 of 1500. Elapsed time 50.36 sec
# Processed 41629 (100.0%) in 1.14 sec. BPR loss is 1.54E+00. Sample per second: 36598
# SLIM_BPR_Recommender: Epoch 203 of 1500. Elapsed time 50.60 sec
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 1.47E+00. Sample per second: 112051
# SLIM_BPR_Recommender: Epoch 204 of 1500. Elapsed time 50.84 sec
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 1.57E+00. Sample per second: 68945
# SLIM_BPR_Recommender: Epoch 205 of 1500. Elapsed time 51.07 sec
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 1.45E+00. Sample per second: 49629
# SLIM_BPR_Recommender: Epoch 206 of 1500. Elapsed time 51.30 sec
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 1.55E+00. Sample per second: 38803
# SLIM_BPR_Recommender: Epoch 207 of 1500. Elapsed time 51.54 sec
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 1.50E+00. Sample per second: 136096
# SLIM_BPR_Recommender: Epoch 208 of 1500. Elapsed time 51.77 sec
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 1.51E+00. Sample per second: 77164
# SLIM_BPR_Recommender: Epoch 209 of 1500. Elapsed time 52.00 sec
# Processed 41629 (100.0%) in 0.77 sec. BPR loss is 1.54E+00. Sample per second: 53684
# SLIM_BPR_Recommender: Epoch 210 of 1500. Elapsed time 52.24 sec
# Processed 41629 (100.0%) in 1.01 sec. BPR loss is 1.51E+00. Sample per second: 41252
# SLIM_BPR_Recommender: Epoch 211 of 1500. Elapsed time 52.47 sec
# Processed 41629 (100.0%) in 0.25 sec. BPR loss is 1.58E+00. Sample per second: 163510
# SLIM_BPR_Recommender: Epoch 212 of 1500. Elapsed time 52.72 sec
# Processed 41629 (100.0%) in 0.49 sec. BPR loss is 1.65E+00. Sample per second: 84908
# SLIM_BPR_Recommender: Epoch 213 of 1500. Elapsed time 52.96 sec
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 1.61E+00. Sample per second: 56984
# SLIM_BPR_Recommender: Epoch 214 of 1500. Elapsed time 53.20 sec
# Processed 41629 (100.0%) in 0.96 sec. BPR loss is 1.60E+00. Sample per second: 43204
# SLIM_BPR_Recommender: Epoch 215 of 1500. Elapsed time 53.43 sec
# Processed 41629 (100.0%) in 1.20 sec. BPR loss is 1.57E+00. Sample per second: 34807
# SLIM_BPR_Recommender: Epoch 216 of 1500. Elapsed time 53.66 sec
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 1.55E+00. Sample per second: 97013
# SLIM_BPR_Recommender: Epoch 217 of 1500. Elapsed time 53.89 sec
# Processed 41629 (100.0%) in 0.66 sec. BPR loss is 1.70E+00. Sample per second: 62933
# SLIM_BPR_Recommender: Epoch 218 of 1500. Elapsed time 54.13 sec
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 1.65E+00. Sample per second: 46488
# SLIM_BPR_Recommender: Epoch 219 of 1500. Elapsed time 54.36 sec
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 1.59E+00. Sample per second: 36839
# SLIM_BPR_Recommender: Epoch 220 of 1500. Elapsed time 54.60 sec
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 1.75E+00. Sample per second: 113663
# SLIM_BPR_Recommender: Epoch 221 of 1500. Elapsed time 54.83 sec
# Processed 41629 (100.0%) in 0.59 sec. BPR loss is 1.62E+00. Sample per second: 69859
# SLIM_BPR_Recommender: Epoch 222 of 1500. Elapsed time 55.06 sec
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 1.67E+00. Sample per second: 50101
# SLIM_BPR_Recommender: Epoch 223 of 1500. Elapsed time 55.30 sec
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 1.66E+00. Sample per second: 38472
# SLIM_BPR_Recommender: Epoch 224 of 1500. Elapsed time 55.55 sec
# Processed 41629 (100.0%) in 0.35 sec. BPR loss is 1.79E+00. Sample per second: 118751
# SLIM_BPR_Recommender: Epoch 225 of 1500. Elapsed time 55.82 sec
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 1.78E+00. Sample per second: 71162
# SLIM_BPR_Recommender: Epoch 226 of 1500. Elapsed time 56.05 sec
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 1.82E+00. Sample per second: 50976
# SLIM_BPR_Recommender: Epoch 227 of 1500. Elapsed time 56.28 sec
# Processed 41629 (100.0%) in 1.05 sec. BPR loss is 1.78E+00. Sample per second: 39682
# SLIM_BPR_Recommender: Epoch 228 of 1500. Elapsed time 56.51 sec
# Processed 41629 (100.0%) in 0.28 sec. BPR loss is 1.90E+00. Sample per second: 148119
# SLIM_BPR_Recommender: Epoch 229 of 1500. Elapsed time 56.75 sec
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 1.80E+00. Sample per second: 81199
# SLIM_BPR_Recommender: Epoch 230 of 1500. Elapsed time 56.98 sec
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 1.78E+00. Sample per second: 56071
# SLIM_BPR_Recommender: Epoch 231 of 1500. Elapsed time 57.21 sec
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 1.79E+00. Sample per second: 42637
# SLIM_BPR_Recommender: Epoch 232 of 1500. Elapsed time 57.44 sec
# Processed 41629 (100.0%) in 1.21 sec. BPR loss is 1.82E+00. Sample per second: 34372
# SLIM_BPR_Recommender: Epoch 233 of 1500. Elapsed time 57.68 sec
# Processed 41629 (100.0%) in 0.45 sec. BPR loss is 1.79E+00. Sample per second: 93102
# SLIM_BPR_Recommender: Epoch 234 of 1500. Elapsed time 57.91 sec
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 1.82E+00. Sample per second: 60862
# SLIM_BPR_Recommender: Epoch 235 of 1500. Elapsed time 58.15 sec
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 1.89E+00. Sample per second: 45182
# SLIM_BPR_Recommender: Epoch 236 of 1500. Elapsed time 58.39 sec
# Processed 41629 (100.0%) in 1.15 sec. BPR loss is 1.83E+00. Sample per second: 36051
# SLIM_BPR_Recommender: Epoch 237 of 1500. Elapsed time 58.62 sec
# Processed 41629 (100.0%) in 0.39 sec. BPR loss is 1.79E+00. Sample per second: 106899
# SLIM_BPR_Recommender: Epoch 238 of 1500. Elapsed time 58.85 sec
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 1.93E+00. Sample per second: 66790
# SLIM_BPR_Recommender: Epoch 239 of 1500. Elapsed time 59.09 sec
# Processed 41629 (100.0%) in 0.86 sec. BPR loss is 1.81E+00. Sample per second: 48613
# SLIM_BPR_Recommender: Epoch 240 of 1500. Elapsed time 59.32 sec
# Processed 41629 (100.0%) in 1.09 sec. BPR loss is 1.92E+00. Sample per second: 38097
# SLIM_BPR_Recommender: Epoch 241 of 1500. Elapsed time 59.56 sec
# Processed 41629 (100.0%) in 0.33 sec. BPR loss is 2.00E+00. Sample per second: 126670
# SLIM_BPR_Recommender: Epoch 242 of 1500. Elapsed time 59.79 sec
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 1.86E+00. Sample per second: 73513
# SLIM_BPR_Recommender: Epoch 243 of 1500. Elapsed time 1.00 min
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 2.03E+00. Sample per second: 51545
# SLIM_BPR_Recommender: Epoch 244 of 1500. Elapsed time 1.00 min
# Processed 41629 (100.0%) in 1.04 sec. BPR loss is 1.95E+00. Sample per second: 39976
# SLIM_BPR_Recommender: Epoch 245 of 1500. Elapsed time 1.01 min
# Processed 41629 (100.0%) in 0.28 sec. BPR loss is 1.92E+00. Sample per second: 151354
# SLIM_BPR_Recommender: Epoch 246 of 1500. Elapsed time 1.01 min
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 1.91E+00. Sample per second: 81938
# SLIM_BPR_Recommender: Epoch 247 of 1500. Elapsed time 1.02 min
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 1.95E+00. Sample per second: 56276
# SLIM_BPR_Recommender: Epoch 248 of 1500. Elapsed time 1.02 min
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 2.09E+00. Sample per second: 42773
# SLIM_BPR_Recommender: Epoch 249 of 1500. Elapsed time 1.02 min
# Processed 41629 (100.0%) in 1.20 sec. BPR loss is 2.04E+00. Sample per second: 34553
# SLIM_BPR_Recommender: Epoch 250 of 1500. Elapsed time 1.03 min
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 1.88E+00. Sample per second: 95733
# SLIM_BPR_Recommender: Epoch 251 of 1500. Elapsed time 1.03 min
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 1.96E+00. Sample per second: 61896
# SLIM_BPR_Recommender: Epoch 252 of 1500. Elapsed time 1.04 min
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 1.97E+00. Sample per second: 45786
# SLIM_BPR_Recommender: Epoch 253 of 1500. Elapsed time 1.04 min
# Processed 41629 (100.0%) in 1.15 sec. BPR loss is 2.06E+00. Sample per second: 36181
# SLIM_BPR_Recommender: Epoch 254 of 1500. Elapsed time 1.04 min
# Processed 41629 (100.0%) in 0.39 sec. BPR loss is 2.17E+00. Sample per second: 107687
# SLIM_BPR_Recommender: Epoch 255 of 1500. Elapsed time 1.05 min
# Processed 41629 (100.0%) in 0.62 sec. BPR loss is 2.12E+00. Sample per second: 67125
# SLIM_BPR_Recommender: Epoch 256 of 1500. Elapsed time 1.05 min
# Processed 41629 (100.0%) in 0.86 sec. BPR loss is 2.13E+00. Sample per second: 48355
# SLIM_BPR_Recommender: Epoch 257 of 1500. Elapsed time 1.06 min
# Processed 41629 (100.0%) in 1.13 sec. BPR loss is 2.02E+00. Sample per second: 36898
# SLIM_BPR_Recommender: Epoch 258 of 1500. Elapsed time 1.06 min
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 2.13E+00. Sample per second: 114707
# SLIM_BPR_Recommender: Epoch 259 of 1500. Elapsed time 1.06 min
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 2.15E+00. Sample per second: 69313
# SLIM_BPR_Recommender: Epoch 260 of 1500. Elapsed time 1.07 min
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 2.11E+00. Sample per second: 49423
# SLIM_BPR_Recommender: Epoch 261 of 1500. Elapsed time 1.07 min
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 2.13E+00. Sample per second: 38547
# SLIM_BPR_Recommender: Epoch 262 of 1500. Elapsed time 1.08 min
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 2.06E+00. Sample per second: 130244
# SLIM_BPR_Recommender: Epoch 263 of 1500. Elapsed time 1.08 min
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 2.09E+00. Sample per second: 74829
# SLIM_BPR_Recommender: Epoch 264 of 1500. Elapsed time 1.08 min
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 2.12E+00. Sample per second: 52280
# SLIM_BPR_Recommender: Epoch 265 of 1500. Elapsed time 1.09 min
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 2.11E+00. Sample per second: 40315
# SLIM_BPR_Recommender: Epoch 266 of 1500. Elapsed time 1.09 min
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 2.28E+00. Sample per second: 154587
# SLIM_BPR_Recommender: Epoch 267 of 1500. Elapsed time 1.10 min
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 2.21E+00. Sample per second: 82215
# SLIM_BPR_Recommender: Epoch 268 of 1500. Elapsed time 1.10 min
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 2.32E+00. Sample per second: 55962
# SLIM_BPR_Recommender: Epoch 269 of 1500. Elapsed time 1.10 min
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 2.27E+00. Sample per second: 42503
# SLIM_BPR_Recommender: Epoch 270 of 1500. Elapsed time 1.11 min
# Processed 41629 (100.0%) in 1.22 sec. BPR loss is 2.38E+00. Sample per second: 34172
# SLIM_BPR_Recommender: Epoch 271 of 1500. Elapsed time 1.11 min
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 2.23E+00. Sample per second: 91179
# SLIM_BPR_Recommender: Epoch 272 of 1500. Elapsed time 1.12 min
# Processed 41629 (100.0%) in 0.69 sec. BPR loss is 2.41E+00. Sample per second: 60045
# SLIM_BPR_Recommender: Epoch 273 of 1500. Elapsed time 1.12 min
# Processed 41629 (100.0%) in 0.93 sec. BPR loss is 2.37E+00. Sample per second: 44652
# SLIM_BPR_Recommender: Epoch 274 of 1500. Elapsed time 1.12 min
# Processed 41629 (100.0%) in 1.17 sec. BPR loss is 2.30E+00. Sample per second: 35559
# SLIM_BPR_Recommender: Epoch 275 of 1500. Elapsed time 1.13 min
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 2.34E+00. Sample per second: 102104
# SLIM_BPR_Recommender: Epoch 276 of 1500. Elapsed time 1.13 min
# Processed 41629 (100.0%) in 0.65 sec. BPR loss is 2.32E+00. Sample per second: 64403
# SLIM_BPR_Recommender: Epoch 277 of 1500. Elapsed time 1.14 min
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 2.33E+00. Sample per second: 47001
# SLIM_BPR_Recommender: Epoch 278 of 1500. Elapsed time 1.14 min
# Processed 41629 (100.0%) in 1.12 sec. BPR loss is 2.30E+00. Sample per second: 37024
# SLIM_BPR_Recommender: Epoch 279 of 1500. Elapsed time 1.14 min
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 2.33E+00. Sample per second: 114490
# SLIM_BPR_Recommender: Epoch 280 of 1500. Elapsed time 1.15 min
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 2.53E+00. Sample per second: 68703
# SLIM_BPR_Recommender: Epoch 281 of 1500. Elapsed time 1.15 min
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 2.33E+00. Sample per second: 49328
# SLIM_BPR_Recommender: Epoch 282 of 1500. Elapsed time 1.16 min
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 2.39E+00. Sample per second: 38524
# SLIM_BPR_Recommender: Epoch 283 of 1500. Elapsed time 1.16 min
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 2.37E+00. Sample per second: 129946
# SLIM_BPR_Recommender: Epoch 284 of 1500. Elapsed time 1.16 min
# Processed 41629 (100.0%) in 0.56 sec. BPR loss is 2.49E+00. Sample per second: 74736
# SLIM_BPR_Recommender: Epoch 285 of 1500. Elapsed time 1.17 min
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 2.46E+00. Sample per second: 52382
# SLIM_BPR_Recommender: Epoch 286 of 1500. Elapsed time 1.17 min
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 2.40E+00. Sample per second: 40325
# SLIM_BPR_Recommender: Epoch 287 of 1500. Elapsed time 1.17 min
# Processed 41629 (100.0%) in 0.27 sec. BPR loss is 2.53E+00. Sample per second: 153088
# SLIM_BPR_Recommender: Epoch 288 of 1500. Elapsed time 1.18 min
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 2.46E+00. Sample per second: 82143
# SLIM_BPR_Recommender: Epoch 289 of 1500. Elapsed time 1.18 min
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 2.55E+00. Sample per second: 55890
# SLIM_BPR_Recommender: Epoch 290 of 1500. Elapsed time 1.19 min
# Processed 41629 (100.0%) in 1.01 sec. BPR loss is 2.46E+00. Sample per second: 41018
# SLIM_BPR_Recommender: Epoch 291 of 1500. Elapsed time 1.19 min
# Processed 41629 (100.0%) in 0.25 sec. BPR loss is 2.58E+00. Sample per second: 163525
# SLIM_BPR_Recommender: Epoch 292 of 1500. Elapsed time 1.20 min
# Processed 41629 (100.0%) in 0.49 sec. BPR loss is 2.66E+00. Sample per second: 84570
# SLIM_BPR_Recommender: Epoch 293 of 1500. Elapsed time 1.20 min
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 2.41E+00. Sample per second: 57107
# SLIM_BPR_Recommender: Epoch 294 of 1500. Elapsed time 1.20 min
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 2.52E+00. Sample per second: 42742
# SLIM_BPR_Recommender: Epoch 295 of 1500. Elapsed time 1.21 min
# Processed 41629 (100.0%) in 1.21 sec. BPR loss is 2.65E+00. Sample per second: 34396
# SLIM_BPR_Recommender: Epoch 296 of 1500. Elapsed time 1.21 min
# Processed 41629 (100.0%) in 0.45 sec. BPR loss is 2.56E+00. Sample per second: 93265
# SLIM_BPR_Recommender: Epoch 297 of 1500. Elapsed time 1.22 min
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 2.37E+00. Sample per second: 60938
# SLIM_BPR_Recommender: Epoch 298 of 1500. Elapsed time 1.22 min
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 2.61E+00. Sample per second: 45308
# SLIM_BPR_Recommender: Epoch 299 of 1500. Elapsed time 1.22 min
# Processed 41629 (100.0%) in 1.15 sec. BPR loss is 2.58E+00. Sample per second: 36014
# SLIM_BPR_Recommender: Epoch 300 of 1500. Elapsed time 1.23 min
# Processed 41629 (100.0%) in 0.39 sec. BPR loss is 2.64E+00. Sample per second: 105568
# SLIM_BPR_Recommender: Epoch 301 of 1500. Elapsed time 1.23 min
# Processed 41629 (100.0%) in 0.64 sec. BPR loss is 2.55E+00. Sample per second: 65226
# SLIM_BPR_Recommender: Epoch 302 of 1500. Elapsed time 1.24 min
# Processed 41629 (100.0%) in 0.88 sec. BPR loss is 2.67E+00. Sample per second: 47490
# SLIM_BPR_Recommender: Epoch 303 of 1500. Elapsed time 1.24 min
# Processed 41629 (100.0%) in 1.11 sec. BPR loss is 2.77E+00. Sample per second: 37450
# SLIM_BPR_Recommender: Epoch 304 of 1500. Elapsed time 1.24 min
# Processed 41629 (100.0%) in 0.35 sec. BPR loss is 2.55E+00. Sample per second: 118855
# SLIM_BPR_Recommender: Epoch 305 of 1500. Elapsed time 1.25 min
# Processed 41629 (100.0%) in 0.59 sec. BPR loss is 2.62E+00. Sample per second: 70767
# SLIM_BPR_Recommender: Epoch 306 of 1500. Elapsed time 1.25 min
# Processed 41629 (100.0%) in 0.83 sec. BPR loss is 2.65E+00. Sample per second: 50325
# SLIM_BPR_Recommender: Epoch 307 of 1500. Elapsed time 1.25 min
# Processed 41629 (100.0%) in 1.06 sec. BPR loss is 2.80E+00. Sample per second: 39117
# SLIM_BPR_Recommender: Epoch 308 of 1500. Elapsed time 1.26 min
# Processed 41629 (100.0%) in 0.30 sec. BPR loss is 2.73E+00. Sample per second: 136549
# SLIM_BPR_Recommender: Epoch 309 of 1500. Elapsed time 1.26 min
# Processed 41629 (100.0%) in 0.54 sec. BPR loss is 2.78E+00. Sample per second: 76570
# SLIM_BPR_Recommender: Epoch 310 of 1500. Elapsed time 1.27 min
# Processed 41629 (100.0%) in 0.78 sec. BPR loss is 2.79E+00. Sample per second: 53139
# SLIM_BPR_Recommender: Epoch 311 of 1500. Elapsed time 1.27 min
# Processed 41629 (100.0%) in 1.03 sec. BPR loss is 2.90E+00. Sample per second: 40598
# SLIM_BPR_Recommender: Epoch 312 of 1500. Elapsed time 1.27 min
# Processed 41629 (100.0%) in 0.26 sec. BPR loss is 2.84E+00. Sample per second: 157635
# SLIM_BPR_Recommender: Epoch 313 of 1500. Elapsed time 1.28 min
# Processed 41629 (100.0%) in 0.50 sec. BPR loss is 2.78E+00. Sample per second: 83244
# SLIM_BPR_Recommender: Epoch 314 of 1500. Elapsed time 1.28 min
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 2.69E+00. Sample per second: 56551
# SLIM_BPR_Recommender: Epoch 315 of 1500. Elapsed time 1.29 min
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 2.81E+00. Sample per second: 42822
# SLIM_BPR_Recommender: Epoch 316 of 1500. Elapsed time 1.29 min
# Processed 41629 (100.0%) in 1.21 sec. BPR loss is 2.88E+00. Sample per second: 34373
# SLIM_BPR_Recommender: Epoch 317 of 1500. Elapsed time 1.29 min
# Processed 41629 (100.0%) in 0.45 sec. BPR loss is 2.80E+00. Sample per second: 93182
# SLIM_BPR_Recommender: Epoch 318 of 1500. Elapsed time 1.30 min
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 2.91E+00. Sample per second: 60903
# SLIM_BPR_Recommender: Epoch 319 of 1500. Elapsed time 1.30 min
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 2.78E+00. Sample per second: 45223
# ...
# SLIM_BPR_Recommender: Epoch 1407 of 1500. Elapsed time 2.24 min
# Processed 41629 (100.0%) in 0.28 sec. BPR loss is 2.22E+02. Sample per second: 147956
# SLIM_BPR_Recommender: Epoch 1408 of 1500. Elapsed time 2.24 min
# Processed 41629 (100.0%) in 0.37 sec. BPR loss is 2.24E+02. Sample per second: 111809
# SLIM_BPR_Recommender: Epoch 1409 of 1500. Elapsed time 2.24 min
# Processed 41629 (100.0%) in 0.47 sec. BPR loss is 2.31E+02. Sample per second: 88964
# SLIM_BPR_Recommender: Epoch 1410 of 1500. Elapsed time 2.25 min
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 2.27E+02. Sample per second: 73170
# SLIM_BPR_Recommender: Epoch 1411 of 1500. Elapsed time 2.25 min
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 2.27E+02. Sample per second: 59138
# SLIM_BPR_Recommender: Epoch 1412 of 1500. Elapsed time 2.25 min
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 2.35E+02. Sample per second: 51633
# SLIM_BPR_Recommender: Epoch 1413 of 1500. Elapsed time 2.25 min
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 2.16E+02. Sample per second: 45887
# SLIM_BPR_Recommender: Epoch 1414 of 1500. Elapsed time 2.25 min
# Processed 41629 (100.0%) in 1.01 sec. BPR loss is 2.40E+02. Sample per second: 41400
# SLIM_BPR_Recommender: Epoch 1415 of 1500. Elapsed time 2.26 min
# Processed 41629 (100.0%) in 0.10 sec. BPR loss is 2.32E+02. Sample per second: 407229
# SLIM_BPR_Recommender: Epoch 1416 of 1500. Elapsed time 2.26 min
# Processed 41629 (100.0%) in 0.20 sec. BPR loss is 2.38E+02. Sample per second: 203495
# SLIM_BPR_Recommender: Epoch 1417 of 1500. Elapsed time 2.26 min
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 2.40E+02. Sample per second: 132335
# SLIM_BPR_Recommender: Epoch 1418 of 1500. Elapsed time 2.26 min
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 2.33E+02. Sample per second: 98507
# SLIM_BPR_Recommender: Epoch 1419 of 1500. Elapsed time 2.26 min
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 2.42E+02. Sample per second: 78214
# SLIM_BPR_Recommender: Epoch 1420 of 1500. Elapsed time 2.26 min
# Processed 41629 (100.0%) in 0.63 sec. BPR loss is 2.25E+02. Sample per second: 65843
# SLIM_BPR_Recommender: Epoch 1421 of 1500. Elapsed time 2.27 min
# Processed 41629 (100.0%) in 0.73 sec. BPR loss is 2.29E+02. Sample per second: 57163
# SLIM_BPR_Recommender: Epoch 1422 of 1500. Elapsed time 2.27 min
# Processed 41629 (100.0%) in 0.82 sec. BPR loss is 2.16E+02. Sample per second: 50642
# SLIM_BPR_Recommender: Epoch 1423 of 1500. Elapsed time 2.27 min
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 2.32E+02. Sample per second: 45501
# SLIM_BPR_Recommender: Epoch 1424 of 1500. Elapsed time 2.27 min
# Processed 41629 (100.0%) in 1.01 sec. BPR loss is 2.28E+02. Sample per second: 41275
# SLIM_BPR_Recommender: Epoch 1425 of 1500. Elapsed time 2.27 min
# Processed 41629 (100.0%) in 0.13 sec. BPR loss is 2.24E+02. Sample per second: 312841
# SLIM_BPR_Recommender: Epoch 1426 of 1500. Elapsed time 2.27 min
# Processed 41629 (100.0%) in 0.24 sec. BPR loss is 2.25E+02. Sample per second: 171949
# SLIM_BPR_Recommender: Epoch 1427 of 1500. Elapsed time 2.28 min
# Processed 41629 (100.0%) in 0.34 sec. BPR loss is 2.40E+02. Sample per second: 123431
# SLIM_BPR_Recommender: Epoch 1428 of 1500. Elapsed time 2.28 min
# Processed 41629 (100.0%) in 0.43 sec. BPR loss is 2.23E+02. Sample per second: 96518
# SLIM_BPR_Recommender: Epoch 1429 of 1500. Elapsed time 2.28 min
# Processed 41629 (100.0%) in 0.53 sec. BPR loss is 2.30E+02. Sample per second: 78739
# SLIM_BPR_Recommender: Epoch 1430 of 1500. Elapsed time 2.28 min
# Processed 41629 (100.0%) in 0.64 sec. BPR loss is 2.35E+02. Sample per second: 65108
# SLIM_BPR_Recommender: Epoch 1431 of 1500. Elapsed time 2.28 min
# Processed 41629 (100.0%) in 0.76 sec. BPR loss is 2.33E+02. Sample per second: 54962
# SLIM_BPR_Recommender: Epoch 1432 of 1500. Elapsed time 2.28 min
# Processed 41629 (100.0%) in 0.86 sec. BPR loss is 2.26E+02. Sample per second: 48608
# SLIM_BPR_Recommender: Epoch 1433 of 1500. Elapsed time 2.29 min
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 2.41E+02. Sample per second: 42605
# SLIM_BPR_Recommender: Epoch 1434 of 1500. Elapsed time 2.29 min
# Processed 41629 (100.0%) in 1.09 sec. BPR loss is 2.30E+02. Sample per second: 38265
# SLIM_BPR_Recommender: Epoch 1435 of 1500. Elapsed time 2.29 min
# Processed 41629 (100.0%) in 0.19 sec. BPR loss is 2.20E+02. Sample per second: 216170
# SLIM_BPR_Recommender: Epoch 1436 of 1500. Elapsed time 2.29 min
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 2.31E+02. Sample per second: 129063
# SLIM_BPR_Recommender: Epoch 1437 of 1500. Elapsed time 2.29 min
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 2.31E+02. Sample per second: 99938
# SLIM_BPR_Recommender: Epoch 1438 of 1500. Elapsed time 2.30 min
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 2.37E+02. Sample per second: 81241
# SLIM_BPR_Recommender: Epoch 1439 of 1500. Elapsed time 2.30 min
# Processed 41629 (100.0%) in 0.61 sec. BPR loss is 2.33E+02. Sample per second: 68761
# SLIM_BPR_Recommender: Epoch 1440 of 1500. Elapsed time 2.30 min
# Processed 41629 (100.0%) in 0.71 sec. BPR loss is 2.37E+02. Sample per second: 58679
# SLIM_BPR_Recommender: Epoch 1441 of 1500. Elapsed time 2.30 min
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 2.45E+02. Sample per second: 51242
# SLIM_BPR_Recommender: Epoch 1442 of 1500. Elapsed time 2.30 min
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 2.30E+02. Sample per second: 45825
# SLIM_BPR_Recommender: Epoch 1443 of 1500. Elapsed time 2.30 min
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 2.33E+02. Sample per second: 40810
# SLIM_BPR_Recommender: Epoch 1444 of 1500. Elapsed time 2.31 min
# Processed 41629 (100.0%) in 0.12 sec. BPR loss is 2.30E+02. Sample per second: 343749
# SLIM_BPR_Recommender: Epoch 1445 of 1500. Elapsed time 2.31 min
# Processed 41629 (100.0%) in 0.23 sec. BPR loss is 2.19E+02. Sample per second: 184349
# SLIM_BPR_Recommender: Epoch 1446 of 1500. Elapsed time 2.31 min
# Processed 41629 (100.0%) in 0.36 sec. BPR loss is 2.19E+02. Sample per second: 116777
# SLIM_BPR_Recommender: Epoch 1447 of 1500. Elapsed time 2.31 min
# Processed 41629 (100.0%) in 0.46 sec. BPR loss is 2.44E+02. Sample per second: 89987
# SLIM_BPR_Recommender: Epoch 1448 of 1500. Elapsed time 2.31 min
# Processed 41629 (100.0%) in 0.57 sec. BPR loss is 2.43E+02. Sample per second: 73600
# SLIM_BPR_Recommender: Epoch 1449 of 1500. Elapsed time 2.31 min
# Processed 41629 (100.0%) in 0.67 sec. BPR loss is 2.29E+02. Sample per second: 62106
# SLIM_BPR_Recommender: Epoch 1450 of 1500. Elapsed time 2.32 min
# Processed 41629 (100.0%) in 0.81 sec. BPR loss is 2.29E+02. Sample per second: 51630
# SLIM_BPR_Recommender: Epoch 1451 of 1500. Elapsed time 2.32 min
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 2.37E+02. Sample per second: 45932
# SLIM_BPR_Recommender: Epoch 1452 of 1500. Elapsed time 2.32 min
# Processed 41629 (100.0%) in 1.01 sec. BPR loss is 2.33E+02. Sample per second: 41222
# SLIM_BPR_Recommender: Epoch 1453 of 1500. Elapsed time 2.32 min
# Processed 41629 (100.0%) in 0.12 sec. BPR loss is 2.36E+02. Sample per second: 359264
# SLIM_BPR_Recommender: Epoch 1454 of 1500. Elapsed time 2.32 min
# Processed 41629 (100.0%) in 0.22 sec. BPR loss is 2.41E+02. Sample per second: 187045
# SLIM_BPR_Recommender: Epoch 1455 of 1500. Elapsed time 2.33 min
# Processed 41629 (100.0%) in 0.32 sec. BPR loss is 2.31E+02. Sample per second: 129057
# SLIM_BPR_Recommender: Epoch 1456 of 1500. Elapsed time 2.33 min
# Processed 41629 (100.0%) in 0.42 sec. BPR loss is 2.33E+02. Sample per second: 98756
# SLIM_BPR_Recommender: Epoch 1457 of 1500. Elapsed time 2.33 min
# Processed 41629 (100.0%) in 0.52 sec. BPR loss is 2.45E+02. Sample per second: 79420
# SLIM_BPR_Recommender: Epoch 1458 of 1500. Elapsed time 2.33 min
# Processed 41629 (100.0%) in 0.63 sec. BPR loss is 2.22E+02. Sample per second: 66271
# SLIM_BPR_Recommender: Epoch 1459 of 1500. Elapsed time 2.33 min
# Processed 41629 (100.0%) in 0.74 sec. BPR loss is 2.39E+02. Sample per second: 56549
# SLIM_BPR_Recommender: Epoch 1460 of 1500. Elapsed time 2.33 min
# Processed 41629 (100.0%) in 0.84 sec. BPR loss is 2.26E+02. Sample per second: 49844
# SLIM_BPR_Recommender: Epoch 1461 of 1500. Elapsed time 2.34 min
# Processed 41629 (100.0%) in 0.97 sec. BPR loss is 2.41E+02. Sample per second: 43133
# SLIM_BPR_Recommender: Epoch 1462 of 1500. Elapsed time 2.34 min
# Processed 41629 (100.0%) in 1.07 sec. BPR loss is 2.29E+02. Sample per second: 38830
# SLIM_BPR_Recommender: Epoch 1463 of 1500. Elapsed time 2.34 min
# Processed 41629 (100.0%) in 0.18 sec. BPR loss is 2.29E+02. Sample per second: 232809
# SLIM_BPR_Recommender: Epoch 1464 of 1500. Elapsed time 2.34 min
# Processed 41629 (100.0%) in 0.28 sec. BPR loss is 2.36E+02. Sample per second: 149308
# SLIM_BPR_Recommender: Epoch 1465 of 1500. Elapsed time 2.34 min
# Processed 41629 (100.0%) in 0.38 sec. BPR loss is 2.31E+02. Sample per second: 110477
# SLIM_BPR_Recommender: Epoch 1466 of 1500. Elapsed time 2.34 min
# Processed 41629 (100.0%) in 0.48 sec. BPR loss is 2.37E+02. Sample per second: 87016
# SLIM_BPR_Recommender: Epoch 1467 of 1500. Elapsed time 2.35 min
# Processed 41629 (100.0%) in 0.58 sec. BPR loss is 2.33E+02. Sample per second: 72097
# SLIM_BPR_Recommender: Epoch 1468 of 1500. Elapsed time 2.35 min
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 2.37E+02. Sample per second: 61473
# SLIM_BPR_Recommender: Epoch 1469 of 1500. Elapsed time 2.35 min
# Processed 41629 (100.0%) in 0.77 sec. BPR loss is 2.40E+02. Sample per second: 53701
# SLIM_BPR_Recommender: Epoch 1470 of 1500. Elapsed time 2.35 min
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 2.35E+02. Sample per second: 46869
# SLIM_BPR_Recommender: Epoch 1471 of 1500. Elapsed time 2.35 min
# Processed 41629 (100.0%) in 1.01 sec. BPR loss is 2.48E+02. Sample per second: 41141
# SLIM_BPR_Recommender: Epoch 1472 of 1500. Elapsed time 2.36 min
# Processed 41629 (100.0%) in 0.12 sec. BPR loss is 2.41E+02. Sample per second: 338757
# SLIM_BPR_Recommender: Epoch 1473 of 1500. Elapsed time 2.36 min
# Processed 41629 (100.0%) in 0.23 sec. BPR loss is 2.38E+02. Sample per second: 177476
# SLIM_BPR_Recommender: Epoch 1474 of 1500. Elapsed time 2.36 min
# Processed 41629 (100.0%) in 0.35 sec. BPR loss is 2.35E+02. Sample per second: 120472
# SLIM_BPR_Recommender: Epoch 1475 of 1500. Elapsed time 2.36 min
# Processed 41629 (100.0%) in 0.45 sec. BPR loss is 2.39E+02. Sample per second: 93021
# SLIM_BPR_Recommender: Epoch 1476 of 1500. Elapsed time 2.36 min
# Processed 41629 (100.0%) in 0.59 sec. BPR loss is 2.42E+02. Sample per second: 71017
# SLIM_BPR_Recommender: Epoch 1477 of 1500. Elapsed time 2.37 min
# Processed 41629 (100.0%) in 0.68 sec. BPR loss is 2.37E+02. Sample per second: 61020
# SLIM_BPR_Recommender: Epoch 1478 of 1500. Elapsed time 2.37 min
# Processed 41629 (100.0%) in 0.79 sec. BPR loss is 2.42E+02. Sample per second: 52816
# SLIM_BPR_Recommender: Epoch 1479 of 1500. Elapsed time 2.37 min
# Processed 41629 (100.0%) in 0.89 sec. BPR loss is 2.39E+02. Sample per second: 46870
# SLIM_BPR_Recommender: Epoch 1480 of 1500. Elapsed time 2.37 min
# Processed 41629 (100.0%) in 0.98 sec. BPR loss is 2.40E+02. Sample per second: 42486
# SLIM_BPR_Recommender: Epoch 1481 of 1500. Elapsed time 2.37 min
# Processed 41629 (100.0%) in 1.08 sec. BPR loss is 2.39E+02. Sample per second: 38623
# SLIM_BPR_Recommender: Epoch 1482 of 1500. Elapsed time 2.37 min
# Processed 41629 (100.0%) in 0.18 sec. BPR loss is 2.36E+02. Sample per second: 233148
# SLIM_BPR_Recommender: Epoch 1483 of 1500. Elapsed time 2.37 min
# Processed 41629 (100.0%) in 0.30 sec. BPR loss is 2.44E+02. Sample per second: 138989
# SLIM_BPR_Recommender: Epoch 1484 of 1500. Elapsed time 2.38 min
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 2.46E+02. Sample per second: 101899
# SLIM_BPR_Recommender: Epoch 1485 of 1500. Elapsed time 2.38 min
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 2.45E+02. Sample per second: 82073
# SLIM_BPR_Recommender: Epoch 1486 of 1500. Elapsed time 2.38 min
# Processed 41629 (100.0%) in 0.61 sec. BPR loss is 2.37E+02. Sample per second: 68780
# SLIM_BPR_Recommender: Epoch 1487 of 1500. Elapsed time 2.38 min
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 2.32E+02. Sample per second: 59590
# SLIM_BPR_Recommender: Epoch 1488 of 1500. Elapsed time 2.38 min
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 2.51E+02. Sample per second: 51866
# SLIM_BPR_Recommender: Epoch 1489 of 1500. Elapsed time 2.39 min
# Processed 41629 (100.0%) in 0.92 sec. BPR loss is 2.49E+02. Sample per second: 45171
# SLIM_BPR_Recommender: Epoch 1490 of 1500. Elapsed time 2.39 min
# Processed 41629 (100.0%) in 1.02 sec. BPR loss is 2.36E+02. Sample per second: 40903
# SLIM_BPR_Recommender: Epoch 1491 of 1500. Elapsed time 2.39 min
# Processed 41629 (100.0%) in 0.11 sec. BPR loss is 2.39E+02. Sample per second: 372522
# SLIM_BPR_Recommender: Epoch 1492 of 1500. Elapsed time 2.39 min
# Processed 41629 (100.0%) in 0.21 sec. BPR loss is 2.40E+02. Sample per second: 197871
# SLIM_BPR_Recommender: Epoch 1493 of 1500. Elapsed time 2.39 min
# Processed 41629 (100.0%) in 0.31 sec. BPR loss is 2.38E+02. Sample per second: 132412
# SLIM_BPR_Recommender: Epoch 1494 of 1500. Elapsed time 2.39 min
# Processed 41629 (100.0%) in 0.41 sec. BPR loss is 2.33E+02. Sample per second: 101016
# SLIM_BPR_Recommender: Epoch 1495 of 1500. Elapsed time 2.40 min
# Processed 41629 (100.0%) in 0.51 sec. BPR loss is 2.40E+02. Sample per second: 82144
# SLIM_BPR_Recommender: Epoch 1496 of 1500. Elapsed time 2.40 min
# Processed 41629 (100.0%) in 0.60 sec. BPR loss is 2.47E+02. Sample per second: 69176
# SLIM_BPR_Recommender: Epoch 1497 of 1500. Elapsed time 2.40 min
# Processed 41629 (100.0%) in 0.70 sec. BPR loss is 2.32E+02. Sample per second: 59492
# SLIM_BPR_Recommender: Epoch 1498 of 1500. Elapsed time 2.40 min
# Processed 41629 (100.0%) in 0.80 sec. BPR loss is 2.38E+02. Sample per second: 51747
# SLIM_BPR_Recommender: Epoch 1499 of 1500. Elapsed time 2.40 min
# Processed 41629 (100.0%) in 0.91 sec. BPR loss is 2.36E+02. Sample per second: 45825
# SLIM_BPR_Recommender: Epoch 1500 of 1500. Elapsed time 2.40 min
# SLIM_BPR_Recommender: Terminating at epoch 1500. Elapsed time 3.57 min
# Deallocating Cython objects
# EvaluatorHoldout: Processed 41629 (100.0%) in 51.99 sec. Users per second: 801
# SearchBayesianSkopt: Config 2 Exception. Config: {'topK': 1191, 'epochs': 1500, 'symmetric': False, 'sgd_mode': 'adam', 'lambda_i': 0.002197173369041251, 'lambda_j': 2.672880303082952e-05, 'learning_rate': 0.0011704837541929795} - Exception: Traceback (most recent call last):
#   File "d:\Developing\RecSys_PoliMi_challenge_2020\HyperparameterTuning\SearchAbstractClass.py", line 604, in _objective_function
#     result_df, recommender_instance = self._evaluate_on_validation(
#   File "d:\Developing\RecSys_PoliMi_challenge_2020\HyperparameterTuning\SearchAbstractClass.py", line 395, in _evaluate_on_validation
#     self.model_counter: recommender_instance.get_validation_summary_table()
#   File "d:\Developing\RecSys_PoliMi_challenge_2020\Recommenders\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table
#     return self._earlystopping_validation_summary_df.copy()
# AttributeError: 'NoneType' object has no attribute 'copy'
#
#
# Deallocating Cython objects
# Traceback (most recent call last):
#   File "d:\Developing\RecSys_PoliMi_challenge_2020\HyperparameterTuning\SearchAbstractClass.py", line 604, in _objective_function
#     result_df, recommender_instance = self._evaluate_on_validation(
#   File "d:\Developing\RecSys_PoliMi_challenge_2020\HyperparameterTuning\SearchAbstractClass.py", line 395, in _evaluate_on_validation
#     self.model_counter: recommender_instance.get_validation_summary_table()
#   File "d:\Developing\RecSys_PoliMi_challenge_2020\Recommenders\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table
#     return self._earlystopping_validation_summary_df.copy()
# AttributeError: 'NoneType' object has no attribute 'copy'
# SearchBayesianSkopt: Search interrupted. No valid config was found during the initial random initialization

# %%
from Recommenders.DataIO import DataIO

data_loader = DataIO(folder_path=output_folder_path)
search_metadata = data_loader.load_data(
    recommender_class.RECOMMENDER_NAME + "_metadata.zip"
)

result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#    topK epochs symmetric sgd_mode  lambda_i  lambda_j learning_rate
# 0   166   1499      True     adam  0.000124  0.001693      0.000103
# 1  1324   1499     False  adagrad  0.000032  0.006309      0.016491
# 2  1191   1499     False     adam  0.002197  0.000027       0.00117
# 3   NaN    NaN       NaN      NaN       NaN       NaN           NaN
# 4   NaN    NaN       NaN      NaN       NaN       NaN           NaN
# 5   NaN    NaN       NaN      NaN       NaN       NaN           NaN
# 6   NaN    NaN       NaN      NaN       NaN       NaN           NaN
# 7   NaN    NaN       NaN      NaN       NaN       NaN           NaN
# 8   NaN    NaN       NaN      NaN       NaN       NaN           NaN
# 9   NaN    NaN       NaN      NaN       NaN       NaN           NaN

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters

# %%
exception_list = search_metadata["exception_list"]
exception_list
# Out:
# ['Traceback (most recent call last):\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 604, in _objective_function\n    result_df, recommender_instance = self._evaluate_on_validation(\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 395, in _evaluate_on_validation\n    self.model_counter: recommender_instance.get_validation_summary_table()\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\Recommenders\\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table\n    return self._earlystopping_validation_summary_df.copy()\nAttributeError: \'NoneType\' object has no attribute \'copy\'\n',
#  'Traceback (most recent call last):\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 604, in _objective_function\n    result_df, recommender_instance = self._evaluate_on_validation(\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 395, in _evaluate_on_validation\n    self.model_counter: recommender_instance.get_validation_summary_table()\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\Recommenders\\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table\n    return self._earlystopping_validation_summary_df.copy()\nAttributeError: \'NoneType\' object has no attribute \'copy\'\n',
#  'Traceback (most recent call last):\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 604, in _objective_function\n    result_df, recommender_instance = self._evaluate_on_validation(\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 395, in _evaluate_on_validation\n    self.model_counter: recommender_instance.get_validation_summary_table()\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\Recommenders\\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table\n    return self._earlystopping_validation_summary_df.copy()\nAttributeError: \'NoneType\' object has no attribute \'copy\'\n',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
recommender = recommender_class(URM_all)
recommender.fit(**best_hyperparameters)
recommender.save_model(
    folder_path=output_folder_path,
    file_name=recommender_class.RECOMMENDER_NAME
    + "_best_model_trained_on_everything.zip",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 recommender = recommender_class(URM_all)
# ----> 2 recommender.fit(**best_hyperparameters)
#       3 recommender.save_model(
#       4     folder_path=recommender_class,
#       5     file_name=recommender_class.RECOMMENDER_NAME
#       6     + "_best_model_trained_on_everything.zip",
#       7 )
#
# TypeError: fit() argument after ** must be a mapping, not NoneType

# %%
from utils.create_submission import create_submission

create_submission(recommender)
