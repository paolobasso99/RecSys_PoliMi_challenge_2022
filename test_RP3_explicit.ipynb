# %%
import os
import random

import numpy as np
import pandas as pd
import scipy.sparse as sps
import matplotlib.pyplot as plt
import seaborn as snb

# Random seed for reproducibility
SEED = 42
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)

# %%
from data_manager import DatasetLoader, DatasetSplitter, URMGenerator

dataset_loader = DatasetLoader()
dataset_splitter = DatasetSplitter(dataset_loader)
dataset_train, dataset_val = dataset_splitter.load_train_val()
URM_generator = URMGenerator(dataset_train, dataset_val)
URM_train, URM_val = URM_generator.generate_explicit_URM()
URM_all = URM_train + URM_val
# Out:
# Loading previusly generated splits...
# Generating explicit URM...

# %%
from evaluation.evaluator import EvaluatorHoldout

evaluator = EvaluatorHoldout(URM_val, cutoff_list=[10])

# %%
from Recommenders.GraphBased.RP3betaRecommender import (
    RP3betaRecommender,
)
from skopt.space import Real, Integer, Categorical
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

output_folder_path = "result_experiments/RP3betaRecommender_explicit/"
recommender_class = RP3betaRecommender
n_cases = 10
n_random_starts = int(n_cases * 0.3)
metric_to_optimize = "MAP"
cutoff_to_optimize = 10

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Define hyperparameters
hyperparameters_range_dictionary = {
    "topK": Integer(5, 1000),
    "alpha": Real(low=0, high=2, prior="uniform"),
    "beta": Real(low=0, high=2, prior="uniform"),
    "normalize_similarity": Categorical([True, False]),
}

hyperparameter_search = SearchBayesianSkopt(
    recommender_class,
    evaluator_validation=evaluator,
)

recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS=[
        URM_train,
    ],
    CONSTRUCTOR_KEYWORD_ARGS={},
    FIT_POSITIONAL_ARGS=[],
    FIT_KEYWORD_ARGS={},
    EARLYSTOPPING_KEYWORD_ARGS={},
)

# %%
hyperparameter_search.search(
    recommender_input_args,
    hyperparameter_search_space=hyperparameters_range_dictionary,
    n_cases=n_cases,
    n_random_starts=n_random_starts,
    save_model="best",
    output_folder_path=output_folder_path,  # Where to save the results
    output_file_name_root=recommender_class.RECOMMENDER_NAME,  # How to call the files
    metric_to_optimize=metric_to_optimize,
    cutoff_to_optimize=cutoff_to_optimize,
)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 584, 'alpha': 1.4875779670057994, 'beta': 1.4920670083680772, 'normalize_similarity': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 431.00 column/sec. Elapsed time 56.86 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.27 min. Users per second: 545
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 584, 'alpha': 1.4875779670057994, 'beta': 1.4920670083680772, 'normalize_similarity': True} - results: PRECISION: 0.0003243, PRECISION_RECALL_MIN_DEN: 0.0004766, RECALL: 0.0003927, MAP: 0.0000835, MAP_MIN_DEN: 0.0001189, MRR: 0.0006928, NDCG: 0.0003329, F1: 0.0003552, HIT_RATE: 0.0028586, ARHR_ALL_HITS: 0.0007592, NOVELTY: 0.0065139, AVERAGE_POPULARITY: 0.0026377, DIVERSITY_MEAN_INTER_LIST: 0.9962453, DIVERSITY_HERFINDAHL: 0.9996221, COVERAGE_ITEM: 0.4284082, COVERAGE_ITEM_HIT: 0.0044885, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.0028586, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.1354542, SHANNON_ENTROPY: 12.0843307, RATIO_DIVERSITY_HERFINDAHL: 0.9999522, RATIO_DIVERSITY_GINI: 0.2662707, RATIO_SHANNON_ENTROPY: 0.8955409, RATIO_AVERAGE_POPULARITY: 0.0521211, RATIO_NOVELTY: 0.3726872,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3betaRecommender_explicit/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3betaRecommender_explicit/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 183.0482
# Function value obtained: -0.0001
# Current minimum: -0.0001
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 85, 'alpha': 1.5791369392562644, 'beta': 0.2158632478732359, 'normalize_similarity': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1167.79 column/sec. Elapsed time 20.99 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 58.93 sec. Users per second: 706
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 85, 'alpha': 1.5791369392562644, 'beta': 0.2158632478732359, 'normalize_similarity': True} - results: PRECISION: 0.0425136, PRECISION_RECALL_MIN_DEN: 0.0680105, RECALL: 0.0642358, MAP: 0.0206027, MAP_MIN_DEN: 0.0327533, MRR: 0.1458006, NDCG: 0.0774634, F1: 0.0511646, HIT_RATE: 0.2967643, ARHR_ALL_HITS: 0.1724890, NOVELTY: 0.0047194, AVERAGE_POPULARITY: 0.1691630, DIVERSITY_MEAN_INTER_LIST: 0.9452274, DIVERSITY_HERFINDAHL: 0.9945205, COVERAGE_ITEM: 0.4659077, COVERAGE_ITEM_HIT: 0.0342351, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2967643, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0629060, SHANNON_ENTROPY: 9.7782314, RATIO_DIVERSITY_HERFINDAHL: 0.9948488, RATIO_DIVERSITY_GINI: 0.1236582, RATIO_SHANNON_ENTROPY: 0.7246414, RATIO_AVERAGE_POPULARITY: 3.3426920, RATIO_NOVELTY: 0.2700124,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3betaRecommender_explicit/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3betaRecommender_explicit/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 89.3880
# Function value obtained: -0.0206
# Current minimum: -0.0206
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 391, 'alpha': 1.3268021484280272, 'beta': 1.0643389035059951, 'normalize_similarity': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 595.47 column/sec. Elapsed time 41.16 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.34 min. Users per second: 519
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 391, 'alpha': 1.3268021484280272, 'beta': 1.0643389035059951, 'normalize_similarity': True} - results: PRECISION: 0.0051503, PRECISION_RECALL_MIN_DEN: 0.0070884, RECALL: 0.0063384, MAP: 0.0021462, MAP_MIN_DEN: 0.0028721, MRR: 0.0152008, NDCG: 0.0079302, F1: 0.0056829, HIT_RATE: 0.0382426, ARHR_ALL_HITS: 0.0179316, NOVELTY: 0.0064371, AVERAGE_POPULARITY: 0.0036812, DIVERSITY_MEAN_INTER_LIST: 0.9971154, DIVERSITY_HERFINDAHL: 0.9997091, COVERAGE_ITEM: 0.5233199, COVERAGE_ITEM_HIT: 0.0232587, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.0382426, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.1730455, SHANNON_ENTROPY: 12.4411347, RATIO_DIVERSITY_HERFINDAHL: 1.0000392, RATIO_DIVERSITY_GINI: 0.3401662, RATIO_SHANNON_ENTROPY: 0.9219828, RATIO_AVERAGE_POPULARITY: 0.0727407, RATIO_NOVELTY: 0.3682896,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 144.6451
# Function value obtained: -0.0021
# Current minimum: -0.0206
# Iteration No: 4 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 96, 'alpha': 0.8233335004502789, 'beta': 0.0, 'normalize_similarity': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 940.87 column/sec. Elapsed time 26.05 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.02 min. Users per second: 681
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 96, 'alpha': 0.8233335004502789, 'beta': 0.0, 'normalize_similarity': False} - results: PRECISION: 0.0431358, PRECISION_RECALL_MIN_DEN: 0.0708443, RECALL: 0.0670408, MAP: 0.0203951, MAP_MIN_DEN: 0.0332274, MRR: 0.1458205, NDCG: 0.0756160, F1: 0.0524950, HIT_RATE: 0.3058445, ARHR_ALL_HITS: 0.1715283, NOVELTY: 0.0041774, AVERAGE_POPULARITY: 0.2456477, DIVERSITY_MEAN_INTER_LIST: 0.8832599, DIVERSITY_HERFINDAHL: 0.9883239, COVERAGE_ITEM: 0.4362835, COVERAGE_ITEM_HIT: 0.0359489, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3058445, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0278664, SHANNON_ENTROPY: 8.2162705, RATIO_DIVERSITY_HERFINDAHL: 0.9886502, RATIO_DIVERSITY_GINI: 0.0547787, RATIO_SHANNON_ENTROPY: 0.6088882, RATIO_AVERAGE_POPULARITY: 4.8540450, RATIO_NOVELTY: 0.2390038,
#
# Iteration No: 4 ended. Search finished for the next optimal point.
# Time taken: 93.2139
# Function value obtained: -0.0204
# Current minimum: -0.0206
# Iteration No: 5 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1000, 'alpha': 0.21076781864710692, 'beta': 0.6813860054313287, 'normalize_similarity': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 267.82 column/sec. Elapsed time 1.53 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 2.05 min. Users per second: 338
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 1000, 'alpha': 0.21076781864710692, 'beta': 0.6813860054313287, 'normalize_similarity': False} - results: PRECISION: 0.0405895, PRECISION_RECALL_MIN_DEN: 0.0661026, RECALL: 0.0624574, MAP: 0.0189056, MAP_MIN_DEN: 0.0304672, MRR: 0.1352189, NDCG: 0.0711164, F1: 0.0492031, HIT_RATE: 0.2891013, ARHR_ALL_HITS: 0.1589806, NOVELTY: 0.0044644, AVERAGE_POPULARITY: 0.1660058, DIVERSITY_MEAN_INTER_LIST: 0.9355695, DIVERSITY_HERFINDAHL: 0.9935547, COVERAGE_ITEM: 0.5533521, COVERAGE_ITEM_HIT: 0.0501897, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2891013, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0440347, SHANNON_ENTROPY: 9.1674294, RATIO_DIVERSITY_HERFINDAHL: 0.9938827, RATIO_DIVERSITY_GINI: 0.0865618, RATIO_SHANNON_ENTROPY: 0.6793763, RATIO_AVERAGE_POPULARITY: 3.2803053, RATIO_NOVELTY: 0.2554257,
#
# Iteration No: 5 ended. Search finished for the next optimal point.
# Time taken: 276.3636
# Function value obtained: -0.0189
# Current minimum: -0.0206
# Iteration No: 6 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1000, 'alpha': 1.7251985545241149, 'beta': 0.09125106497092077, 'normalize_similarity': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 220.59 column/sec. Elapsed time 1.85 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.85 min. Users per second: 376
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 1000, 'alpha': 1.7251985545241149, 'beta': 0.09125106497092077, 'normalize_similarity': True} - results: PRECISION: 0.0391122, PRECISION_RECALL_MIN_DEN: 0.0626933, RECALL: 0.0591903, MAP: 0.0180612, MAP_MIN_DEN: 0.0285171, MRR: 0.1296284, NDCG: 0.0687971, F1: 0.0471008, HIT_RATE: 0.2793245, ARHR_ALL_HITS: 0.1523756, NOVELTY: 0.0045437, AVERAGE_POPULARITY: 0.2110985, DIVERSITY_MEAN_INTER_LIST: 0.9063518, DIVERSITY_HERFINDAHL: 0.9906330, COVERAGE_ITEM: 0.4413841, COVERAGE_ITEM_HIT: 0.0264822, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2793245, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0560341, SHANNON_ENTROPY: 9.2137304, RATIO_DIVERSITY_HERFINDAHL: 0.9909601, RATIO_DIVERSITY_GINI: 0.1101496, RATIO_SHANNON_ENTROPY: 0.6828076, RATIO_AVERAGE_POPULARITY: 4.1713469, RATIO_NOVELTY: 0.2599624,
#
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 281.8397
# Function value obtained: -0.0181
# Current minimum: -0.0206
# Iteration No: 7 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 772, 'alpha': 0.0, 'beta': 0.30722274674024097, 'normalize_similarity': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 352.10 column/sec. Elapsed time 1.16 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.26 min. Users per second: 551
# SearchBayesianSkopt: New best config found. Config 6: {'topK': 772, 'alpha': 0.0, 'beta': 0.30722274674024097, 'normalize_similarity': True} - results: PRECISION: 0.0443897, PRECISION_RECALL_MIN_DEN: 0.0735828, RECALL: 0.0696150, MAP: 0.0210394, MAP_MIN_DEN: 0.0346587, MRR: 0.1501827, NDCG: 0.0734375, F1: 0.0542116, HIT_RATE: 0.3145644, ARHR_ALL_HITS: 0.1767443, NOVELTY: 0.0041343, AVERAGE_POPULARITY: 0.2696096, DIVERSITY_MEAN_INTER_LIST: 0.8611330, DIVERSITY_HERFINDAHL: 0.9861112, COVERAGE_ITEM: 0.4679479, COVERAGE_ITEM_HIT: 0.0431713, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3145644, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0276356, SHANNON_ENTROPY: 8.1191632, RATIO_DIVERSITY_HERFINDAHL: 0.9864368, RATIO_DIVERSITY_GINI: 0.0543249, RATIO_SHANNON_ENTROPY: 0.6016918, RATIO_AVERAGE_POPULARITY: 5.3275371, RATIO_NOVELTY: 0.2365408,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3betaRecommender_explicit/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3betaRecommender_explicit/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 194.7329
# Function value obtained: -0.0210
# Current minimum: -0.0210
# Iteration No: 8 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'alpha': 2.0, 'beta': 0.3370186641721076, 'normalize_similarity': False}
# RP3betaRecommender: Similarity column 24507 (100.0%), 3206.53 column/sec. Elapsed time 7.64 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 30.28 sec. Users per second: 1375
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': 5, 'alpha': 2.0, 'beta': 0.3370186641721076, 'normalize_similarity': False} - results: PRECISION: 0.0002835, PRECISION_RECALL_MIN_DEN: 0.0005975, RECALL: 0.0005751, MAP: 0.0000584, MAP_MIN_DEN: 0.0001267, MRR: 0.0005837, NDCG: 0.0003919, F1: 0.0003797, HIT_RATE: 0.0028346, ARHR_ALL_HITS: 0.0005837, NOVELTY: 0.0062825, AVERAGE_POPULARITY: 0.0052486, DIVERSITY_MEAN_INTER_LIST: 0.9989467, DIVERSITY_HERFINDAHL: 0.9998923, COVERAGE_ITEM: 0.6010120, COVERAGE_ITEM_HIT: 0.0045701, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.0028346, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.3496748, SHANNON_ENTROPY: 13.4189745, RATIO_DIVERSITY_HERFINDAHL: 1.0002224, RATIO_DIVERSITY_GINI: 0.6873771, RATIO_SHANNON_ENTROPY: 0.9944482, RATIO_AVERAGE_POPULARITY: 0.1037125, RATIO_NOVELTY: 0.3594436,
#
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 39.2902
# Function value obtained: -0.0001
# Current minimum: -0.0210
# Iteration No: 9 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 146, 'alpha': 0.8745041827526168, 'beta': 0.0, 'normalize_similarity': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 1344.66 column/sec. Elapsed time 18.23 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.56 min. Users per second: 445
# SearchBayesianSkopt: New best config found. Config 8: {'topK': 146, 'alpha': 0.8745041827526168, 'beta': 0.0, 'normalize_similarity': True} - results: PRECISION: 0.0449566, PRECISION_RECALL_MIN_DEN: 0.0729691, RECALL: 0.0689364, MAP: 0.0216698, MAP_MIN_DEN: 0.0350184, MRR: 0.1526731, NDCG: 0.0796537, F1: 0.0544221, HIT_RATE: 0.3126186, ARHR_ALL_HITS: 0.1808285, NOVELTY: 0.0043219, AVERAGE_POPULARITY: 0.1940679, DIVERSITY_MEAN_INTER_LIST: 0.9354163, DIVERSITY_HERFINDAHL: 0.9935394, COVERAGE_ITEM: 0.4056392, COVERAGE_ITEM_HIT: 0.0419880, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3126186, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0275261, SHANNON_ENTROPY: 8.7631062, RATIO_DIVERSITY_HERFINDAHL: 0.9938674, RATIO_DIVERSITY_GINI: 0.0541098, RATIO_SHANNON_ENTROPY: 0.6494129, RATIO_AVERAGE_POPULARITY: 3.8348186, RATIO_NOVELTY: 0.2472742,
#
# SearchBayesianSkopt: Saving model in result_experiments/RP3betaRecommender_explicit/RP3betaRecommender
#
# RP3betaRecommender: Saving model in file 'result_experiments/RP3betaRecommender_explicit/RP3betaRecommender_best_model'
# RP3betaRecommender: Saving complete
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 129.2986
# Function value obtained: -0.0217
# Current minimum: -0.0217
# Iteration No: 10 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1000, 'alpha': 1.3192249785786423, 'beta': 0.0, 'normalize_similarity': True}
# RP3betaRecommender: Similarity column 24507 (100.0%), 257.19 column/sec. Elapsed time 1.59 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.49 min. Users per second: 465
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 1000, 'alpha': 1.3192249785786423, 'beta': 0.0, 'normalize_similarity': True} - results: PRECISION: 0.0410939, PRECISION_RECALL_MIN_DEN: 0.0676774, RECALL: 0.0641023, MAP: 0.0189094, MAP_MIN_DEN: 0.0306663, MRR: 0.1367620, NDCG: 0.0720978, F1: 0.0500819, HIT_RATE: 0.2956593, ARHR_ALL_HITS: 0.1601379, NOVELTY: 0.0040719, AVERAGE_POPULARITY: 0.2731761, DIVERSITY_MEAN_INTER_LIST: 0.8510526, DIVERSITY_HERFINDAHL: 0.9851032, COVERAGE_ITEM: 0.2940384, COVERAGE_ITEM_HIT: 0.0266046, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2956593, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0163761, SHANNON_ENTROPY: 7.6717349, RATIO_DIVERSITY_HERFINDAHL: 0.9854284, RATIO_DIVERSITY_GINI: 0.0321915, RATIO_SHANNON_ENTROPY: 0.5685340, RATIO_AVERAGE_POPULARITY: 5.3980110, RATIO_NOVELTY: 0.2329662,
#
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 235.3829
# Function value obtained: -0.0189
# Current minimum: -0.0217
# SearchBayesianSkopt: Search complete. Best config is 8: {'topK': 146, 'alpha': 0.8745041827526168, 'beta': 0.0, 'normalize_similarity': True}

# %%
from Recommenders.DataIO import DataIO

data_loader = DataIO(folder_path=output_folder_path)
search_metadata = data_loader.load_data(
    recommender_class.RECOMMENDER_NAME + "_metadata.zip"
)

result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#          PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#   cutoff
# 0 10      0.000324                 0.000477  0.000393  0.000084    0.000119
# 1 10      0.042514                 0.068011  0.064236  0.020603    0.032753
# 2 10       0.00515                 0.007088  0.006338  0.002146    0.002872
# 3 10      0.043136                 0.070844  0.067041  0.020395    0.033227
# 4 10      0.040589                 0.066103  0.062457  0.018906    0.030467
# 5 10      0.039112                 0.062693   0.05919  0.018061    0.028517
# 6 10       0.04439                 0.073583  0.069615  0.021039    0.034659
# 7 10      0.000283                 0.000597  0.000575  0.000058    0.000127
# 8 10      0.044957                 0.072969  0.068936   0.02167    0.035018
# 9 10      0.041094                 0.067677  0.064102  0.018909    0.030666
#
#                MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#   cutoff                                                        ...
# 0 10      0.000693  0.000333  0.000355  0.002859      0.000759  ...
# 1 10      0.145801  0.077463  0.051165  0.296764      0.172489  ...
# 2 10      0.015201   0.00793  0.005683  0.038243      0.017932  ...
# 3 10      0.145821  0.075616  0.052495  0.305844      0.171528  ...
# 4 10      0.135219  0.071116  0.049203  0.289101      0.158981  ...
# 5 10      0.129628  0.068797  0.047101  0.279325      0.152376  ...
# 6 10      0.150183  0.073438  0.054212  0.314564      0.176744  ...
# 7 10      0.000584  0.000392   0.00038  0.002835      0.000584  ...
# 8 10      0.152673  0.079654  0.054422  0.312619      0.180829  ...
# 9 10      0.136762  0.072098  0.050082  0.295659      0.160138  ...
#
#          COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#   cutoff
# 0 10               1.0          0.002859         1.0       0.135454
# 1 10               1.0          0.296764         1.0       0.062906
# 2 10               1.0          0.038243         1.0       0.173046
# 3 10               1.0          0.305844         1.0       0.027866
# 4 10               1.0          0.289101         1.0       0.044035
# 5 10               1.0          0.279325         1.0       0.056034
# 6 10               1.0          0.314564         1.0       0.027636
# 7 10               1.0          0.002835         1.0       0.349675
# 8 10               1.0          0.312619         1.0       0.027526
# 9 10               1.0          0.295659         1.0       0.016376
#
#          SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#   cutoff
# 0 10           12.084331                   0.999952             0.266271
# 1 10            9.778231                   0.994849             0.123658
# 2 10           12.441135                   1.000039             0.340166
# 3 10            8.216271                    0.98865             0.054779
# 4 10            9.167429                   0.993883             0.086562
# 5 10             9.21373                    0.99096              0.11015
# 6 10            8.119163                   0.986437             0.054325
# 7 10           13.418974                   1.000222             0.687377
# 8 10            8.763106                   0.993867              0.05411
# 9 10            7.671735                   0.985428             0.032192
#
#          RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#   cutoff
# 0 10                  0.895541                 0.052121      0.372687
# 1 10                  0.724641                 3.342692      0.270012
# 2 10                  0.921983                 0.072741       0.36829
# 3 10                  0.608888                 4.854045      0.239004
# 4 10                  0.679376                 3.280305      0.255426
# 5 10                  0.682808                 4.171347      0.259962
# 6 10                  0.601692                 5.327537      0.236541
# 7 10                  0.994448                 0.103712      0.359444
# 8 10                  0.649413                 3.834819      0.247274
# 9 10                  0.568534                 5.398011      0.232966
#
# [10 rows x 27 columns]

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#    topK     alpha      beta normalize_similarity
# 0   584  1.487578  1.492067                 True
# 1    85  1.579137  0.215863                 True
# 2   391  1.326802  1.064339                 True
# 3    96  0.823334       0.0                False
# 4  1000  0.210768  0.681386                False
# 5  1000  1.725199  0.091251                 True
# 6   772       0.0  0.307223                 True
# 7     5       2.0  0.337019                False
# 8   146  0.874504       0.0                 True
# 9  1000  1.319225       0.0                 True

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters

# %%
exception_list = search_metadata["exception_list"]
exception_list
# Out:
# ['Traceback (most recent call last):\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 604, in _objective_function\n    result_df, recommender_instance = self._evaluate_on_validation(\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 395, in _evaluate_on_validation\n    self.model_counter: recommender_instance.get_validation_summary_table()\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\Recommenders\\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table\n    return self._earlystopping_validation_summary_df.copy()\nAttributeError: \'NoneType\' object has no attribute \'copy\'\n',
#  'Traceback (most recent call last):\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 604, in _objective_function\n    result_df, recommender_instance = self._evaluate_on_validation(\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 395, in _evaluate_on_validation\n    self.model_counter: recommender_instance.get_validation_summary_table()\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\Recommenders\\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table\n    return self._earlystopping_validation_summary_df.copy()\nAttributeError: \'NoneType\' object has no attribute \'copy\'\n',
#  'Traceback (most recent call last):\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 604, in _objective_function\n    result_df, recommender_instance = self._evaluate_on_validation(\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 395, in _evaluate_on_validation\n    self.model_counter: recommender_instance.get_validation_summary_table()\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\Recommenders\\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table\n    return self._earlystopping_validation_summary_df.copy()\nAttributeError: \'NoneType\' object has no attribute \'copy\'\n',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
recommender = recommender_class(URM_all)
recommender.fit(**best_hyperparameters)
recommender.save_model(
    folder_path=output_folder_path,
    file_name=recommender_class.RECOMMENDER_NAME
    + "_best_model_trained_on_everything.zip",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 recommender = recommender_class(URM_all)
# ----> 2 recommender.fit(**best_hyperparameters)
#       3 recommender.save_model(
#       4     folder_path=recommender_class,
#       5     file_name=recommender_class.RECOMMENDER_NAME
#       6     + "_best_model_trained_on_everything.zip",
#       7 )
#
# TypeError: fit() argument after ** must be a mapping, not NoneType

# %%
from utils.create_submission import create_submission

create_submission(recommender)
