# %%
import os
import random

import numpy as np
import pandas as pd
import scipy.sparse as sps
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split

# Random seed for reproducibility
SEED = 42

random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Load dataset

# %%
URM_all = sps.load_npz("Data/URM/combined/URM_combined_all.npz")
URM_train = sps.load_npz("Data/URM/combined/URM_combined_train.npz")
URM_val = sps.load_npz("Data/URM/combined/URM_combined_val.npz")

# %%
from evaluation.evaluator import EvaluatorHoldout

evaluator = EvaluatorHoldout(URM_val, cutoff_list=[10])

# %% [markdown]
# ## Model

# %%
from Recommenders.KNN.ItemKNNSimilarityHybridRecommender import (
    ItemKNNSimilarityHybridRecommender,
)
from Recommenders.KNN.ItemKNNCFRecommender import (
    ItemKNNCFRecommender,
)
from skopt.space import Real, Integer, Categorical
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

recommender_class = ItemKNNSimilarityHybridRecommender
n_cases = 10

hyperparameters_range_dictionary = {
    "topK": Integer(100, 2000),
    "alpha": Real(0.0, 1.0),
}

hyperparameterSearch = SearchBayesianSkopt(
    recommender_class,
    evaluator_validation=evaluator,
)

cosine_recommender = ItemKNNCFRecommender(URM_train)
cosine_recommender.load_model(
    folder_path="result_experiments/item_knn_cf_combined/",
    file_name=ItemKNNCFRecommender.RECOMMENDER_NAME + "_cosine_best_model.zip",
)
jaccard_recommender = ItemKNNCFRecommender(URM_train)
jaccard_recommender.load_model(
    folder_path="result_experiments/item_knn_cf_combined/",
    file_name=ItemKNNCFRecommender.RECOMMENDER_NAME + "_jaccard_best_model.zip",
)

recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS=[
        URM_train,
        cosine_recommender.W_sparse,
        jaccard_recommender.W_sparse
    ],
    CONSTRUCTOR_KEYWORD_ARGS={},
    FIT_POSITIONAL_ARGS=[],
    FIT_KEYWORD_ARGS={},
    EARLYSTOPPING_KEYWORD_ARGS={},
)

output_folder_path = "result_experiments/item_knn_cf_hybrid/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

n_random_starts = int(n_cases * 0.3)
metric_to_optimize = "MAP"
cutoff_to_optimize = 10
# Out:
# ItemKNNCFRecommender: Loading model from file 'result_experiments/item_knn_cf_combined/ItemKNNCFRecommender_cosine_best_model.zip'
# ItemKNNCFRecommender: Loading complete
# ItemKNNCFRecommender: Loading model from file 'result_experiments/item_knn_cf_combined/ItemKNNCFRecommender_jaccard_best_model.zip'
# ItemKNNCFRecommender: Loading complete

# %%
hyperparameterSearch.search(
    recommender_input_args,
    hyperparameter_search_space=hyperparameters_range_dictionary,
    n_cases=n_cases,
    n_random_starts=n_random_starts,
    save_model="best",
    output_folder_path=output_folder_path,  # Where to save the results
    output_file_name_root=recommender_class.RECOMMENDER_NAME,  # How to call the files
    metric_to_optimize=metric_to_optimize,
    cutoff_to_optimize=cutoff_to_optimize,
)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1091, 'alpha': 0.30143986805874196}
# EvaluatorHoldout: Processed 41629 (100.0%) in 58.06 sec. Users per second: 717
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 1091, 'alpha': 0.30143986805874196} - results: PRECISION: 0.0452281, PRECISION_RECALL_MIN_DEN: 0.0742436, RECALL: 0.0701628, MAP: 0.0218043, MAP_MIN_DEN: 0.0357120, MRR: 0.1532911, NDCG: 0.0769643, F1: 0.0550014, HIT_RATE: 0.3141800, ARHR_ALL_HITS: 0.1818115, NOVELTY: 0.0044163, AVERAGE_POPULARITY: 0.1918478, DIVERSITY_MEAN_INTER_LIST: 0.9283803, DIVERSITY_HERFINDAHL: 0.9928358, COVERAGE_ITEM: 0.6069694, COVERAGE_ITEM_HIT: 0.0523524, ITEMS_IN_GT: 0.9926960, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3141800, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0473711, SHANNON_ENTROPY: 9.1180944, RATIO_DIVERSITY_HERFINDAHL: 0.9931628, RATIO_DIVERSITY_GINI: 0.0931786, RATIO_SHANNON_ENTROPY: 0.6757088, RATIO_AVERAGE_POPULARITY: 3.7833181, RATIO_NOVELTY: 0.2526679,
#
# SearchBayesianSkopt: Saving model in result_experiments/item_knn_cf_hybrid/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/item_knn_cf_hybrid/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 101.5494
# Function value obtained: -0.0218
# Current minimum: -0.0218
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 454, 'alpha': 0.8424042405288403}
# EvaluatorHoldout: Processed 41629 (100.0%) in 50.26 sec. Users per second: 828
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 454, 'alpha': 0.8424042405288403} - results: PRECISION: 0.0456749, PRECISION_RECALL_MIN_DEN: 0.0750057, RECALL: 0.0708986, MAP: 0.0221954, MAP_MIN_DEN: 0.0363600, MRR: 0.1562205, NDCG: 0.0777211, F1: 0.0555578, HIT_RATE: 0.3171827, ARHR_ALL_HITS: 0.1852099, NOVELTY: 0.0044144, AVERAGE_POPULARITY: 0.2035487, DIVERSITY_MEAN_INTER_LIST: 0.9206215, DIVERSITY_HERFINDAHL: 0.9920599, COVERAGE_ITEM: 0.6956788, COVERAGE_ITEM_HIT: 0.0519851, ITEMS_IN_GT: 0.9926960, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3171827, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0586692, SHANNON_ENTROPY: 9.1403305, RATIO_DIVERSITY_HERFINDAHL: 0.9923867, RATIO_DIVERSITY_GINI: 0.1154019, RATIO_SHANNON_ENTROPY: 0.6773566, RATIO_AVERAGE_POPULARITY: 4.0140652, RATIO_NOVELTY: 0.2525623,
#
# SearchBayesianSkopt: Saving model in result_experiments/item_knn_cf_hybrid/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/item_knn_cf_hybrid/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 77.2847
# Function value obtained: -0.0222
# Current minimum: -0.0222
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1476, 'alpha': 0.08499028127151022}
# EvaluatorHoldout: Processed 41629 (100.0%) in 56.39 sec. Users per second: 738
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 1476, 'alpha': 0.08499028127151022} - results: PRECISION: 0.0444089, PRECISION_RECALL_MIN_DEN: 0.0729989, RECALL: 0.0690082, MAP: 0.0211999, MAP_MIN_DEN: 0.0347304, MRR: 0.1494077, NDCG: 0.0754507, F1: 0.0540409, HIT_RATE: 0.3093997, ARHR_ALL_HITS: 0.1770208, NOVELTY: 0.0044375, AVERAGE_POPULARITY: 0.1816223, DIVERSITY_MEAN_INTER_LIST: 0.9338738, DIVERSITY_HERFINDAHL: 0.9933851, COVERAGE_ITEM: 0.5579222, COVERAGE_ITEM_HIT: 0.0528828, ITEMS_IN_GT: 0.9926960, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3093997, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0441249, SHANNON_ENTROPY: 9.1679949, RATIO_DIVERSITY_HERFINDAHL: 0.9937124, RATIO_DIVERSITY_GINI: 0.0867935, RATIO_SHANNON_ENTROPY: 0.6794067, RATIO_AVERAGE_POPULARITY: 3.5816670, RATIO_NOVELTY: 0.2538815,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 77.0993
# Function value obtained: -0.0212
# Current minimum: -0.0222
# Iteration No: 4 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 527, 'alpha': 0.8076338902289039}
# EvaluatorHoldout: Processed 41629 (100.0%) in 53.46 sec. Users per second: 779
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 527, 'alpha': 0.8076338902289039} - results: PRECISION: 0.0456581, PRECISION_RECALL_MIN_DEN: 0.0749533, RECALL: 0.0708502, MAP: 0.0221913, MAP_MIN_DEN: 0.0363458, MRR: 0.1562045, NDCG: 0.0777539, F1: 0.0555305, HIT_RATE: 0.3170866, ARHR_ALL_HITS: 0.1851804, NOVELTY: 0.0044103, AVERAGE_POPULARITY: 0.2044580, DIVERSITY_MEAN_INTER_LIST: 0.9198342, DIVERSITY_HERFINDAHL: 0.9919812, COVERAGE_ITEM: 0.6918431, COVERAGE_ITEM_HIT: 0.0518219, ITEMS_IN_GT: 0.9926960, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3170866, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0578975, SHANNON_ENTROPY: 9.1236259, RATIO_DIVERSITY_HERFINDAHL: 0.9923080, RATIO_DIVERSITY_GINI: 0.1138840, RATIO_SHANNON_ENTROPY: 0.6761187, RATIO_AVERAGE_POPULARITY: 4.0319974, RATIO_NOVELTY: 0.2523251,
#
# Iteration No: 4 ended. Search finished for the next optimal point.
# Time taken: 70.1523
# Function value obtained: -0.0222
# Current minimum: -0.0222
# Iteration No: 5 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 2000, 'alpha': 0.5393020051814567}
# EvaluatorHoldout: Processed 41629 (100.0%) in 55.86 sec. Users per second: 745
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 2000, 'alpha': 0.5393020051814567} - results: PRECISION: 0.0455500, PRECISION_RECALL_MIN_DEN: 0.0747811, RECALL: 0.0706831, MAP: 0.0220715, MAP_MIN_DEN: 0.0361448, MRR: 0.1551793, NDCG: 0.0775054, F1: 0.0553993, HIT_RATE: 0.3164621, ARHR_ALL_HITS: 0.1840553, NOVELTY: 0.0044099, AVERAGE_POPULARITY: 0.1990723, DIVERSITY_MEAN_INTER_LIST: 0.9237772, DIVERSITY_HERFINDAHL: 0.9923755, COVERAGE_ITEM: 0.6534868, COVERAGE_ITEM_HIT: 0.0523932, ITEMS_IN_GT: 0.9926960, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3164621, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0523527, SHANNON_ENTROPY: 9.1104083, RATIO_DIVERSITY_HERFINDAHL: 0.9927024, RATIO_DIVERSITY_GINI: 0.1029774, RATIO_SHANNON_ENTROPY: 0.6751392, RATIO_AVERAGE_POPULARITY: 3.9257895, RATIO_NOVELTY: 0.2522997,
#
# Iteration No: 5 ended. Search finished for the next optimal point.
# Time taken: 77.0932
# Function value obtained: -0.0221
# Current minimum: -0.0222
# Iteration No: 6 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1421, 'alpha': 1.0}
# EvaluatorHoldout: Processed 41629 (100.0%) in 53.26 sec. Users per second: 782
# SearchBayesianSkopt: New best config found. Config 5: {'topK': 1421, 'alpha': 1.0} - results: PRECISION: 0.0457085, PRECISION_RECALL_MIN_DEN: 0.0750830, RECALL: 0.0709952, MAP: 0.0222018, MAP_MIN_DEN: 0.0363761, MRR: 0.1563607, NDCG: 0.0777256, F1: 0.0556124, HIT_RATE: 0.3175190, ARHR_ALL_HITS: 0.1853527, NOVELTY: 0.0044142, AVERAGE_POPULARITY: 0.2065367, DIVERSITY_MEAN_INTER_LIST: 0.9182130, DIVERSITY_HERFINDAHL: 0.9918191, COVERAGE_ITEM: 0.7147346, COVERAGE_ITEM_HIT: 0.0521484, ITEMS_IN_GT: 0.9926960, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3175190, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0617567, SHANNON_ENTROPY: 9.1432132, RATIO_DIVERSITY_HERFINDAHL: 0.9921458, RATIO_DIVERSITY_GINI: 0.1214751, RATIO_SHANNON_ENTROPY: 0.6775703, RATIO_AVERAGE_POPULARITY: 4.0729901, RATIO_NOVELTY: 0.2525462,
#
# SearchBayesianSkopt: Saving model in result_experiments/item_knn_cf_hybrid/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/item_knn_cf_hybrid/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 79.7208
# Function value obtained: -0.0222
# Current minimum: -0.0222
# Iteration No: 7 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 2000, 'alpha': 0.9274983562263128}
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.01 min. Users per second: 685
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'topK': 2000, 'alpha': 0.9274983562263128} - results: PRECISION: 0.0457253, PRECISION_RECALL_MIN_DEN: 0.0751257, RECALL: 0.0710401, MAP: 0.0221967, MAP_MIN_DEN: 0.0363801, MRR: 0.1562830, NDCG: 0.0777714, F1: 0.0556386, HIT_RATE: 0.3176872, ARHR_ALL_HITS: 0.1852709, NOVELTY: 0.0044125, AVERAGE_POPULARITY: 0.2058146, DIVERSITY_MEAN_INTER_LIST: 0.9187883, DIVERSITY_HERFINDAHL: 0.9918766, COVERAGE_ITEM: 0.7066960, COVERAGE_ITEM_HIT: 0.0520668, ITEMS_IN_GT: 0.9926960, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3176872, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0603576, SHANNON_ENTROPY: 9.1352558, RATIO_DIVERSITY_HERFINDAHL: 0.9922033, RATIO_DIVERSITY_GINI: 0.1187231, RATIO_SHANNON_ENTROPY: 0.6769806, RATIO_AVERAGE_POPULARITY: 4.0587502, RATIO_NOVELTY: 0.2524536,
#
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 82.3149
# Function value obtained: -0.0222
# Current minimum: -0.0222
# Iteration No: 8 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 550, 'alpha': 0.7362688307535828}
# EvaluatorHoldout: Processed 41629 (100.0%) in 53.11 sec. Users per second: 784
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': 550, 'alpha': 0.7362688307535828} - results: PRECISION: 0.0456317, PRECISION_RECALL_MIN_DEN: 0.0749366, RECALL: 0.0708513, MAP: 0.0221939, MAP_MIN_DEN: 0.0363660, MRR: 0.1561931, NDCG: 0.0778018, F1: 0.0555113, HIT_RATE: 0.3167023, ARHR_ALL_HITS: 0.1851867, NOVELTY: 0.0044093, AVERAGE_POPULARITY: 0.2033799, DIVERSITY_MEAN_INTER_LIST: 0.9206159, DIVERSITY_HERFINDAHL: 0.9920594, COVERAGE_ITEM: 0.6831926, COVERAGE_ITEM_HIT: 0.0517403, ITEMS_IN_GT: 0.9926960, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3167023, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0564854, SHANNON_ENTROPY: 9.1171241, RATIO_DIVERSITY_HERFINDAHL: 0.9923861, RATIO_DIVERSITY_GINI: 0.1111064, RATIO_SHANNON_ENTROPY: 0.6756369, RATIO_AVERAGE_POPULARITY: 4.0107359, RATIO_NOVELTY: 0.2522679,
#
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 72.0396
# Function value obtained: -0.0222
# Current minimum: -0.0222
# Iteration No: 9 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1538, 'alpha': 0.0647885748959476}
# EvaluatorHoldout: Processed 41629 (100.0%) in 56.33 sec. Users per second: 739
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'topK': 1538, 'alpha': 0.0647885748959476} - results: PRECISION: 0.0442912, PRECISION_RECALL_MIN_DEN: 0.0727986, RECALL: 0.0688189, MAP: 0.0211615, MAP_MIN_DEN: 0.0346641, MRR: 0.1492935, NDCG: 0.0753434, F1: 0.0538957, HIT_RATE: 0.3088952, ARHR_ALL_HITS: 0.1767821, NOVELTY: 0.0044406, AVERAGE_POPULARITY: 0.1804449, DIVERSITY_MEAN_INTER_LIST: 0.9344401, DIVERSITY_HERFINDAHL: 0.9934418, COVERAGE_ITEM: 0.5540050, COVERAGE_ITEM_HIT: 0.0527604, ITEMS_IN_GT: 0.9926960, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3088952, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0440388, SHANNON_ENTROPY: 9.1758853, RATIO_DIVERSITY_HERFINDAHL: 0.9937690, RATIO_DIVERSITY_GINI: 0.0866241, RATIO_SHANNON_ENTROPY: 0.6799915, RATIO_AVERAGE_POPULARITY: 3.5584491, RATIO_NOVELTY: 0.2540566,
#
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 77.6168
# Function value obtained: -0.0212
# Current minimum: -0.0222
# Iteration No: 10 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 434, 'alpha': 0.4997026222457668}
# EvaluatorHoldout: Processed 41629 (100.0%) in 47.24 sec. Users per second: 881
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 434, 'alpha': 0.4997026222457668} - results: PRECISION: 0.0455332, PRECISION_RECALL_MIN_DEN: 0.0747087, RECALL: 0.0706103, MAP: 0.0220081, MAP_MIN_DEN: 0.0360502, MRR: 0.1547836, NDCG: 0.0774455, F1: 0.0553645, HIT_RATE: 0.3161978, ARHR_ALL_HITS: 0.1835600, NOVELTY: 0.0044116, AVERAGE_POPULARITY: 0.1978037, DIVERSITY_MEAN_INTER_LIST: 0.9246963, DIVERSITY_HERFINDAHL: 0.9924674, COVERAGE_ITEM: 0.6439385, COVERAGE_ITEM_HIT: 0.0525156, ITEMS_IN_GT: 0.9926960, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3161978, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0513542, SHANNON_ENTROPY: 9.1171689, RATIO_DIVERSITY_HERFINDAHL: 0.9927943, RATIO_DIVERSITY_GINI: 0.1010134, RATIO_SHANNON_ENTROPY: 0.6756402, RATIO_AVERAGE_POPULARITY: 3.9007715, RATIO_NOVELTY: 0.2524010,
#
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 62.0544
# Function value obtained: -0.0220
# Current minimum: -0.0222
# SearchBayesianSkopt: Search complete. Best config is 5: {'topK': 1421, 'alpha': 1.0}

# %%
from Recommenders.DataIO import DataIO

data_loader = DataIO(folder_path=output_folder_path)
search_metadata = data_loader.load_data(
    ItemKNNSimilarityHybridRecommender.RECOMMENDER_NAME + "_metadata.zip"
)

result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#          PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#   cutoff
# 0 10      0.045228                 0.074244  0.070163  0.021804    0.035712
# 1 10      0.045675                 0.075006  0.070899  0.022195     0.03636
# 2 10      0.044409                 0.072999  0.069008    0.0212     0.03473
# 3 10      0.045658                 0.074953   0.07085  0.022191    0.036346
# 4 10       0.04555                 0.074781  0.070683  0.022072    0.036145
# 5 10      0.045709                 0.075083  0.070995  0.022202    0.036376
# 6 10      0.045725                 0.075126   0.07104  0.022197     0.03638
# 7 10      0.045632                 0.074937  0.070851  0.022194    0.036366
# 8 10      0.044291                 0.072799  0.068819  0.021162    0.034664
# 9 10      0.045533                 0.074709   0.07061  0.022008     0.03605
#
#                MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#   cutoff                                                        ...
# 0 10      0.153291  0.076964  0.055001   0.31418      0.181811  ...
# 1 10       0.15622  0.077721  0.055558  0.317183       0.18521  ...
# 2 10      0.149408  0.075451  0.054041    0.3094      0.177021  ...
# 3 10      0.156205  0.077754  0.055531  0.317087       0.18518  ...
# 4 10      0.155179  0.077505  0.055399  0.316462      0.184055  ...
# 5 10      0.156361  0.077726  0.055612  0.317519      0.185353  ...
# 6 10      0.156283  0.077771  0.055639  0.317687      0.185271  ...
# 7 10      0.156193  0.077802  0.055511  0.316702      0.185187  ...
# 8 10      0.149294  0.075343  0.053896  0.308895      0.176782  ...
# 9 10      0.154784  0.077445  0.055364  0.316198       0.18356  ...
#
#          COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#   cutoff
# 0 10               1.0           0.31418         1.0       0.047371
# 1 10               1.0          0.317183         1.0       0.058669
# 2 10               1.0            0.3094         1.0       0.044125
# 3 10               1.0          0.317087         1.0       0.057897
# 4 10               1.0          0.316462         1.0       0.052353
# 5 10               1.0          0.317519         1.0       0.061757
# 6 10               1.0          0.317687         1.0       0.060358
# 7 10               1.0          0.316702         1.0       0.056485
# 8 10               1.0          0.308895         1.0       0.044039
# 9 10               1.0          0.316198         1.0       0.051354
#
#          SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#   cutoff
# 0 10            9.118094                   0.993163             0.093179
# 1 10             9.14033                   0.992387             0.115402
# 2 10            9.167995                   0.993712             0.086793
# 3 10            9.123626                   0.992308             0.113884
# 4 10            9.110408                   0.992702             0.102977
# 5 10            9.143213                   0.992146             0.121475
# 6 10            9.135256                   0.992203             0.118723
# 7 10            9.117124                   0.992386             0.111106
# 8 10            9.175885                   0.993769             0.086624
# 9 10            9.117169                   0.992794             0.101013
#
#          RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#   cutoff
# 0 10                  0.675709                 3.783318      0.252668
# 1 10                  0.677357                 4.014065      0.252562
# 2 10                  0.679407                 3.581667      0.253881
# 3 10                  0.676119                 4.031997      0.252325
# 4 10                  0.675139                  3.92579        0.2523
# 5 10                   0.67757                  4.07299      0.252546
# 6 10                  0.676981                  4.05875      0.252454
# 7 10                  0.675637                 4.010736      0.252268
# 8 10                  0.679991                 3.558449      0.254057
# 9 10                   0.67564                 3.900772      0.252401
#
# [10 rows x 27 columns]

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#    topK     alpha
# 0  1091   0.30144
# 1   454  0.842404
# 2  1476   0.08499
# 3   527  0.807634
# 4  2000  0.539302
# 5  1421       1.0
# 6  2000  0.927498
# 7   550  0.736269
# 8  1538  0.064789
# 9   434  0.499703

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'topK': 1421, 'alpha': 1.0}

# %%
exception_list = search_metadata["exception_list"]
exception_list
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
recommender = ItemKNNSimilarityHybridRecommender(URM_all, cosine_recommender.W_sparse, jaccard_recommender.W_sparse)
recommender.load_model(
    folder_path="result_experiments/",
    file_name=ItemKNNSimilarityHybridRecommender.RECOMMENDER_NAME + "_best_model.zip",
)
# Out:
# ItemKNNSimilarityHybridRecommender: Loading model from file 'result_experiments/ItemKNNSimilarityHybridRecommender_best_model.zip'
# ItemKNNSimilarityHybridRecommender: Loading complete

# %%
target_users = pd.read_csv("Data/data_target_users_test.csv", dtype={0: int})

# %%
target_users = pd.read_csv("Data/data_target_users_test.csv", dtype={0: int})[
    "user_id"
].values

print("Creating recomendations...")
recomendations = recommender.recommend(target_users, cutoff=10)
# Out:
# Creating recomendations...

# %%
from datetime import datetime

out = os.path.join("Output", datetime.now().strftime("%Y_%m_%d_%H_%M_%S") + ".csv")
print("Writing to file...")
with open(out, "w") as f:
    f.write("user_id,item_list\n")

    for i in range(len(target_users)):
        f.write(
            str(target_users[i])
            + ","
            + " ".join(str(x) for x in recomendations[i])
            + "\n"
        )
# Out:
# Writing to file...
