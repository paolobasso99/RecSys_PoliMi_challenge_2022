# %%
import os
import random

import numpy as np
import pandas as pd
import scipy.sparse as sps
import matplotlib.pyplot as plt
import seaborn as snb

# Random seed for reproducibility
SEED = 42
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)

# %%
from data_manager import DatasetLoader, DatasetSplitter, URMGenerator

dataset_loader = DatasetLoader()
dataset_splitter = DatasetSplitter(dataset_loader)
dataset_train, dataset_val = dataset_splitter.load_train_val()
URM_generator = URMGenerator(dataset_train, dataset_val)
URM_train, URM_val = URM_generator.generate_implicit_URM()
URM_all = URM_train + URM_val
# Out:
# Loading previusly generated splits...
# Generating implicit URM...

# %%
from evaluation.evaluator import EvaluatorHoldout

evaluator = EvaluatorHoldout(URM_val, cutoff_list=[10])

# %%
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from skopt.space import Real, Integer, Categorical
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

output_folder_path = "result_experiments/ItemKNNCFRecommender_implicit/"
recommender_class = ItemKNNCFRecommender
n_cases = 15
n_random_starts = int(n_cases * 0.3)
metric_to_optimize = "MAP"
cutoff_to_optimize = 10

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Define hyperparameters
hyperparameters_range_dictionary = {
    "topK": Integer(5, 2000),
    "shrink": Integer(0, 1000),
    "similarity": Categorical(["cosine", "jaccard"]),
    "normalize": Categorical([True, False]),
}

hyperparameter_search = SearchBayesianSkopt(
    recommender_class,
    evaluator_validation=evaluator,
)

recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS=[
        URM_train,
    ],
    CONSTRUCTOR_KEYWORD_ARGS={},
    FIT_POSITIONAL_ARGS=[],
    FIT_KEYWORD_ARGS={},
    EARLYSTOPPING_KEYWORD_ARGS={},
)

# %%
hyperparameter_search.search(
    recommender_input_args,
    hyperparameter_search_space=hyperparameters_range_dictionary,
    n_cases=n_cases,
    n_random_starts=n_random_starts,
    save_model="best",
    output_folder_path=output_folder_path,  # Where to save the results
    output_file_name_root=recommender_class.RECOMMENDER_NAME,  # How to call the files
    metric_to_optimize=metric_to_optimize,
    cutoff_to_optimize=cutoff_to_optimize,
)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1444, 'shrink': 158, 'similarity': 'cosine', 'normalize': True}
# Similarity column 24507 (100.0%), 1705.53 column/sec. Elapsed time 14.37 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.49 min. Users per second: 465
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 1444, 'shrink': 158, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0424031, PRECISION_RECALL_MIN_DEN: 0.0710910, RECALL: 0.0673407, MAP: 0.0202406, MAP_MIN_DEN: 0.0335933, MRR: 0.1461785, NDCG: 0.0691522, F1: 0.0520386, HIT_RATE: 0.3037066, ARHR_ALL_HITS: 0.1710519, NOVELTY: 0.0039505, AVERAGE_POPULARITY: 0.2927468, DIVERSITY_MEAN_INTER_LIST: 0.8333346, DIVERSITY_HERFINDAHL: 0.9833315, COVERAGE_ITEM: 0.1281267, COVERAGE_ITEM_HIT: 0.0277880, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3037066, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0069009, SHANNON_ENTROPY: 7.1936778, RATIO_DIVERSITY_HERFINDAHL: 0.9836561, RATIO_DIVERSITY_GINI: 0.0135656, RATIO_SHANNON_ENTROPY: 0.5331063, RATIO_AVERAGE_POPULARITY: 5.7847314, RATIO_NOVELTY: 0.2260216,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNCFRecommender_implicit/ItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender_implicit/ItemKNNCFRecommender_best_model'
# ItemKNNCFRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 133.9845
# Function value obtained: -0.0202
# Current minimum: -0.0202
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 183, 'shrink': 457, 'similarity': 'cosine', 'normalize': False}
# Similarity column 24507 (100.0%), 4397.64 column/sec. Elapsed time 5.57 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.07 min. Users per second: 649
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'topK': 183, 'shrink': 457, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0337913, PRECISION_RECALL_MIN_DEN: 0.0580685, RECALL: 0.0552634, MAP: 0.0150933, MAP_MIN_DEN: 0.0258577, MRR: 0.1161387, NDCG: 0.0548541, F1: 0.0419388, HIT_RATE: 0.2588100, ARHR_ALL_HITS: 0.1318565, NOVELTY: 0.0037161, AVERAGE_POPULARITY: 0.3895406, DIVERSITY_MEAN_INTER_LIST: 0.6461217, DIVERSITY_HERFINDAHL: 0.9646106, COVERAGE_ITEM: 0.1611784, COVERAGE_ITEM_HIT: 0.0177500, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2588100, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0051762, SHANNON_ENTROPY: 6.0394864, RATIO_DIVERSITY_HERFINDAHL: 0.9649291, RATIO_DIVERSITY_GINI: 0.0101751, RATIO_SHANNON_ENTROPY: 0.4475719, RATIO_AVERAGE_POPULARITY: 7.6973954, RATIO_NOVELTY: 0.2126110,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 70.4054
# Function value obtained: -0.0151
# Current minimum: -0.0202
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1532, 'shrink': 320, 'similarity': 'jaccard', 'normalize': False}
# Similarity column 24507 (100.0%), 2865.28 column/sec. Elapsed time 8.55 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.27 min. Users per second: 545
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 1532, 'shrink': 320, 'similarity': 'jaccard', 'normalize': False} - results: PRECISION: 0.0419731, PRECISION_RECALL_MIN_DEN: 0.0698353, RECALL: 0.0661113, MAP: 0.0198531, MAP_MIN_DEN: 0.0327714, MRR: 0.1431890, NDCG: 0.0677988, F1: 0.0513469, HIT_RATE: 0.3008239, ARHR_ALL_HITS: 0.1676797, NOVELTY: 0.0040844, AVERAGE_POPULARITY: 0.2346618, DIVERSITY_MEAN_INTER_LIST: 0.8880852, DIVERSITY_HERFINDAHL: 0.9888064, COVERAGE_ITEM: 0.1556698, COVERAGE_ITEM_HIT: 0.0308483, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3008239, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0096031, SHANNON_ENTROPY: 7.7277736, RATIO_DIVERSITY_HERFINDAHL: 0.9891328, RATIO_DIVERSITY_GINI: 0.0188773, RATIO_SHANNON_ENTROPY: 0.5726869, RATIO_AVERAGE_POPULARITY: 4.6369604, RATIO_NOVELTY: 0.2336813,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 87.2891
# Function value obtained: -0.0199
# Current minimum: -0.0202
# Iteration No: 4 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 700, 'shrink': 837, 'similarity': 'cosine', 'normalize': True}
# Similarity column 24507 (100.0%), 3216.42 column/sec. Elapsed time 7.62 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.31 min. Users per second: 531
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 700, 'shrink': 837, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0390281, PRECISION_RECALL_MIN_DEN: 0.0661712, RECALL: 0.0628230, MAP: 0.0183136, MAP_MIN_DEN: 0.0307477, MRR: 0.1355367, NDCG: 0.0638667, F1: 0.0481460, HIT_RATE: 0.2864590, ARHR_ALL_HITS: 0.1567592, NOVELTY: 0.0037990, AVERAGE_POPULARITY: 0.3454932, DIVERSITY_MEAN_INTER_LIST: 0.7531663, DIVERSITY_HERFINDAHL: 0.9753148, COVERAGE_ITEM: 0.1075611, COVERAGE_ITEM_HIT: 0.0195046, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2864590, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0042235, SHANNON_ENTROPY: 6.4792684, RATIO_DIVERSITY_HERFINDAHL: 0.9756368, RATIO_DIVERSITY_GINI: 0.0083023, RATIO_SHANNON_ENTROPY: 0.4801631, RATIO_AVERAGE_POPULARITY: 6.8270104, RATIO_NOVELTY: 0.2173549,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 88.0730
# Function value obtained: -0.0183
# Current minimum: -0.0202
# Iteration No: 5 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1121, 'shrink': 987, 'similarity': 'jaccard', 'normalize': False}
# Similarity column 24507 (100.0%), 3669.58 column/sec. Elapsed time 6.68 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.38 min. Users per second: 502
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 1121, 'shrink': 987, 'similarity': 'jaccard', 'normalize': False} - results: PRECISION: 0.0404502, PRECISION_RECALL_MIN_DEN: 0.0676608, RECALL: 0.0640870, MAP: 0.0191151, MAP_MIN_DEN: 0.0316075, MRR: 0.1390984, NDCG: 0.0655978, F1: 0.0495963, HIT_RATE: 0.2923203, ARHR_ALL_HITS: 0.1622015, NOVELTY: 0.0039388, AVERAGE_POPULARITY: 0.2808223, DIVERSITY_MEAN_INTER_LIST: 0.8413002, DIVERSITY_HERFINDAHL: 0.9841280, COVERAGE_ITEM: 0.1216795, COVERAGE_ITEM_HIT: 0.0231362, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2923203, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0061592, SHANNON_ENTROPY: 7.1153138, RATIO_DIVERSITY_HERFINDAHL: 0.9844529, RATIO_DIVERSITY_GINI: 0.0121074, RATIO_SHANNON_ENTROPY: 0.5272989, RATIO_AVERAGE_POPULARITY: 5.5491007, RATIO_NOVELTY: 0.2253532,
#
# Iteration No: 5 ended. Search finished for the next optimal point.
# Time taken: 92.8608
# Function value obtained: -0.0191
# Current minimum: -0.0202
# Iteration No: 6 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1999, 'shrink': 458, 'similarity': 'cosine', 'normalize': True}
# Similarity column 24507 (100.0%), 3422.62 column/sec. Elapsed time 7.16 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.35 min. Users per second: 514
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 1999, 'shrink': 458, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.0395998, PRECISION_RECALL_MIN_DEN: 0.0670727, RECALL: 0.0636664, MAP: 0.0186633, MAP_MIN_DEN: 0.0313207, MRR: 0.1377033, NDCG: 0.0648826, F1: 0.0488287, HIT_RATE: 0.2894377, ARHR_ALL_HITS: 0.1594921, NOVELTY: 0.0038051, AVERAGE_POPULARITY: 0.3423878, DIVERSITY_MEAN_INTER_LIST: 0.7603197, DIVERSITY_HERFINDAHL: 0.9760301, COVERAGE_ITEM: 0.0907904, COVERAGE_ITEM_HIT: 0.0200351, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2894377, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0039804, SHANNON_ENTROPY: 6.4953050, RATIO_DIVERSITY_HERFINDAHL: 0.9763524, RATIO_DIVERSITY_GINI: 0.0078245, RATIO_SHANNON_ENTROPY: 0.4813516, RATIO_AVERAGE_POPULARITY: 6.7656470, RATIO_NOVELTY: 0.2177035,
#
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 91.2687
# Function value obtained: -0.0187
# Current minimum: -0.0202
# Iteration No: 7 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1055, 'shrink': 0, 'similarity': 'jaccard', 'normalize': False}
# Similarity column 24507 (100.0%), 3415.16 column/sec. Elapsed time 7.18 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.22 min. Users per second: 568
# SearchBayesianSkopt: New best config found. Config 6: {'topK': 1055, 'shrink': 0, 'similarity': 'jaccard', 'normalize': False} - results: PRECISION: 0.0429773, PRECISION_RECALL_MIN_DEN: 0.0710124, RECALL: 0.0673133, MAP: 0.0202903, MAP_MIN_DEN: 0.0333595, MRR: 0.1449688, NDCG: 0.0689827, F1: 0.0524604, HIT_RATE: 0.3058445, ARHR_ALL_HITS: 0.1706064, NOVELTY: 0.0043840, AVERAGE_POPULARITY: 0.1861986, DIVERSITY_MEAN_INTER_LIST: 0.9266867, DIVERSITY_HERFINDAHL: 0.9926664, COVERAGE_ITEM: 0.3888277, COVERAGE_ITEM_HIT: 0.0499041, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3058445, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0283590, SHANNON_ENTROPY: 8.8124863, RATIO_DIVERSITY_HERFINDAHL: 0.9929942, RATIO_DIVERSITY_GINI: 0.0557471, RATIO_SHANNON_ENTROPY: 0.6530724, RATIO_AVERAGE_POPULARITY: 3.6793185, RATIO_NOVELTY: 0.2508266,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNCFRecommender_implicit/ItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender_implicit/ItemKNNCFRecommender_best_model'
# ItemKNNCFRecommender: Saving complete
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 107.1011
# Function value obtained: -0.0203
# Current minimum: -0.0203
# Iteration No: 8 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1291, 'shrink': 0, 'similarity': 'jaccard', 'normalize': False}
# Similarity column 24507 (100.0%), 3173.18 column/sec. Elapsed time 7.72 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.27 min. Users per second: 545
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': 1291, 'shrink': 0, 'similarity': 'jaccard', 'normalize': False} - results: PRECISION: 0.0429724, PRECISION_RECALL_MIN_DEN: 0.0709403, RECALL: 0.0672359, MAP: 0.0202862, MAP_MIN_DEN: 0.0333223, MRR: 0.1448642, NDCG: 0.0689228, F1: 0.0524333, HIT_RATE: 0.3057004, ARHR_ALL_HITS: 0.1705315, NOVELTY: 0.0043876, AVERAGE_POPULARITY: 0.1856706, DIVERSITY_MEAN_INTER_LIST: 0.9268378, DIVERSITY_HERFINDAHL: 0.9926816, COVERAGE_ITEM: 0.3912760, COVERAGE_ITEM_HIT: 0.0498225, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3057004, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0286759, SHANNON_ENTROPY: 8.8195622, RATIO_DIVERSITY_HERFINDAHL: 0.9930093, RATIO_DIVERSITY_GINI: 0.0563699, RATIO_SHANNON_ENTROPY: 0.6535967, RATIO_AVERAGE_POPULARITY: 3.6688861, RATIO_NOVELTY: 0.2510319,
#
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 86.9868
# Function value obtained: -0.0203
# Current minimum: -0.0203
# Iteration No: 9 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 456, 'shrink': 91, 'similarity': 'jaccard', 'normalize': True}
# Similarity column 24507 (100.0%), 3293.69 column/sec. Elapsed time 7.44 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 53.72 sec. Users per second: 775
# SearchBayesianSkopt: New best config found. Config 8: {'topK': 456, 'shrink': 91, 'similarity': 'jaccard', 'normalize': True} - results: PRECISION: 0.0434217, PRECISION_RECALL_MIN_DEN: 0.0719657, RECALL: 0.0681419, MAP: 0.0206844, MAP_MIN_DEN: 0.0340688, MRR: 0.1481057, NDCG: 0.0701676, F1: 0.0530430, HIT_RATE: 0.3089913, ARHR_ALL_HITS: 0.1740155, NOVELTY: 0.0042175, AVERAGE_POPULARITY: 0.2081579, DIVERSITY_MEAN_INTER_LIST: 0.9121780, DIVERSITY_HERFINDAHL: 0.9912156, COVERAGE_ITEM: 0.2089199, COVERAGE_ITEM_HIT: 0.0427225, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3089913, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0152076, SHANNON_ENTROPY: 8.2805915, RATIO_DIVERSITY_HERFINDAHL: 0.9915429, RATIO_DIVERSITY_GINI: 0.0298945, RATIO_SHANNON_ENTROPY: 0.6136549, RATIO_AVERAGE_POPULARITY: 4.1132402, RATIO_NOVELTY: 0.2412970,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNCFRecommender_implicit/ItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender_implicit/ItemKNNCFRecommender_best_model'
# ItemKNNCFRecommender: Saving complete
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 74.2761
# Function value obtained: -0.0207
# Current minimum: -0.0207
# Iteration No: 10 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1013, 'shrink': 1000, 'similarity': 'jaccard', 'normalize': True}
# Similarity column 24507 (100.0%), 3689.28 column/sec. Elapsed time 6.64 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.27 min. Users per second: 547
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 1013, 'shrink': 1000, 'similarity': 'jaccard', 'normalize': True} - results: PRECISION: 0.0405150, PRECISION_RECALL_MIN_DEN: 0.0678318, RECALL: 0.0642542, MAP: 0.0191302, MAP_MIN_DEN: 0.0316382, MRR: 0.1392744, NDCG: 0.0656951, F1: 0.0496951, HIT_RATE: 0.2929448, ARHR_ALL_HITS: 0.1623524, NOVELTY: 0.0039391, AVERAGE_POPULARITY: 0.2810227, DIVERSITY_MEAN_INTER_LIST: 0.8411259, DIVERSITY_HERFINDAHL: 0.9841106, COVERAGE_ITEM: 0.1230669, COVERAGE_ITEM_HIT: 0.0231362, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2929448, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0062006, SHANNON_ENTROPY: 7.1183374, RATIO_DIVERSITY_HERFINDAHL: 0.9844355, RATIO_DIVERSITY_GINI: 0.0121890, RATIO_SHANNON_ENTROPY: 0.5275230, RATIO_AVERAGE_POPULARITY: 5.5530609, RATIO_NOVELTY: 0.2253677,
#
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 85.0686
# Function value obtained: -0.0191
# Current minimum: -0.0207
# Iteration No: 11 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 149, 'shrink': 132, 'similarity': 'cosine', 'normalize': False}
# Similarity column 24507 (100.0%), 4231.67 column/sec. Elapsed time 5.79 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.04 min. Users per second: 665
# SearchBayesianSkopt: Config 10 is suboptimal. Config: {'topK': 149, 'shrink': 132, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0341325, PRECISION_RECALL_MIN_DEN: 0.0585457, RECALL: 0.0556975, MAP: 0.0153144, MAP_MIN_DEN: 0.0262449, MRR: 0.1175768, NDCG: 0.0555091, F1: 0.0423265, HIT_RATE: 0.2603714, ARHR_ALL_HITS: 0.1336401, NOVELTY: 0.0037356, AVERAGE_POPULARITY: 0.3824370, DIVERSITY_MEAN_INTER_LIST: 0.6626839, DIVERSITY_HERFINDAHL: 0.9662668, COVERAGE_ITEM: 0.1727670, COVERAGE_ITEM_HIT: 0.0184029, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2603714, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0058247, SHANNON_ENTROPY: 6.1580483, RATIO_DIVERSITY_HERFINDAHL: 0.9665858, RATIO_DIVERSITY_GINI: 0.0114500, RATIO_SHANNON_ENTROPY: 0.4563583, RATIO_AVERAGE_POPULARITY: 7.5570265, RATIO_NOVELTY: 0.2137279,
#
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 69.7667
# Function value obtained: -0.0153
# Current minimum: -0.0207
# Iteration No: 12 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 31, 'shrink': 1000, 'similarity': 'cosine', 'normalize': False}
# Similarity column 24507 (100.0%), 4143.19 column/sec. Elapsed time 5.92 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 53.50 sec. Users per second: 778
# SearchBayesianSkopt: Config 11 is suboptimal. Config: {'topK': 31, 'shrink': 1000, 'similarity': 'cosine', 'normalize': False} - results: PRECISION: 0.0359509, PRECISION_RECALL_MIN_DEN: 0.0605944, RECALL: 0.0575539, MAP: 0.0165998, MAP_MIN_DEN: 0.0279052, MRR: 0.1246246, NDCG: 0.0584374, F1: 0.0442569, HIT_RATE: 0.2672176, ARHR_ALL_HITS: 0.1431877, NOVELTY: 0.0039306, AVERAGE_POPULARITY: 0.3135885, DIVERSITY_MEAN_INTER_LIST: 0.7972190, DIVERSITY_HERFINDAHL: 0.9797200, COVERAGE_ITEM: 0.3075856, COVERAGE_ITEM_HIT: 0.0241564, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2672176, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0150684, SHANNON_ENTROPY: 7.2675287, RATIO_DIVERSITY_HERFINDAHL: 0.9800434, RATIO_DIVERSITY_GINI: 0.0296208, RATIO_SHANNON_ENTROPY: 0.5385792, RATIO_AVERAGE_POPULARITY: 6.1965678, RATIO_NOVELTY: 0.2248856,
#
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 60.2541
# Function value obtained: -0.0166
# Current minimum: -0.0207
# Iteration No: 13 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1968, 'shrink': 528, 'similarity': 'jaccard', 'normalize': True}
# Similarity column 24507 (100.0%), 3683.95 column/sec. Elapsed time 6.65 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.17 min. Users per second: 594
# SearchBayesianSkopt: Config 12 is suboptimal. Config: {'topK': 1968, 'shrink': 528, 'similarity': 'jaccard', 'normalize': True} - results: PRECISION: 0.0412981, PRECISION_RECALL_MIN_DEN: 0.0688141, RECALL: 0.0651639, MAP: 0.0195286, MAP_MIN_DEN: 0.0322984, MRR: 0.1415059, NDCG: 0.0668389, F1: 0.0505560, HIT_RATE: 0.2967162, ARHR_ALL_HITS: 0.1653155, NOVELTY: 0.0040182, AVERAGE_POPULARITY: 0.2529172, DIVERSITY_MEAN_INTER_LIST: 0.8707193, DIVERSITY_HERFINDAHL: 0.9870698, COVERAGE_ITEM: 0.1339617, COVERAGE_ITEM_HIT: 0.0266454, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2967162, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0077101, SHANNON_ENTROPY: 7.4508262, RATIO_DIVERSITY_HERFINDAHL: 0.9873957, RATIO_DIVERSITY_GINI: 0.0151562, RATIO_SHANNON_ENTROPY: 0.5521630, RATIO_AVERAGE_POPULARITY: 4.9976920, RATIO_NOVELTY: 0.2298974,
#
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 79.5697
# Function value obtained: -0.0195
# Current minimum: -0.0207
# Iteration No: 14 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 35, 'shrink': 678, 'similarity': 'jaccard', 'normalize': False}
# Similarity column 24507 (100.0%), 3962.82 column/sec. Elapsed time 6.18 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 39.52 sec. Users per second: 1053
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'topK': 35, 'shrink': 678, 'similarity': 'jaccard', 'normalize': False} - results: PRECISION: 0.0430229, PRECISION_RECALL_MIN_DEN: 0.0712221, RECALL: 0.0674281, MAP: 0.0205668, MAP_MIN_DEN: 0.0337666, MRR: 0.1473057, NDCG: 0.0695779, F1: 0.0525292, HIT_RATE: 0.3053160, ARHR_ALL_HITS: 0.1730953, NOVELTY: 0.0041303, AVERAGE_POPULARITY: 0.2262178, DIVERSITY_MEAN_INTER_LIST: 0.9091223, DIVERSITY_HERFINDAHL: 0.9909100, COVERAGE_ITEM: 0.2179377, COVERAGE_ITEM_HIT: 0.0357449, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3053160, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0138765, SHANNON_ENTROPY: 8.1395833, RATIO_DIVERSITY_HERFINDAHL: 0.9912372, RATIO_DIVERSITY_GINI: 0.0272779, RATIO_SHANNON_ENTROPY: 0.6032051, RATIO_AVERAGE_POPULARITY: 4.4701063, RATIO_NOVELTY: 0.2363076,
#
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 46.6878
# Function value obtained: -0.0206
# Current minimum: -0.0207
# Iteration No: 15 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'shrink': 0, 'similarity': 'jaccard', 'normalize': False}
# Similarity column 24507 (100.0%), 4057.21 column/sec. Elapsed time 6.04 sec
# EvaluatorHoldout: Processed 41629 (100.0%) in 30.92 sec. Users per second: 1346
# SearchBayesianSkopt: New best config found. Config 14: {'topK': 5, 'shrink': 0, 'similarity': 'jaccard', 'normalize': False} - results: PRECISION: 0.0442576, PRECISION_RECALL_MIN_DEN: 0.0714296, RECALL: 0.0673620, MAP: 0.0207906, MAP_MIN_DEN: 0.0335615, MRR: 0.1463144, NDCG: 0.0696453, F1: 0.0534186, HIT_RATE: 0.3084869, ARHR_ALL_HITS: 0.1734920, NOVELTY: 0.0046323, AVERAGE_POPULARITY: 0.1497023, DIVERSITY_MEAN_INTER_LIST: 0.9634204, DIVERSITY_HERFINDAHL: 0.9963397, COVERAGE_ITEM: 0.4395887, COVERAGE_ITEM_HIT: 0.0685926, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3084869, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0537760, SHANNON_ENTROPY: 10.0271503, RATIO_DIVERSITY_HERFINDAHL: 0.9966687, RATIO_DIVERSITY_GINI: 0.1057108, RATIO_SHANNON_ENTROPY: 0.7430882, RATIO_AVERAGE_POPULARITY: 2.9581455, RATIO_NOVELTY: 0.2650285,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNCFRecommender_implicit/ItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender_implicit/ItemKNNCFRecommender_best_model'
# ItemKNNCFRecommender: Saving complete
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 38.2958
# Function value obtained: -0.0208
# Current minimum: -0.0208
# SearchBayesianSkopt: Search complete. Best config is 14: {'topK': 5, 'shrink': 0, 'similarity': 'jaccard', 'normalize': False}

# %%
from Recommenders.DataIO import DataIO

data_loader = DataIO(folder_path=output_folder_path)
search_metadata = data_loader.load_data(
    recommender_class.RECOMMENDER_NAME + "_metadata.zip"
)

result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#           PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#    cutoff
# 0  10      0.042403                 0.071091  0.067341  0.020241    0.033593
# 1  10      0.033791                 0.058068  0.055263  0.015093    0.025858
# 2  10      0.041973                 0.069835  0.066111  0.019853    0.032771
# 3  10      0.039028                 0.066171  0.062823  0.018314    0.030748
# 4  10       0.04045                 0.067661  0.064087  0.019115    0.031608
# 5  10        0.0396                 0.067073  0.063666  0.018663    0.031321
# 6  10      0.042977                 0.071012  0.067313   0.02029    0.033359
# 7  10      0.042972                  0.07094  0.067236  0.020286    0.033322
# 8  10      0.043422                 0.071966  0.068142  0.020684    0.034069
# 9  10      0.040515                 0.067832  0.064254   0.01913    0.031638
# 10 10      0.034132                 0.058546  0.055697  0.015314    0.026245
# 11 10      0.035951                 0.060594  0.057554    0.0166    0.027905
# 12 10      0.041298                 0.068814  0.065164  0.019529    0.032298
# 13 10      0.043023                 0.071222  0.067428  0.020567    0.033767
# 14 10      0.044258                  0.07143  0.067362  0.020791    0.033562
#
#                 MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#    cutoff                                                        ...
# 0  10      0.146178  0.069152  0.052039  0.303707      0.171052  ...
# 1  10      0.116139  0.054854  0.041939   0.25881      0.131856  ...
# 2  10      0.143189  0.067799  0.051347  0.300824       0.16768  ...
# 3  10      0.135537  0.063867  0.048146  0.286459      0.156759  ...
# 4  10      0.139098  0.065598  0.049596   0.29232      0.162202  ...
# 5  10      0.137703  0.064883  0.048829  0.289438      0.159492  ...
# 6  10      0.144969  0.068983   0.05246  0.305844      0.170606  ...
# 7  10      0.144864  0.068923  0.052433    0.3057      0.170532  ...
# 8  10      0.148106  0.070168  0.053043  0.308991      0.174015  ...
# 9  10      0.139274  0.065695  0.049695  0.292945      0.162352  ...
# 10 10      0.117577  0.055509  0.042326  0.260371       0.13364  ...
# 11 10      0.124625  0.058437  0.044257  0.267218      0.143188  ...
# 12 10      0.141506  0.066839  0.050556  0.296716      0.165315  ...
# 13 10      0.147306  0.069578  0.052529  0.305316      0.173095  ...
# 14 10      0.146314  0.069645  0.053419  0.308487      0.173492  ...
#
#           COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#    cutoff
# 0  10               1.0          0.303707         1.0       0.006901
# 1  10               1.0           0.25881         1.0       0.005176
# 2  10               1.0          0.300824         1.0       0.009603
# 3  10               1.0          0.286459         1.0       0.004223
# 4  10               1.0           0.29232         1.0       0.006159
# 5  10               1.0          0.289438         1.0        0.00398
# 6  10               1.0          0.305844         1.0       0.028359
# 7  10               1.0            0.3057         1.0       0.028676
# 8  10               1.0          0.308991         1.0       0.015208
# 9  10               1.0          0.292945         1.0       0.006201
# 10 10               1.0          0.260371         1.0       0.005825
# 11 10               1.0          0.267218         1.0       0.015068
# 12 10               1.0          0.296716         1.0        0.00771
# 13 10               1.0          0.305316         1.0       0.013876
# 14 10               1.0          0.308487         1.0       0.053776
#
#           SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#    cutoff
# 0  10            7.193678                   0.983656             0.013566
# 1  10            6.039486                   0.964929             0.010175
# 2  10            7.727774                   0.989133             0.018877
# 3  10            6.479268                   0.975637             0.008302
# 4  10            7.115314                   0.984453             0.012107
# 5  10            6.495305                   0.976352             0.007825
# 6  10            8.812486                   0.992994             0.055747
# 7  10            8.819562                   0.993009              0.05637
# 8  10            8.280592                   0.991543             0.029895
# 9  10            7.118337                   0.984435             0.012189
# 10 10            6.158048                   0.966586              0.01145
# 11 10            7.267529                   0.980043             0.029621
# 12 10            7.450826                   0.987396             0.015156
# 13 10            8.139583                   0.991237             0.027278
# 14 10            10.02715                   0.996669             0.105711
#
#           RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#    cutoff
# 0  10                  0.533106                 5.784731      0.226022
# 1  10                  0.447572                 7.697395      0.212611
# 2  10                  0.572687                  4.63696      0.233681
# 3  10                  0.480163                  6.82701      0.217355
# 4  10                  0.527299                 5.549101      0.225353
# 5  10                  0.481352                 6.765647      0.217703
# 6  10                  0.653072                 3.679318      0.250827
# 7  10                  0.653597                 3.668886      0.251032
# 8  10                  0.613655                  4.11324      0.241297
# 9  10                  0.527523                 5.553061      0.225368
# 10 10                  0.456358                 7.557026      0.213728
# 11 10                  0.538579                 6.196568      0.224886
# 12 10                  0.552163                 4.997692      0.229897
# 13 10                  0.603205                 4.470106      0.236308
# 14 10                  0.743088                 2.958145      0.265028
#
# [15 rows x 27 columns]

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#     topK shrink similarity normalize
# 0    594    913     cosine     False
# 1    624    959     cosine     False
# 2   1508    200     cosine     False
# 3    603     17     cosine      True
# 4    819    358     cosine     False
# 5   1218    732     cosine     False
# 6   1296     34     cosine     False
# 7    530    259     cosine      True
# 8   1043    418     cosine      True
# 9   2000      0     cosine      True
# 10   500      0     cosine      True
# 11   500      0     cosine      True
# 12   503    999     cosine      True
# 13  1818    421     cosine     False
# 14   735    907     cosine      True
# 15   628    963     cosine     False
# 16  1593    589     cosine     False
# 17   698    614     cosine     False
# 18  1617    726     cosine     False
# 19   806      0     cosine      True
# 20   500      0     cosine      True
# 21   500      0     cosine      True
# 22  1996    988     cosine      True
# 23   757    653     cosine     False
# 24  1642    920     cosine      True
# 25  1567    619     cosine      True
# 26   501    307     cosine      True
# 27  1458    634     cosine     False
# 28   500      0     cosine      True
# 29   500      0     cosine      True

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'topK': 500, 'shrink': 0, 'similarity': 'cosine', 'normalize': True}

# %%
exception_list = search_metadata["exception_list"]
exception_list
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
recommender = recommender_class(URM_all)
recommender.fit(**best_hyperparameters)
recommender.save_model(
    folder_path=output_folder_path,
    file_name=recommender_class.RECOMMENDER_NAME
    + "_best_model_trained_on_everything.zip",
)
# Out:
# Similarity column 24507 (100.0%), 3450.89 column/sec. Elapsed time 7.10 sec
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender/ItemKNNCFRecommender_best_model_trained_on_everything.zip'
# ItemKNNCFRecommender: Saving complete

# %%
from utils.create_submission import create_submission

create_submission(recommender)
