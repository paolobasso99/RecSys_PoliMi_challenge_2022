# %%
import os
import random

import numpy as np
import pandas as pd
import scipy.sparse as sps
import matplotlib.pyplot as plt
import seaborn as snb

# Random seed for reproducibility
SEED = 42
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)

# %%
from data_manager import DatasetLoader, DatasetSplitter, URMGenerator

dataset_loader = DatasetLoader()
dataset_splitter = DatasetSplitter(dataset_loader)
dataset_train, dataset_val = dataset_splitter.load_train_val()
URM_generator = URMGenerator(dataset_train, dataset_val)
URM_train, URM_val = URM_generator.generate_explicit_URM()
URM_all = URM_train + URM_val
# Out:
# Loading previusly generated splits...
# Generating explicit URM...

# %%
from evaluation.evaluator import EvaluatorHoldout

evaluator = EvaluatorHoldout(URM_val, cutoff_list=[10])

# %%
from Recommenders.EASE_R.EASE_R_Recommender import (
    EASE_R_Recommender,
)
from skopt.space import Real, Integer, Categorical
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

output_folder_path = "result_experiments/EASE_R_Recommender/"
recommender_class = EASE_R_Recommender
n_cases = 10
n_random_starts = int(n_cases * 0.3)
metric_to_optimize = "MAP"
cutoff_to_optimize = 10

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Define hyperparameters
hyperparameters_range_dictionary = {
    "topK": Categorical([None]),
    "normalize_matrix": Categorical([False]),
    "l2_norm": Real(low=1e0, high=1e7, prior="log-uniform"),
}

hyperparameter_search = SearchBayesianSkopt(
    recommender_class,
    evaluator_validation=evaluator,
)

recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS=[
        URM_train,
    ],
    CONSTRUCTOR_KEYWORD_ARGS={},
    FIT_POSITIONAL_ARGS=[],
    FIT_KEYWORD_ARGS={},
    EARLYSTOPPING_KEYWORD_ARGS={},
)

# %%
hyperparameter_search.search(
    recommender_input_args,
    hyperparameter_search_space=hyperparameters_range_dictionary,
    n_cases=n_cases,
    n_random_starts=n_random_starts,
    save_model="best",
    output_folder_path=output_folder_path,  # Where to save the results
    output_file_name_root=recommender_class.RECOMMENDER_NAME,  # How to call the files
    metric_to_optimize=metric_to_optimize,
    cutoff_to_optimize=cutoff_to_optimize,
)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 79.26401388961496}
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 10.39 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.00 min. Users per second: 693
# SearchBayesianSkopt: New best config found. Config 0: {'topK': None, 'normalize_matrix': False, 'l2_norm': 79.26401388961496} - results: PRECISION: 0.0488938, PRECISION_RECALL_MIN_DEN: 0.0797064, RECALL: 0.0752914, MAP: 0.0238613, MAP_MIN_DEN: 0.0383330, MRR: 0.1648978, NDCG: 0.0885390, F1: 0.0592870, HIT_RATE: 0.3333493, ARHR_ALL_HITS: 0.1972497, NOVELTY: 0.0042001, AVERAGE_POPULARITY: 0.2140285, DIVERSITY_MEAN_INTER_LIST: 0.9252907, DIVERSITY_HERFINDAHL: 0.9925268, COVERAGE_ITEM: 0.1249031, COVERAGE_ITEM_HIT: 0.0514547, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3333493, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0138832, SHANNON_ENTROPY: 8.4378273, RATIO_DIVERSITY_HERFINDAHL: 0.9928545, RATIO_DIVERSITY_GINI: 0.0272911, RATIO_SHANNON_ENTROPY: 0.6253073, RATIO_AVERAGE_POPULARITY: 4.2292437, RATIO_NOVELTY: 0.2403023,
#
# SearchBayesianSkopt: Saving model in result_experiments/EASE_R_Recommender/EASE_R_Recommender
#
# EASE_R_Recommender: Saving model in file 'result_experiments/EASE_R_Recommender/EASE_R_Recommender_best_model'
# EASE_R_Recommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 856.6790
# Function value obtained: -0.0239
# Current minimum: -0.0239
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 31.030268299655944}
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 8.48 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.10 min. Users per second: 629
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 31.030268299655944} - results: PRECISION: 0.0476567, PRECISION_RECALL_MIN_DEN: 0.0768919, RECALL: 0.0725172, MAP: 0.0233095, MAP_MIN_DEN: 0.0371896, MRR: 0.1610426, NDCG: 0.0860871, F1: 0.0575155, HIT_RATE: 0.3252781, ARHR_ALL_HITS: 0.1927198, NOVELTY: 0.0042143, AVERAGE_POPULARITY: 0.2099213, DIVERSITY_MEAN_INTER_LIST: 0.9285802, DIVERSITY_HERFINDAHL: 0.9928558, COVERAGE_ITEM: 0.1313094, COVERAGE_ITEM_HIT: 0.0575754, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3252781, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0149370, SHANNON_ENTROPY: 8.5164771, RATIO_DIVERSITY_HERFINDAHL: 0.9931836, RATIO_DIVERSITY_GINI: 0.0293626, RATIO_SHANNON_ENTROPY: 0.6311358, RATIO_AVERAGE_POPULARITY: 4.1480853, RATIO_NOVELTY: 0.2411175,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 579.0245
# Function value obtained: -0.0233
# Current minimum: -0.0239
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 1.2894245605808734}
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 8.68 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.21 min. Users per second: 574
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 1.2894245605808734} - results: PRECISION: 0.0348363, PRECISION_RECALL_MIN_DEN: 0.0544128, RECALL: 0.0510368, MAP: 0.0163289, MAP_MIN_DEN: 0.0253142, MRR: 0.1184255, NDCG: 0.0610920, F1: 0.0414084, HIT_RATE: 0.2515554, ARHR_ALL_HITS: 0.1384333, NOVELTY: 0.0041575, AVERAGE_POPULARITY: 0.2098604, DIVERSITY_MEAN_INTER_LIST: 0.9284271, DIVERSITY_HERFINDAHL: 0.9928405, COVERAGE_ITEM: 0.1700739, COVERAGE_ITEM_HIT: 0.0524340, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2515554, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0126029, SHANNON_ENTROPY: 8.2899240, RATIO_DIVERSITY_HERFINDAHL: 0.9931683, RATIO_DIVERSITY_GINI: 0.0247743, RATIO_SHANNON_ENTROPY: 0.6143465, RATIO_AVERAGE_POPULARITY: 4.1468817, RATIO_NOVELTY: 0.2378640,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 600.5332
# Function value obtained: -0.0163
# Current minimum: -0.0239
# Iteration No: 4 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 4482.123796932504}
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 9.05 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.04 min. Users per second: 666
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 4482.123796932504} - results: PRECISION: 0.0392467, PRECISION_RECALL_MIN_DEN: 0.0664158, RECALL: 0.0631390, MAP: 0.0183388, MAP_MIN_DEN: 0.0305227, MRR: 0.1354492, NDCG: 0.0702343, F1: 0.0484051, HIT_RATE: 0.2885248, ARHR_ALL_HITS: 0.1569094, NOVELTY: 0.0038497, AVERAGE_POPULARITY: 0.3190080, DIVERSITY_MEAN_INTER_LIST: 0.7888840, DIVERSITY_HERFINDAHL: 0.9788865, COVERAGE_ITEM: 0.0693679, COVERAGE_ITEM_HIT: 0.0199127, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2885248, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0041188, SHANNON_ENTROPY: 6.6906341, RATIO_DIVERSITY_HERFINDAHL: 0.9792097, RATIO_DIVERSITY_GINI: 0.0080966, RATIO_SHANNON_ENTROPY: 0.4958269, RATIO_AVERAGE_POPULARITY: 6.3036582, RATIO_NOVELTY: 0.2202563,
#
# Iteration No: 4 ended. Search finished for the next optimal point.
# Time taken: 614.4970
# Function value obtained: -0.0183
# Current minimum: -0.0239
# Iteration No: 5 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 9999656.678601524}
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 8.98 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 59.41 sec. Users per second: 701
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 9999656.678601524} - results: PRECISION: 0.0307766, PRECISION_RECALL_MIN_DEN: 0.0538256, RECALL: 0.0514116, MAP: 0.0133835, MAP_MIN_DEN: 0.0230762, MRR: 0.1045228, NDCG: 0.0535299, F1: 0.0385037, HIT_RATE: 0.2407216, ARHR_ALL_HITS: 0.1178611, NOVELTY: 0.0035830, AVERAGE_POPULARITY: 0.4343571, DIVERSITY_MEAN_INTER_LIST: 0.4943895, DIVERSITY_HERFINDAHL: 0.9494378, COVERAGE_ITEM: 0.0289713, COVERAGE_ITEM_HIT: 0.0097523, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2407216, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0011896, SHANNON_ENTROPY: 5.0228165, RATIO_DIVERSITY_HERFINDAHL: 0.9497512, RATIO_DIVERSITY_GINI: 0.0023385, RATIO_SHANNON_ENTROPY: 0.3722290, RATIO_AVERAGE_POPULARITY: 8.5829790, RATIO_NOVELTY: 0.2049986,
#
# Iteration No: 5 ended. Search finished for the next optimal point.
# Time taken: 608.0016
# Function value obtained: -0.0134
# Current minimum: -0.0239
# Iteration No: 6 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 167435.05136725985}
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 8.59 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 58.01 sec. Users per second: 718
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 167435.05136725985} - results: PRECISION: 0.0313099, PRECISION_RECALL_MIN_DEN: 0.0547192, RECALL: 0.0522662, MAP: 0.0137205, MAP_MIN_DEN: 0.0236407, MRR: 0.1068595, NDCG: 0.0547133, F1: 0.0391607, HIT_RATE: 0.2440126, ARHR_ALL_HITS: 0.1206548, NOVELTY: 0.0035959, AVERAGE_POPULARITY: 0.4286095, DIVERSITY_MEAN_INTER_LIST: 0.5145916, DIVERSITY_HERFINDAHL: 0.9514579, COVERAGE_ITEM: 0.0308483, COVERAGE_ITEM_HIT: 0.0105684, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2440126, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0012862, SHANNON_ENTROPY: 5.1189952, RATIO_DIVERSITY_HERFINDAHL: 0.9517721, RATIO_DIVERSITY_GINI: 0.0025283, RATIO_SHANNON_ENTROPY: 0.3793565, RATIO_AVERAGE_POPULARITY: 8.4694044, RATIO_NOVELTY: 0.2057350,
#
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 582.4325
# Function value obtained: -0.0137
# Current minimum: -0.0239
# Iteration No: 7 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 227.1869395168621}
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 8.50 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 55.81 sec. Users per second: 746
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 227.1869395168621} - results: PRECISION: 0.0481635, PRECISION_RECALL_MIN_DEN: 0.0790631, RECALL: 0.0747851, MAP: 0.0234122, MAP_MIN_DEN: 0.0378239, MRR: 0.1635148, NDCG: 0.0872707, F1: 0.0585922, HIT_RATE: 0.3314997, ARHR_ALL_HITS: 0.1946133, NOVELTY: 0.0041517, AVERAGE_POPULARITY: 0.2244056, DIVERSITY_MEAN_INTER_LIST: 0.9163440, DIVERSITY_HERFINDAHL: 0.9916322, COVERAGE_ITEM: 0.1170278, COVERAGE_ITEM_HIT: 0.0416208, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3314997, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0115997, SHANNON_ENTROPY: 8.2089053, RATIO_DIVERSITY_HERFINDAHL: 0.9919596, RATIO_DIVERSITY_GINI: 0.0228022, RATIO_SHANNON_ENTROPY: 0.6083424, RATIO_AVERAGE_POPULARITY: 4.4342960, RATIO_NOVELTY: 0.2375324,
#
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 570.9323
# Function value obtained: -0.0234
# Current minimum: -0.0239
# Iteration No: 8 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 1497062.0808039242}
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 8.55 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 56.52 sec. Users per second: 737
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 1497062.0808039242} - results: PRECISION: 0.0308199, PRECISION_RECALL_MIN_DEN: 0.0538890, RECALL: 0.0514712, MAP: 0.0134189, MAP_MIN_DEN: 0.0231275, MRR: 0.1048056, NDCG: 0.0536362, F1: 0.0385543, HIT_RATE: 0.2410099, ARHR_ALL_HITS: 0.1181791, NOVELTY: 0.0035843, AVERAGE_POPULARITY: 0.4338065, DIVERSITY_MEAN_INTER_LIST: 0.4962869, DIVERSITY_HERFINDAHL: 0.9496275, COVERAGE_ITEM: 0.0290529, COVERAGE_ITEM_HIT: 0.0098339, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2410099, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0011980, SHANNON_ENTROPY: 5.0319035, RATIO_DIVERSITY_HERFINDAHL: 0.9499410, RATIO_DIVERSITY_GINI: 0.0023550, RATIO_SHANNON_ENTROPY: 0.3729024, RATIO_AVERAGE_POPULARITY: 8.5720983, RATIO_NOVELTY: 0.2050685,
#
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 576.2612
# Function value obtained: -0.0134
# Current minimum: -0.0239
# Iteration No: 9 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 96.03676978129798}
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 8.03 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.02 min. Users per second: 679
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 96.03676978129798} - results: PRECISION: 0.0489082, PRECISION_RECALL_MIN_DEN: 0.0798146, RECALL: 0.0754186, MAP: 0.0238378, MAP_MIN_DEN: 0.0383396, MRR: 0.1650542, NDCG: 0.0885575, F1: 0.0593370, HIT_RATE: 0.3338778, ARHR_ALL_HITS: 0.1972663, NOVELTY: 0.0041942, AVERAGE_POPULARITY: 0.2153537, DIVERSITY_MEAN_INTER_LIST: 0.9241909, DIVERSITY_HERFINDAHL: 0.9924169, COVERAGE_ITEM: 0.1240054, COVERAGE_ITEM_HIT: 0.0495369, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3338778, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0135630, SHANNON_ENTROPY: 8.4093277, RATIO_DIVERSITY_HERFINDAHL: 0.9927445, RATIO_DIVERSITY_GINI: 0.0266615, RATIO_SHANNON_ENTROPY: 0.6231952, RATIO_AVERAGE_POPULARITY: 4.2554304, RATIO_NOVELTY: 0.2399648,
#
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 547.1131
# Function value obtained: -0.0238
# Current minimum: -0.0239
# Iteration No: 10 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 151652.0254240179}
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 7.95 min
# EvaluatorHoldout: Processed 41629 (100.0%) in 56.34 sec. Users per second: 739
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': None, 'normalize_matrix': False, 'l2_norm': 151652.0254240179} - results: PRECISION: 0.0313459, PRECISION_RECALL_MIN_DEN: 0.0547892, RECALL: 0.0523350, MAP: 0.0137463, MAP_MIN_DEN: 0.0236728, MRR: 0.1070418, NDCG: 0.0548023, F1: 0.0392082, HIT_RATE: 0.2442768, ARHR_ALL_HITS: 0.1208719, NOVELTY: 0.0035972, AVERAGE_POPULARITY: 0.4280318, DIVERSITY_MEAN_INTER_LIST: 0.5166055, DIVERSITY_HERFINDAHL: 0.9516593, COVERAGE_ITEM: 0.0310932, COVERAGE_ITEM_HIT: 0.0107316, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2442768, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0012965, SHANNON_ENTROPY: 5.1287182, RATIO_DIVERSITY_HERFINDAHL: 0.9519735, RATIO_DIVERSITY_GINI: 0.0025486, RATIO_SHANNON_ENTROPY: 0.3800771, RATIO_AVERAGE_POPULARITY: 8.4579890, RATIO_NOVELTY: 0.2058099,
#
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 543.4609
# Function value obtained: -0.0137
# Current minimum: -0.0239
# SearchBayesianSkopt: Search complete. Best config is 0: {'topK': None, 'normalize_matrix': False, 'l2_norm': 79.26401388961496}

# %%
from Recommenders.DataIO import DataIO

data_loader = DataIO(folder_path=output_folder_path)
search_metadata = data_loader.load_data(
    recommender_class.RECOMMENDER_NAME + "_metadata.zip"
)

result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#          PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#   cutoff
# 0 10      0.048894                 0.079706  0.075291  0.023861    0.038333
# 1 10      0.047657                 0.076892  0.072517  0.023309     0.03719
# 2 10      0.034836                 0.054413  0.051037  0.016329    0.025314
# 3 10      0.039247                 0.066416  0.063139  0.018339    0.030523
# 4 10      0.030777                 0.053826  0.051412  0.013383    0.023076
# 5 10       0.03131                 0.054719  0.052266  0.013721    0.023641
# 6 10      0.048164                 0.079063  0.074785  0.023412    0.037824
# 7 10       0.03082                 0.053889  0.051471  0.013419    0.023128
# 8 10      0.048908                 0.079815  0.075419  0.023838     0.03834
# 9 10      0.031346                 0.054789  0.052335  0.013746    0.023673
#
#                MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#   cutoff                                                        ...
# 0 10      0.164898  0.088539  0.059287  0.333349       0.19725  ...
# 1 10      0.161043  0.086087  0.057515  0.325278       0.19272  ...
# 2 10      0.118425  0.061092  0.041408  0.251555      0.138433  ...
# 3 10      0.135449  0.070234  0.048405  0.288525      0.156909  ...
# 4 10      0.104523   0.05353  0.038504  0.240722      0.117861  ...
# 5 10      0.106859  0.054713  0.039161  0.244013      0.120655  ...
# 6 10      0.163515  0.087271  0.058592    0.3315      0.194613  ...
# 7 10      0.104806  0.053636  0.038554   0.24101      0.118179  ...
# 8 10      0.165054  0.088558  0.059337  0.333878      0.197266  ...
# 9 10      0.107042  0.054802  0.039208  0.244277      0.120872  ...
#
#          COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#   cutoff
# 0 10               1.0          0.333349         1.0       0.013883
# 1 10               1.0          0.325278         1.0       0.014937
# 2 10               1.0          0.251555         1.0       0.012603
# 3 10               1.0          0.288525         1.0       0.004119
# 4 10               1.0          0.240722         1.0        0.00119
# 5 10               1.0          0.244013         1.0       0.001286
# 6 10               1.0            0.3315         1.0         0.0116
# 7 10               1.0           0.24101         1.0       0.001198
# 8 10               1.0          0.333878         1.0       0.013563
# 9 10               1.0          0.244277         1.0       0.001296
#
#          SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#   cutoff
# 0 10            8.437827                   0.992855             0.027291
# 1 10            8.516477                   0.993184             0.029363
# 2 10            8.289924                   0.993168             0.024774
# 3 10            6.690634                    0.97921             0.008097
# 4 10            5.022816                   0.949751             0.002338
# 5 10            5.118995                   0.951772             0.002528
# 6 10            8.208905                    0.99196             0.022802
# 7 10            5.031903                   0.949941             0.002355
# 8 10            8.409328                   0.992745             0.026662
# 9 10            5.128718                   0.951973             0.002549
#
#          RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#   cutoff
# 0 10                  0.625307                 4.229244      0.240302
# 1 10                  0.631136                 4.148085      0.241117
# 2 10                  0.614347                 4.146882      0.237864
# 3 10                  0.495827                 6.303658      0.220256
# 4 10                  0.372229                 8.582979      0.204999
# 5 10                  0.379357                 8.469404      0.205735
# 6 10                  0.608342                 4.434296      0.237532
# 7 10                  0.372902                 8.572098      0.205068
# 8 10                  0.623195                  4.25543      0.239965
# 9 10                  0.380077                 8.457989       0.20581
#
# [10 rows x 27 columns]

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#    topK normalize_matrix         l2_norm
# 0  None            False       79.264014
# 1  None            False       31.030268
# 2  None            False        1.289425
# 3  None            False     4482.123797
# 4  None            False  9999656.678602
# 5  None            False   167435.051367
# 6  None            False       227.18694
# 7  None            False  1497062.080804
# 8  None            False        96.03677
# 9  None            False   151652.025424

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'topK': None, 'normalize_matrix': False, 'l2_norm': 79.26401388961496}

# %%
exception_list = search_metadata["exception_list"]
exception_list
# Out:
# ['Traceback (most recent call last):\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 604, in _objective_function\n    result_df, recommender_instance = self._evaluate_on_validation(\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 395, in _evaluate_on_validation\n    self.model_counter: recommender_instance.get_validation_summary_table()\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\Recommenders\\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table\n    return self._earlystopping_validation_summary_df.copy()\nAttributeError: \'NoneType\' object has no attribute \'copy\'\n',
#  'Traceback (most recent call last):\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 604, in _objective_function\n    result_df, recommender_instance = self._evaluate_on_validation(\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 395, in _evaluate_on_validation\n    self.model_counter: recommender_instance.get_validation_summary_table()\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\Recommenders\\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table\n    return self._earlystopping_validation_summary_df.copy()\nAttributeError: \'NoneType\' object has no attribute \'copy\'\n',
#  'Traceback (most recent call last):\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 604, in _objective_function\n    result_df, recommender_instance = self._evaluate_on_validation(\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 395, in _evaluate_on_validation\n    self.model_counter: recommender_instance.get_validation_summary_table()\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\Recommenders\\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table\n    return self._earlystopping_validation_summary_df.copy()\nAttributeError: \'NoneType\' object has no attribute \'copy\'\n',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
recommender = recommender_class(URM_all)
recommender.fit(**best_hyperparameters)
recommender.save_model(
    folder_path=output_folder_path,
    file_name=recommender_class.RECOMMENDER_NAME
    + "_best_model_trained_on_everything.zip",
)
# Out:
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 8.01 min
# EASE_R_Recommender: Saving model in file 'result_experiments/EASE_R_Recommender/EASE_R_Recommender_best_model_trained_on_everything.zip'
# EASE_R_Recommender: Saving complete

# %%
from utils.create_submission import create_submission

create_submission(recommender)
