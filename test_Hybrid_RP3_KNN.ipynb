# %%
import os
import random

import numpy as np
import pandas as pd
import scipy.sparse as sps
import matplotlib.pyplot as plt
import seaborn as snb

# Random seed for reproducibility
SEED = 42
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)

# %%
from data_manager import DatasetLoader, DatasetSplitter, URMGenerator

dataset_loader = DatasetLoader()
dataset_splitter = DatasetSplitter(dataset_loader)
dataset_train, dataset_val = dataset_splitter.load_train_val()
URM_generator = URMGenerator(dataset_train, dataset_val)
URM_train, URM_val = URM_generator.generate_implicit_URM()
URM_all = URM_train + URM_val
# Out:
# Loading previusly generated splits...
# Generating implicit URM...

# %%
from evaluation.evaluator import EvaluatorHoldout

evaluator = EvaluatorHoldout(URM_val, cutoff_list=[10])

# %%
from Recommenders.KNN.ItemKNNSimilarityHybridRecommender import (
    ItemKNNSimilarityHybridRecommender,
)
from Recommenders.GraphBased.RP3betaRecommender import (
    RP3betaRecommender,
)
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from skopt.space import Real, Integer, Categorical
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

output_folder_path = "result_experiments/ItemKNNSimilarityHybridRecommender/"
recommender_class = ItemKNNSimilarityHybridRecommender
n_cases = 10
n_random_starts = int(n_cases * 0.3)
metric_to_optimize = "MAP"
cutoff_to_optimize = 10

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Define hyperparameters
hyperparameters_range_dictionary = {
    "topK": Integer(5, 2000),
    "alpha": Real(0.0, 1.0),
}

knn = ItemKNNCFRecommender(URM_train)
knn.load_model(
    folder_path="result_experiments/ItemKNNCFRecommender/",
    file_name=ItemKNNCFRecommender.RECOMMENDER_NAME + "_best_model.zip",
)
rp3 = RP3betaRecommender(URM_train)
rp3.load_model(
    folder_path="result_experiments/RP3betaRecommender/",
    file_name=RP3betaRecommender.RECOMMENDER_NAME + "_best_model.zip",
)

hyperparameter_search = SearchBayesianSkopt(
    recommender_class,
    evaluator_validation=evaluator,
)

recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS=[
        URM_train,
        knn.W_sparse,
        rp3.W_sparse,
    ],
    CONSTRUCTOR_KEYWORD_ARGS={},
    FIT_POSITIONAL_ARGS=[],
    FIT_KEYWORD_ARGS={},
    EARLYSTOPPING_KEYWORD_ARGS={},
)
# Out:
# ItemKNNCFRecommender: Loading model from file 'result_experiments/ItemKNNCFRecommender/ItemKNNCFRecommender_best_model.zip'
# ItemKNNCFRecommender: Loading complete
# RP3betaRecommender: Loading model from file 'result_experiments/RP3betaRecommender/RP3betaRecommender_best_model.zip'
# RP3betaRecommender: Loading complete

# %%
hyperparameter_search.search(
    recommender_input_args,
    hyperparameter_search_space=hyperparameters_range_dictionary,
    n_cases=n_cases,
    n_random_starts=n_random_starts,
    save_model="best",
    output_folder_path=output_folder_path,  # Where to save the results
    output_file_name_root=recommender_class.RECOMMENDER_NAME,  # How to call the files
    metric_to_optimize=metric_to_optimize,
    cutoff_to_optimize=cutoff_to_optimize,
)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 133, 'alpha': 0.19002161632387143}
# EvaluatorHoldout: Processed 41629 (100.0%) in 43.17 sec. Users per second: 964
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 133, 'alpha': 0.19002161632387143} - results: PRECISION: 0.0496457, PRECISION_RECALL_MIN_DEN: 0.0812767, RECALL: 0.0769279, MAP: 0.0241158, MAP_MIN_DEN: 0.0391318, MRR: 0.1662943, NDCG: 0.0796729, F1: 0.0603465, HIT_RATE: 0.3378414, ARHR_ALL_HITS: 0.1990715, NOVELTY: 0.0044821, AVERAGE_POPULARITY: 0.1731950, DIVERSITY_MEAN_INTER_LIST: 0.9511248, DIVERSITY_HERFINDAHL: 0.9951102, COVERAGE_ITEM: 0.5063043, COVERAGE_ITEM_HIT: 0.0594524, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3378414, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0431038, SHANNON_ENTROPY: 9.4703120, RATIO_DIVERSITY_HERFINDAHL: 0.9954387, RATIO_DIVERSITY_GINI: 0.0847317, RATIO_SHANNON_ENTROPY: 0.7018222, RATIO_AVERAGE_POPULARITY: 3.4223661, RATIO_NOVELTY: 0.2564380,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNSimilarityHybridRecommender/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/ItemKNNSimilarityHybridRecommender/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 56.8150
# Function value obtained: -0.0241
# Current minimum: -0.0241
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 264, 'alpha': 0.8614012111818585}
# EvaluatorHoldout: Processed 41629 (100.0%) in 54.68 sec. Users per second: 761
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'topK': 264, 'alpha': 0.8614012111818585} - results: PRECISION: 0.0453074, PRECISION_RECALL_MIN_DEN: 0.0741590, RECALL: 0.0701946, MAP: 0.0218868, MAP_MIN_DEN: 0.0354495, MRR: 0.1538395, NDCG: 0.0727943, F1: 0.0550698, HIT_RATE: 0.3151889, ARHR_ALL_HITS: 0.1825368, NOVELTY: 0.0044431, AVERAGE_POPULARITY: 0.1980556, DIVERSITY_MEAN_INTER_LIST: 0.9213757, DIVERSITY_HERFINDAHL: 0.9921354, COVERAGE_ITEM: 0.4756600, COVERAGE_ITEM_HIT: 0.0535357, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3151889, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0373865, SHANNON_ENTROPY: 9.0132777, RATIO_DIVERSITY_HERFINDAHL: 0.9924629, RATIO_DIVERSITY_GINI: 0.0734929, RATIO_SHANNON_ENTROPY: 0.6679525, RATIO_AVERAGE_POPULARITY: 3.9136163, RATIO_NOVELTY: 0.2542069,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 67.2105
# Function value obtained: -0.0219
# Current minimum: -0.0241
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 1103, 'alpha': 0.665046367288419}
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.12 min. Users per second: 621
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 1103, 'alpha': 0.665046367288419} - results: PRECISION: 0.0458454, PRECISION_RECALL_MIN_DEN: 0.0752961, RECALL: 0.0713075, MAP: 0.0222235, MAP_MIN_DEN: 0.0361415, MRR: 0.1564138, NDCG: 0.0740059, F1: 0.0558095, HIT_RATE: 0.3192486, ARHR_ALL_HITS: 0.1854535, NOVELTY: 0.0044032, AVERAGE_POPULARITY: 0.2058690, DIVERSITY_MEAN_INTER_LIST: 0.9167870, DIVERSITY_HERFINDAHL: 0.9916765, COVERAGE_ITEM: 0.4457910, COVERAGE_ITEM_HIT: 0.0521892, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3192486, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0341965, SHANNON_ENTROPY: 8.9020931, RATIO_DIVERSITY_HERFINDAHL: 0.9920039, RATIO_DIVERSITY_GINI: 0.0672221, RATIO_SHANNON_ENTROPY: 0.6597129, RATIO_AVERAGE_POPULARITY: 4.0680106, RATIO_NOVELTY: 0.2519262,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 85.8399
# Function value obtained: -0.0222
# Current minimum: -0.0241
# Iteration No: 4 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1879, 'alpha': 0.0}
# EvaluatorHoldout: Processed 41629 (100.0%) in 36.11 sec. Users per second: 1153
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 1879, 'alpha': 0.0} - results: PRECISION: 0.0492157, PRECISION_RECALL_MIN_DEN: 0.0793355, RECALL: 0.0749383, MAP: 0.0238603, MAP_MIN_DEN: 0.0383858, MRR: 0.1638211, NDCG: 0.0782670, F1: 0.0594123, HIT_RATE: 0.3329650, ARHR_ALL_HITS: 0.1965930, NOVELTY: 0.0047945, AVERAGE_POPULARITY: 0.1309941, DIVERSITY_MEAN_INTER_LIST: 0.9748266, DIVERSITY_HERFINDAHL: 0.9974803, COVERAGE_ITEM: 0.6590770, COVERAGE_ITEM_HIT: 0.0577794, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3329650, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0865826, SHANNON_ENTROPY: 10.5271398, RATIO_DIVERSITY_HERFINDAHL: 0.9978096, RATIO_DIVERSITY_GINI: 0.1702008, RATIO_SHANNON_ENTROPY: 0.7801412, RATIO_AVERAGE_POPULARITY: 2.5884673, RATIO_NOVELTY: 0.2743105,
#
# Iteration No: 4 ended. Search finished for the next optimal point.
# Time taken: 38.4013
# Function value obtained: -0.0239
# Current minimum: -0.0241
# Iteration No: 5 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1975, 'alpha': 0.2978363549941264}
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.13 min. Users per second: 613
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 1975, 'alpha': 0.2978363549941264} - results: PRECISION: 0.0487425, PRECISION_RECALL_MIN_DEN: 0.0800697, RECALL: 0.0758465, MAP: 0.0236228, MAP_MIN_DEN: 0.0384288, MRR: 0.1639016, NDCG: 0.0783870, F1: 0.0593463, HIT_RATE: 0.3345024, ARHR_ALL_HITS: 0.1956262, NOVELTY: 0.0044048, AVERAGE_POPULARITY: 0.1942581, DIVERSITY_MEAN_INTER_LIST: 0.9333809, DIVERSITY_HERFINDAHL: 0.9933358, COVERAGE_ITEM: 0.4617456, COVERAGE_ITEM_HIT: 0.0559840, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3345024, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0355102, SHANNON_ENTROPY: 9.1011685, RATIO_DIVERSITY_HERFINDAHL: 0.9936638, RATIO_DIVERSITY_GINI: 0.0698046, RATIO_SHANNON_ENTROPY: 0.6744659, RATIO_AVERAGE_POPULARITY: 3.8385760, RATIO_NOVELTY: 0.2520143,
#
# Iteration No: 5 ended. Search finished for the next optimal point.
# Time taken: 86.5257
# Function value obtained: -0.0236
# Current minimum: -0.0241
# Iteration No: 6 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'alpha': 0.0}
# EvaluatorHoldout: Processed 41629 (100.0%) in 35.20 sec. Users per second: 1183
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 5, 'alpha': 0.0} - results: PRECISION: 0.0411900, PRECISION_RECALL_MIN_DEN: 0.0656411, RECALL: 0.0618600, MAP: 0.0198113, MAP_MIN_DEN: 0.0318853, MRR: 0.1425575, NDCG: 0.0658948, F1: 0.0494520, HIT_RATE: 0.2925124, ARHR_ALL_HITS: 0.1673359, NOVELTY: 0.0052020, AVERAGE_POPULARITY: 0.0761019, DIVERSITY_MEAN_INTER_LIST: 0.9896699, DIVERSITY_HERFINDAHL: 0.9989646, COVERAGE_ITEM: 0.5828131, COVERAGE_ITEM_HIT: 0.0744277, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.2925124, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.1129255, SHANNON_ENTROPY: 11.4673346, RATIO_DIVERSITY_HERFINDAHL: 0.9992944, RATIO_DIVERSITY_GINI: 0.2219846, RATIO_SHANNON_ENTROPY: 0.8498168, RATIO_AVERAGE_POPULARITY: 1.5037887, RATIO_NOVELTY: 0.2976234,
#
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 37.1959
# Function value obtained: -0.0198
# Current minimum: -0.0241
# Iteration No: 7 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 173, 'alpha': 0.1876997879807723}
# EvaluatorHoldout: Processed 41629 (100.0%) in 44.33 sec. Users per second: 939
# SearchBayesianSkopt: New best config found. Config 6: {'topK': 173, 'alpha': 0.1876997879807723} - results: PRECISION: 0.0495736, PRECISION_RECALL_MIN_DEN: 0.0812774, RECALL: 0.0769513, MAP: 0.0241494, MAP_MIN_DEN: 0.0392028, MRR: 0.1665031, NDCG: 0.0797393, F1: 0.0603004, HIT_RATE: 0.3376733, ARHR_ALL_HITS: 0.1993668, NOVELTY: 0.0044738, AVERAGE_POPULARITY: 0.1754556, DIVERSITY_MEAN_INTER_LIST: 0.9496131, DIVERSITY_HERFINDAHL: 0.9949590, COVERAGE_ITEM: 0.5085894, COVERAGE_ITEM_HIT: 0.0588403, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3376733, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0429570, SHANNON_ENTROPY: 9.4404510, RATIO_DIVERSITY_HERFINDAHL: 0.9952875, RATIO_DIVERSITY_GINI: 0.0844432, RATIO_SHANNON_ENTROPY: 0.6996093, RATIO_AVERAGE_POPULARITY: 3.4670350, RATIO_NOVELTY: 0.2559614,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNSimilarityHybridRecommender/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/ItemKNNSimilarityHybridRecommender/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 57.3991
# Function value obtained: -0.0241
# Current minimum: -0.0241
# Iteration No: 8 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1975, 'alpha': 0.14188000443238327}
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.11 min. Users per second: 625
# SearchBayesianSkopt: New best config found. Config 7: {'topK': 1975, 'alpha': 0.14188000443238327} - results: PRECISION: 0.0500829, PRECISION_RECALL_MIN_DEN: 0.0819122, RECALL: 0.0775443, MAP: 0.0242935, MAP_MIN_DEN: 0.0394717, MRR: 0.1672682, NDCG: 0.0803006, F1: 0.0608592, HIT_RATE: 0.3406039, ARHR_ALL_HITS: 0.2003766, NOVELTY: 0.0044726, AVERAGE_POPULARITY: 0.1782957, DIVERSITY_MEAN_INTER_LIST: 0.9485609, DIVERSITY_HERFINDAHL: 0.9948538, COVERAGE_ITEM: 0.5354797, COVERAGE_ITEM_HIT: 0.0576978, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3406039, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0460225, SHANNON_ENTROPY: 9.4618951, RATIO_DIVERSITY_HERFINDAHL: 0.9951823, RATIO_DIVERSITY_GINI: 0.0904692, RATIO_SHANNON_ENTROPY: 0.7011985, RATIO_AVERAGE_POPULARITY: 3.5231574, RATIO_NOVELTY: 0.2558969,
#
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNSimilarityHybridRecommender/ItemKNNSimilarityHybridRecommender
#
# ItemKNNSimilarityHybridRecommender: Saving model in file 'result_experiments/ItemKNNSimilarityHybridRecommender/ItemKNNSimilarityHybridRecommender_best_model'
# ItemKNNSimilarityHybridRecommender: Saving complete
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 99.2387
# Function value obtained: -0.0243
# Current minimum: -0.0243
# Iteration No: 9 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1037, 'alpha': 0.2305477028199079}
# EvaluatorHoldout: Processed 41629 (100.0%) in 1.13 min. Users per second: 614
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'topK': 1037, 'alpha': 0.2305477028199079} - results: PRECISION: 0.0493574, PRECISION_RECALL_MIN_DEN: 0.0809710, RECALL: 0.0766955, MAP: 0.0239772, MAP_MIN_DEN: 0.0390007, MRR: 0.1659590, NDCG: 0.0793979, F1: 0.0600619, HIT_RATE: 0.3372649, ARHR_ALL_HITS: 0.1983287, NOVELTY: 0.0044191, AVERAGE_POPULARITY: 0.1894875, DIVERSITY_MEAN_INTER_LIST: 0.9386054, DIVERSITY_HERFINDAHL: 0.9938583, COVERAGE_ITEM: 0.4869221, COVERAGE_ITEM_HIT: 0.0563512, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3372649, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0382690, SHANNON_ENTROPY: 9.2051436, RATIO_DIVERSITY_HERFINDAHL: 0.9941864, RATIO_DIVERSITY_GINI: 0.0752277, RATIO_SHANNON_ENTROPY: 0.6821712, RATIO_AVERAGE_POPULARITY: 3.7443092, RATIO_NOVELTY: 0.2528348,
#
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 87.1649
# Function value obtained: -0.0240
# Current minimum: -0.0243
# Iteration No: 10 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 14, 'alpha': 0.4453343972390279}
# EvaluatorHoldout: Processed 41629 (100.0%) in 36.08 sec. Users per second: 1154
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 14, 'alpha': 0.4453343972390279} - results: PRECISION: 0.0464460, PRECISION_RECALL_MIN_DEN: 0.0751228, RECALL: 0.0709242, MAP: 0.0222642, MAP_MIN_DEN: 0.0358214, MRR: 0.1545758, NDCG: 0.0736541, F1: 0.0561326, HIT_RATE: 0.3196570, ARHR_ALL_HITS: 0.1844327, NOVELTY: 0.0046234, AVERAGE_POPULARITY: 0.1450022, DIVERSITY_MEAN_INTER_LIST: 0.9647307, DIVERSITY_HERFINDAHL: 0.9964707, COVERAGE_ITEM: 0.4041294, COVERAGE_ITEM_HIT: 0.0670421, ITEMS_IN_GT: 0.9925736, COVERAGE_USER: 1.0000000, COVERAGE_USER_HIT: 0.3196570, USERS_IN_GT: 1.0000000, DIVERSITY_GINI: 0.0436917, SHANNON_ENTROPY: 9.8431158, RATIO_DIVERSITY_HERFINDAHL: 0.9967997, RATIO_DIVERSITY_GINI: 0.0858874, RATIO_SHANNON_ENTROPY: 0.7294498, RATIO_AVERAGE_POPULARITY: 2.8652698, RATIO_NOVELTY: 0.2645198,
#
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 39.1859
# Function value obtained: -0.0223
# Current minimum: -0.0243
# SearchBayesianSkopt: Search complete. Best config is 7: {'topK': 1975, 'alpha': 0.14188000443238327}

# %%
from Recommenders.DataIO import DataIO

data_loader = DataIO(folder_path=output_folder_path)
search_metadata = data_loader.load_data(
    recommender_class.RECOMMENDER_NAME + "_metadata.zip"
)

result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#          PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#   cutoff
# 0 10      0.049646                 0.081277  0.076928  0.024116    0.039132
# 1 10      0.045307                 0.074159  0.070195  0.021887    0.035449
# 2 10      0.045845                 0.075296  0.071307  0.022223    0.036141
# 3 10      0.049216                 0.079335  0.074938   0.02386    0.038386
# 4 10      0.048742                  0.08007  0.075846  0.023623    0.038429
# 5 10       0.04119                 0.065641   0.06186  0.019811    0.031885
# 6 10      0.049574                 0.081277  0.076951  0.024149    0.039203
# 7 10      0.050083                 0.081912  0.077544  0.024293    0.039472
# 8 10      0.049357                 0.080971  0.076695  0.023977    0.039001
# 9 10      0.046446                 0.075123  0.070924  0.022264    0.035821
#
#                MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#   cutoff                                                        ...
# 0 10      0.166294  0.079673  0.060347  0.337841      0.199072  ...
# 1 10      0.153839  0.072794   0.05507  0.315189      0.182537  ...
# 2 10      0.156414  0.074006   0.05581  0.319249      0.185454  ...
# 3 10      0.163821  0.078267  0.059412  0.332965      0.196593  ...
# 4 10      0.163902  0.078387  0.059346  0.334502      0.195626  ...
# 5 10      0.142557  0.065895  0.049452  0.292512      0.167336  ...
# 6 10      0.166503  0.079739    0.0603  0.337673      0.199367  ...
# 7 10      0.167268  0.080301  0.060859  0.340604      0.200377  ...
# 8 10      0.165959  0.079398  0.060062  0.337265      0.198329  ...
# 9 10      0.154576  0.073654  0.056133  0.319657      0.184433  ...
#
#          COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#   cutoff
# 0 10               1.0          0.337841         1.0       0.043104
# 1 10               1.0          0.315189         1.0       0.037386
# 2 10               1.0          0.319249         1.0       0.034196
# 3 10               1.0          0.332965         1.0       0.086583
# 4 10               1.0          0.334502         1.0        0.03551
# 5 10               1.0          0.292512         1.0       0.112926
# 6 10               1.0          0.337673         1.0       0.042957
# 7 10               1.0          0.340604         1.0       0.046022
# 8 10               1.0          0.337265         1.0       0.038269
# 9 10               1.0          0.319657         1.0       0.043692
#
#          SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#   cutoff
# 0 10            9.470312                   0.995439             0.084732
# 1 10            9.013278                   0.992463             0.073493
# 2 10            8.902093                   0.992004             0.067222
# 3 10            10.52714                    0.99781             0.170201
# 4 10            9.101169                   0.993664             0.069805
# 5 10           11.467335                   0.999294             0.221985
# 6 10            9.440451                   0.995288             0.084443
# 7 10            9.461895                   0.995182             0.090469
# 8 10            9.205144                   0.994186             0.075228
# 9 10            9.843116                     0.9968             0.085887
#
#          RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#   cutoff
# 0 10                  0.701822                 3.422366      0.256438
# 1 10                  0.667953                 3.913616      0.254207
# 2 10                  0.659713                 4.068011      0.251926
# 3 10                  0.780141                 2.588467      0.274311
# 4 10                  0.674466                 3.838576      0.252014
# 5 10                  0.849817                 1.503789      0.297623
# 6 10                  0.699609                 3.467035      0.255961
# 7 10                  0.701198                 3.523157      0.255897
# 8 10                  0.682171                 3.744309      0.252835
# 9 10                   0.72945                  2.86527       0.26452
#
# [10 rows x 27 columns]

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#    topK epochs symmetric sgd_mode  lambda_i  lambda_j learning_rate
# 0   166   1499      True     adam  0.000124  0.001693      0.000103
# 1  1324   1499     False  adagrad  0.000032  0.006309      0.016491
# 2  1191   1499     False     adam  0.002197  0.000027       0.00117
# 3   NaN    NaN       NaN      NaN       NaN       NaN           NaN
# 4   NaN    NaN       NaN      NaN       NaN       NaN           NaN
# 5   NaN    NaN       NaN      NaN       NaN       NaN           NaN
# 6   NaN    NaN       NaN      NaN       NaN       NaN           NaN
# 7   NaN    NaN       NaN      NaN       NaN       NaN           NaN
# 8   NaN    NaN       NaN      NaN       NaN       NaN           NaN
# 9   NaN    NaN       NaN      NaN       NaN       NaN           NaN

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'topK': 1975, 'alpha': 0.14188000443238327}

# %%
exception_list = search_metadata["exception_list"]
exception_list
# Out:
# ['Traceback (most recent call last):\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 604, in _objective_function\n    result_df, recommender_instance = self._evaluate_on_validation(\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 395, in _evaluate_on_validation\n    self.model_counter: recommender_instance.get_validation_summary_table()\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\Recommenders\\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table\n    return self._earlystopping_validation_summary_df.copy()\nAttributeError: \'NoneType\' object has no attribute \'copy\'\n',
#  'Traceback (most recent call last):\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 604, in _objective_function\n    result_df, recommender_instance = self._evaluate_on_validation(\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 395, in _evaluate_on_validation\n    self.model_counter: recommender_instance.get_validation_summary_table()\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\Recommenders\\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table\n    return self._earlystopping_validation_summary_df.copy()\nAttributeError: \'NoneType\' object has no attribute \'copy\'\n',
#  'Traceback (most recent call last):\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 604, in _objective_function\n    result_df, recommender_instance = self._evaluate_on_validation(\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\HyperparameterTuning\\SearchAbstractClass.py", line 395, in _evaluate_on_validation\n    self.model_counter: recommender_instance.get_validation_summary_table()\n  File "d:\\Developing\\RecSys_PoliMi_challenge_2020\\Recommenders\\Incremental_Training_Early_Stopping.py", line 110, in get_validation_summary_table\n    return self._earlystopping_validation_summary_df.copy()\nAttributeError: \'NoneType\' object has no attribute \'copy\'\n',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
recommender = recommender_class(URM_all)
recommender.fit(**best_hyperparameters)
recommender.save_model(
    folder_path=output_folder_path,
    file_name=recommender_class.RECOMMENDER_NAME
    + "_best_model_trained_on_everything.zip",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 recommender = recommender_class(URM_all)
# ----> 2 recommender.fit(**best_hyperparameters)
#       3 recommender.save_model(
#       4     folder_path=recommender_class,
#       5     file_name=recommender_class.RECOMMENDER_NAME
#       6     + "_best_model_trained_on_everything.zip",
#       7 )
#
# TypeError: fit() argument after ** must be a mapping, not NoneType

# %%
from utils.create_submission import create_submission

create_submission(recommender)
